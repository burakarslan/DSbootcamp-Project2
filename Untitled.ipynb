# %% [markdown]
# 1- Web Scraping

# %%
import pandas as pd
import numpy as np
import matplotlib as plot
# %matplotlib inline
import seaborn as sns
from bs4 import BeautifulSoup
import requests

# %%
url = 'https://www.arabam.com/ikinci-el/otomobil'
response = requests.get(url)

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# ' <!DOCTYPE html><html ng-app="arabam"><head>  <script async src="//arabam.api.useinsider.com/ins.js?id=10001971"></script>    <title>İkinci El Satılık Araba Fiyatları ve İlanları - Sayfa 1</title><meta name="description" content="İkinci El Satılık Araba fiyatları arabam.com\'da! İkinci El Satılık Araba ilanlarını inceleyin ve aradığınız İkinci El Satılık Araba ilanını arabam.com\'da hemen bulun!">  <meta http-equiv="Content-Type" content="text/html; charset=utf-8" /><meta property="al:ios:url" content="arabam://" /><meta property="al:ios:app_store_id" content="369111943" /><meta property="al:ios:app_name" content="Arabam" />  <meta property="al:android:url" content="https://www.arabam.com/ikinci-el/otomobil">  <meta property="al:android:url" content="http://www.arabam.com"><meta property="al:android:package" content="com.dogan.arabam"><meta property="al:android:app_name" content="Arabam"><meta property="al:web:url" content="https://www.arabam.com/ikinci-el/otomobil" /><meta name="viewport" content="width=device-width, initial-scale=1, maximum-scale=1, user-scalable=1" /><meta name="twitter:title" content="İkinci El Satılık Araba Fiyatları ve İlanları - Sayfa 1"><meta name="twitter:description" content="İkinci El Satılık Araba fiyatları arabam.com\'da! İkinci El Satılık Araba ilanlarını inceleyin ve aradığınız İkinci El Satılık Araba ilanını arabam.com\'da hemen bulun!" /><meta property="og:type" content="website" /><meta property="og:title" content="İkinci El Satılık Araba Fiyatları ve İlanları - Sayfa 1" /><meta property="og:description" content="İkinci El Satılık Araba fiyatları arabam.com\'da! İkinci El Satılık Araba ilanlarını inceleyin ve aradığınız İkinci El Satılık Araba ilanını arabam.com\'da hemen bulun!" /><meta property="og:site_name" content="www.arabam.com" /><meta itemprop="name" content="İkinci El Satılık Araba Fiyatları ve İlanları - Sayfa 1" /><meta itemprop="creator" content="arabam.com" /><meta itemprop="copyrightHolder" content="arabam.com" /><meta itemprop="provider" content="arabam.com" /><meta itemprop="sourceOrganization" content="arabam.com" /><meta itemprop="inLanguage" content="tr-TR" /><meta itemprop="isFamilyFriendly" content="true" /><meta name="revisit-after" content="1 Days" /><meta itemprop="keywords" content="İkinci El Satılık Araba fiyatları arabam.com\'da! İkinci El Satılık Araba ilanlarını inceleyin ve aradığınız İkinci El Satılık Araba ilanını arabam.com\'da hemen bulun!" /><link rel="apple-touch-icon" sizes="180x180" href="/apple-touch-icon.png"><link rel="icon" type="image/png" href="/favicon-32x32.png" sizes="32x32"><link rel="icon" type="image/png" href="/favicon-16x16.png" sizes="16x16"><link rel="icon" sizes="192x192" href="/192x192-arabam-ikon.png"><link rel="manifest" href="/manifest.json"><link rel="mask-icon" href="/safari-pinned-tab.svg" color="#c0282f"><link rel="shortcut icon" href="/arabam-favicon-144x144.png"><link rel="dns-prefetch" href="https://fonts.googleapis.com/"><link rel="dns-prefetch" href="https://d38ceu5cy6520w.cloudfront.net"><link rel="dns-prefetch" href="https://www.googletagmanager.com/"><link rel="dns-prefetch" href="https://arbimg1.mncdn.com/"><link rel="dns-prefetch" href="https://arbimg2.mncdn.com/"><link rel="dns-prefetch" href="https://arbimg3.mncdn.com/"><link rel="dns-prefetch" href="https://arbimg4.mncdn.com/"><link rel="dns-prefetch" href="https://arbimg55.mncdn.com/"><link rel="dns-prefetch" href="https://arbimg6.mncdn.com/"><link rel="dns-prefetch" href="https://arbimg7.mncdn.com/"><link rel="dns-prefetch" href="https://connect.facebook.net/"><link rel="dns-prefetch" href="https://creativecdn.com/">   <link rel="alternate" href="android-app://com.dogan.arabam/arabam/searchAdvert" />   <meta property="og:image" content="https://arbimg1.mncdn.com/assets/dist/img/arabam-faceshare.png?v=20201225143513" />      <script> function isIE() { var myNav = navigator.userAgent.toLowerCase(); return (myNav.indexOf(\'msie\') != -1) ? parseInt(myNav.split(\'msie ...
