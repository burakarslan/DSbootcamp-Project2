# %%
#İmport all required libaries first.
import pandas as pd
import numpy as np
import matplotlib as plot
# %matplotlib inline
import seaborn as sns
from bs4 import BeautifulSoup
import requests

from random import randint
from time import sleep
import statsmodels.api as sm
import statsmodels.formula.api as smf
import patsy

from sklearn.linear_model import LinearRegression
from sklearn.linear_model import RidgeCV

# %%
url_fm2021 = 'https://fmdataba.com/21/l/2613/premier-league/best-players/' 
response = requests.get(url_fm2021)
response.status_code
# Out:
# 422

# %%
headers = {'Accept-Language': 'en-gb'}
response = requests.get(url_fm2021, headers=headers)
from fake_useragent import UserAgent
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
response = requests.get(url_fm2021, headers=headers)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.text,"html.parser")
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Premier League FM 2021 Best Players Review, Profiles</title>
# <meta content="Premier League FM 2021 Best Players Review, Profiles, Premier League, ratings, highest rated, top players, some of the biggest stars of the game, Premier League fm21 attributes, current ability (ca), potential ability (pa), stats, ratings, salary, traits." name="description">
# <meta content="Premier League FM 2021 Best Players Review, Profiles" property="og:title"/>
# <meta content="article" property="og:type"/>
# <meta content="https://fmdataba.com/21/l/2613/premier-league/best-players/" property="og:url"/>
# <meta content="https://fmdataba.com/images/banner.jpg" property="og:image"/>
# <meta content="FM 2021 | Team, Player, League Review" property="og:site_name"/>
# ...
