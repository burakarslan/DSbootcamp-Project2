# %% [markdown]
# 1- Web Scraping

# %%
import pandas as pd
import numpy as np
import matplotlib as plot
# %matplotlib inline
import seaborn as sns
from bs4 import BeautifulSoup
import requests

# %%
url1 = 'https://en.wikipedia.org/wiki/List_of_countries_and_dependencies_by_number_of_physicians'
url2 = 'https://en.wikipedia.org/wiki/List_of_countries_by_home_ownership_rate'
url3 = 'https://en.wikipedia.org/wiki/List_of_countries_by_Human_Development_Index'
url4 = 'https://en.wikipedia.org/wiki/List_of_countries_by_antidepressant_consumption'
url5 = 'https://en.wikipedia.org/wiki/World_Happiness_Report'
url6 = 'https://en.wikipedia.org/wiki/List_of_countries_by_intentional_homicide_rate'
url7 = 'https://en.wikipedia.org/wiki/List_of_countries_by_age_at_first_marriage'
url8 = 'https://en.wikipedia.org/wiki/List_of_countries_by_GDP_(nominal)_per_capita'
table_class="wikitable sortable jquery-tablesorter"

response = requests.get(url1)

# %%
response.status_code
# Out:
# 200

# %%
response.text
# Out:
# '<!DOCTYPE html>\n<html class="client-nojs" lang="en" dir="ltr">\n<head>\n<meta charset="UTF-8"/>\n<title>List of countries and dependencies by number of physicians - Wikipedia</title>\n<script>document.documentElement.className="client-js";RLCONF={"wgBreakFrames":!1,"wgSeparatorTransformTable":["",""],"wgDigitTransformTable":["",""],"wgDefaultDateFormat":"dmy","wgMonthNames":["","January","February","March","April","May","June","July","August","September","October","November","December"],"wgRequestId":"X@pxhQpAAEQAAGBNZqwAAABV","wgCSPNonce":!1,"wgCanonicalNamespace":"","wgCanonicalSpecialPageName":!1,"wgNamespaceNumber":0,"wgPageName":"List_of_countries_and_dependencies_by_number_of_physicians","wgTitle":"List of countries and dependencies by number of physicians","wgCurRevisionId":996411109,"wgRevisionId":996411109,"wgArticleId":49470944,"wgIsArticle":!0,"wgIsRedirect":!1,"wgAction":"view","wgUserName":null,"wgUserGroups":["*"],"wgCategories":["Wikipedia articles in need of updatin
# ...

# %%
soup = BeautifulSoup(response.text,"html.parser")

# %%
country_name = []
size =[]
physicians_per_10k = []
physicians_per_10k_old = []

# %%
phy_list=soup.find('table',{'class':"wikitable"})
phy_list
# Out:
# <table class="sortable wikitable">
# <tbody><tr>
# <th rowspan="2">Country or dependency
# </th>
# <th colspan="2">2000–2009<sup class="reference" id="cite_ref-1"><a href="#cite_note-1">[1]</a></sup>
# </th>
# <th>2007–2013 <sup class="reference" id="cite_ref-2"><a href="#cite_note-2">[2]</a></sup>
# </th></tr>
# <tr>
# <th>Size
# </th>
# <th>Physicians per<br/><sup>10,000 people</sup>
# </th>
# <th>Physicians per<br/><sup>10,000 people</sup>
# </th></tr>
# <tr>
# ...

# %%
df=pd.read_html(str(phy_list))
df=pd.DataFrame(df[0])
df.head(100)
# Out:
#    Country or dependency 2000–2009[1]                              \
#    Country or dependency         Size Physicians per10,000 people
# 0              Australia        19612                        10.0
# 1                Austria        31175                        38.0
# 2             Azerbaijan        32388                        38.0
# 3                Albania         3626                        11.0
# 4                Algeria        40857                        12.0
# ..                   ...          ...                         ...
# 95               Morocco        18269                         6.0
# 96      Marshall Islands           24                         5.0
# 97                Mexico       303519                        29.0
# 98            Micronesia           60                         6.0
# 99            Mozambique          548                         0.5
#
#                  2007–2013 [2]
#    Physicians per10,000 people
# 0                         32.7
# ...
