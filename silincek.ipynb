# %% [markdown]
# # Project Luther: Soccer Players Values

# %% [markdown]
# Elvis Davalillo - info@elvisdavalillo.com
#
# Part 1/2 - Scrapping, organization, and cleaning for soccer players data
#
# Scrapped website: www.sofifa.com

# %% [markdown]
# Process:
#
#     1.Webscraping basic player information from main subpage
#     2.Webscraping detailed player information from every player subpage
#     3.Cleaning the data

# %%
import numpy as np
import pandas as pd 
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

import random
import urllib.request
import requests
import warnings
import time
import random
from __future__ import print_function, division
from bs4 import BeautifulSoup

# %%
# import requests
requests.__path__

# %%
base_url = 'https://sofifa.com/players?offset='
response = requests.get(base_url)

# %%
response.status_code # status code = 200 => OK

# %%
page = response.text

# %%
soup = BeautifulSoup(page, "html5")

# %%
print(soup.tbody.prettify());

# %% [markdown]
# ## Webscrape basic player information from main subpages

# %%
# scrape data from thousands of players going through different offsets=subpages 
offset = 0
columns = ['ID', 'Name', 'Age', 'Country','Position','Overall', 'Potential', 'Team'
           , 'Value', 'Salary']
data = DataFrame(columns=columns)

# %%
# start first with the basic player data from the url https://sofifa.com/players?offset=
for offset in range(0,300):
    offset+=1
    url = base_url + str(offset*61)
    source_code = requests.get(url)
    plain_text = source_code.text
    soup = BeautifulSoup(plain_text)
    table_body = soup.find('tbody')
    for row in table_body.findAll('tr'):
        td = row.findAll('td')
        player_id = td[0].find('img').get('id').strip()
        name = td[1].findAll('a')[1].text
        age = td[2].text.strip()
        country = td[1].find('a').get('title')
        position = td[1].findAll('a')[2].text
        overall = td[3].text.strip()
        potential = td[4].text.strip()
        club = td[5].findAll('a')[0].text
        value = td[7].text.strip()
        salary = td[8].text
        player_data = DataFrame([[player_id, name, age, country, position, overall, 
                                  potential, club, value, salary]])
        player_data.columns = columns
        data = data.append(player_data, ignore_index=True)
    data.to_csv('baseline_data.csv', encoding='utf-8')
    if (offset % 20 == 0):
        print(offset)

# %%
data = pd.read_csv('baseline_data.csv')
player = None
player_url = 'https://sofifa.com/player/'
id_list = data['ID']
count = 0
data.head(5)
# Out:
#    Unnamed: 0      ID          Name  Age    Country Position  Overall  \
# 0           0  236007      E. Barco   19  Argentina       LM       74
# 1           1  229582    G. Mancini   22      Italy       CB       74
# 2           2  232104      D. James   20      Wales       LM       70
# 3           3  235883  R. Sessegnon   18    England       LM       75
# 4           4  224232    N. Barella   21      Italy       CM       79
#
#    Potential            Team   Value Salary
# 0         89  Atlanta United    €12M    €4K
# 1         85        Atalanta   €8.5M   €18K
# 2         82    Swansea City   €3.2M   €12K
# 3         86          Fulham  €10.5M   €23K
# 4         89        Cagliari    €20M   €28K

# %%
# let's filter the player list to only include players from the largest 3 European Leagues
teams_by_league = pd.read_csv('teams_by_league.csv')

# %%
teams_by_league = teams_by_league.iloc[:,:2]

# %%
teams_filter = list(teams_by_league.Team)

# %%
small_data = data[data['Team'].isin(teams_filter)].reset_index()
small_data = small_data.drop(['index','Unnamed: 0'],axis=1)

# %%
# Add the league column so we can reference to it later
small_data = pd.merge(small_data,teams_by_league[['Team','League']],on='Team', how='left')

# %%
small_data.to_csv('small_player_data.csv', encoding='utf-8')

# %%
# Now let's gather the skills statistics for each player

# %%
skill_names = []

# %% [markdown]
# ## Webscrape detailed player information from player subpage

# %%
player_data_url = 'https://sofifa.com/player/'
r = 0
for index, row in small_data.iterrows():
    skill_names = []
    skill_map = {'ID' : str(row['ID'])}
    url = player_data_url + str(row['ID'])
    source_code = requests.get(url)
    plain_text = source_code.text
    soup = BeautifulSoup(plain_text)
    categories = soup.findAll('div', {'class': 'column col-4'})
    for category in categories[:-1]:
        skills = category.findAll('li')
        for skill in skills:
            a = skill.text.split()
            #print(a)
            a.reverse()
            value = a.pop()
            a.reverse()
            n = ' '.join(a)
            skill_names.append(n)
            skill_map[str(n)] = value
    attr_data = DataFrame(columns=skill_names)
    for key in skill_map.keys():
        attr_data.loc[r,key] = skill_map[key]
    r = r + 1
    master_data = pd.concat([master_data, attr_data])
    if r % 500 == 0:
        print(r)
        time.sleep(2)
        master_data.to_csv('skills_data.csv', encoding='utf-8')

# %%
master_data = DataFrame(columns=skill_names)

# %%
skills_data = pd.read_csv('skills_data.csv')

# %% [markdown]
# ## Data Cleaning

# %%
skills_data = skills_data.drop(['Unnamed: 0'],axis=1)

# %%
skills_data.shape
# Out:
# (2000, 35)

# %%
# let's make ID the index for our DF to be able to merge the master_data set with the small_data set
skills_data = skills_data.set_index('ID')

# %%
small_data = small_data.set_index('ID')

# %%
# let's combine the basic data and the skills of the players

# %%
full_data = pd.merge(small_data,skills_data, left_index=True, right_index=True)

# %%
full_data.describe()
# Out:
#                Age      Overall    Potential
# count  2004.000000  2004.000000  2004.000000
# mean     24.943613    72.365768    77.750000
# std       5.076973     8.054014     5.715494
# min      16.000000    47.000000    52.000000
# 25%      21.000000    66.000000    74.000000
# 50%      25.000000    74.000000    78.000000
# 75%      29.000000    78.000000    82.000000
# max      43.000000    94.000000    94.000000

# %%
full_data.columns
# Out:
# Index(['Name', 'Age', 'Country', 'Position', 'Overall', 'Potential', 'Team',
#        'Value', 'Salary', 'League', 'Acceleration', 'Aggression', 'Agility',
#        'Balance', 'Ball Control', 'Composure', 'Crossing', 'Curve',
#        'Dribbling', 'FK Accuracy', 'Finishing', 'GK Diving', 'GK Handling',
#        'GK Kicking', 'GK Positioning', 'GK Reflexes', 'Heading Accuracy',
#        'Interceptions', 'Jumping', 'Long Passing', 'Long Shots', 'Marking',
#        'Penalties', 'Positioning', 'Reactions', 'Short Passing', 'Shot Power',
#        'Sliding Tackle', 'Sprint Speed', 'Stamina', 'Standing Tackle',
#        'Strength', 'Vision', 'Volleys'],
#       dtype='object')

# %%
# find column names with nan values 
null_columns = full_data.columns[full_data.isnull().any()]
full_data[null_columns].isnull().sum()
# Out:
# Agility           11
# Balance           11
# Composure         72
# Curve             11
# Jumping           11
# Sliding Tackle    11
# Vision            11
# Volleys           11
# dtype: int64

# %%
# find the rows that had nan values
full_data[full_data.isnull().any(axis=1)].loc[:, ["Agility", "Balance", "Composure", "Curve",
                                                  "Jumping", "Sliding Tackle", "Vision","Volleys"]]
# Out:
#        Agility Balance Composure Curve Jumping Sliding Tackle Vision Volleys
# ID
# 185         45      43       NaN    12      74             12     34      14
# 241         72      70       NaN    87      59             51     83      75
# 246         68      82       NaN    74      64             36     91      85
# 450         75      80       NaN    68    82+9             24     76      73
# 1041        55      90       NaN    60      49             69     69      60
# 1109       NaN     NaN       NaN   NaN     NaN            NaN    NaN     NaN
# 1183       NaN     NaN       NaN   NaN     NaN            NaN    NaN     NaN
# 1198        53      65       NaN    56      74             19     57    80+2
# 1419        66      79       NaN  65-2      78           78-3   79-1      62
# 1615       NaN     NaN       NaN   NaN     NaN            NaN    NaN     NaN
# 1845       NaN     NaN       NaN   NaN     NaN            NaN    NaN     NaN
# 2956        53      56       NaN    45      67             70     76      73
# 3912        68      54       NaN    75      72             30     66      74
# 4077        75      78       NaN    85      69             25     76      58
# 4731        68      70       NaN    60      68             68     72      64
# 4738       NaN     NaN       NaN   NaN     NaN            NaN    NaN     NaN
# 5003       NaN     NaN       NaN   NaN     NaN            NaN    NaN     NaN
# 5099        72      66       NaN  78+5      67             78   74+5      72
# 5589       NaN     NaN       NaN   NaN     NaN            NaN    NaN     NaN
# 6235       NaN     NaN       NaN   NaN     NaN            NaN    NaN     NaN
# 6908        49      65       NaN    78      55             60     82      80
# 7142        53      58       NaN    44      71           76-1     37      46
# 7512      60+3    62-8       NaN    70      75             16   77-3      82
# 7612        45      64       NaN    83      75             64     70      61
# 9512       NaN     NaN       NaN   NaN     NaN            NaN    NaN     NaN
# 10535       79      90       NaN    85      53             59     94      66
# 11141       64      61       NaN    65      89             22     64      76
# 11983       43      42       NaN    25      50             25     25      25
# 12259       69      58       NaN    56      74             75     79      67
# 13038       54      59       NaN    53      76             82     52      44
# ...        ...     ...       ...   ...     ...            ...    ...     ...
# 110082      45      60       NaN    25      62             25     36      25
# 111010      68      75       NaN    82      57             20     74      61
# 120202      69      64       NaN    67      73             80     63      47
# 120274      80      84       NaN    81      60             22     82      84
# 135455      72      71       NaN    80      71             77     65      80
# 135567      86      70       NaN    76      61             15     74      81
# 136130      44      44       NaN    47      84             78     35      36
# 137179      48      63       NaN    34      90             69     46      34
# 138871      60      50       NaN    76      75             30     60      68
# 140601      50      47       NaN    42      84             82     44      35
# 146641     NaN     NaN       NaN   NaN     NaN            NaN    NaN     NaN
# 146692      77      74       NaN    82      62             25     77      75
# 156272      76      75       NaN    77      66             47     72      71
# 158804      79      85       NaN    75      73             52     80      80
# 163386      57      69       NaN    44      68             46     57      24
# 164300      58      54       NaN    37      79             76     43      41
# 164978      79      82       NaN    74      52             52     75      71
# 165816      83      89       NaN    70      59             72     64      64
# 177831      39      40       NaN    25      67             25     25      25
# 187323      61      58       NaN    52      69           78+2  48+12      70
# 191092      71      72       NaN    34      50             19     48      26
# 191166    59+6    48-4       NaN  42-3    56-3           32-2   52+1    39-3
# 196382      65      65       NaN    40      51             25     37      57
# 205893      58      60       NaN    46      72             72     47      40
# 207715      82      78       NaN    70      66             23     63      74
# 208106      66      70       NaN    50      70             25     49      53
# 210393      82      79       NaN    56      58             39     60      48
# 212056      67      69       NaN    58      61             25     53      45
# 228482      57      64       NaN    43      60             66     33      35
# 231968      64      66       NaN    48      65             19     52      49
#
# [72 rows x 8 columns]

# %%
#remove the rows with a large number of NaN
full_data = full_data.drop([1109,1183,1615,4738,5003,5589,6235,9512,146641]);

# %%
#fill the NaN with the feature average
full_data = full_data.fillna(full_data.mean())

# %%
#fill remaining NaN with zeros
full_data = full_data.fillna(0)

# %%
full_data['Value'],full_data['Salary'] = full_data['Value'].str.replace('€',''),full_data['Salary'].str.replace('€','')

# %%
#make the value column an integer number with the same unit across observations
full_data.Value = (full_data.Value.replace(r'[KM]+$', '', regex=True).astype(float) * \
        full_data.Value.str.extract(r'[\d\.]+([KM]+)', expand=False)
        .fillna(1)
        .replace(['K','M'], [10**3, 10**6]).astype(int))

# %%
full_data
# Out:
#                     Name  Age              Country Position  Overall  \
# ID
# 185             D. James   41              England       GK       65
# 241             R. Giggs   39                Wales       LM       78
# 246           P. Scholes   37              England       CM       80
# 450           D. Vassell   31              England       ST       69
# 768               Felipe   33               Brazil       CB       75
# 1041          J. Zanetti   39            Argentina       RM       75
# 1178        P. Cannavaro   36                Italy       CB       75
# 1198          F. Inzaghi   37                Italy       ST       73
# 1238            F. Totti   39                Italy       CF       80
# 1419           P. Vieira   34               France      CDM       76
# 1845         O. Solskjær   34               Norway       ST       75
# 2147     M. Stekelenburg   35          Netherlands       GK       73
# 2956           S. Petrov   32             Bulgaria       CM       76
# 3912             L. Saha   33               France       ST       76
# 4077               Simão   33             Portugal       LM       74
# 4098               Tiago   35             Portugal       CM       81
# 4731         S. Perrotta   34                Italy       CM       72
# 5099        G. Zambrotta   34                Italy       RB       76
# 6908        D. Stanković   33               Serbia       CM       78
# 7142          K. Kaladze   33              Georgia       CB       76
# 7512           H. Crespo   35            Argentina       ST       76
# 7612            I. Harte   36  Republic of Ireland       LB       63
# 7631          A. Cassano   33                Italy       CF       76
# 10535               Xavi   34                Spain       CM       86
# 11141           M. Klose   37              Germany       ST       79
# 11983         B. Friedel   43        United States       GK       77
# 12259           S. Keita   35                 Mali      CDM       76
# 13038              Puyol   35                Spain       CB       83
# 13732           J. Terry   36              England       CB       76
# 17964          M. Petrov   33             Bulgaria       LM       72
# ...                  ...  ...                  ...      ...      ...
# 246947       P. Akouokou   20          Ivory Coast       CM       62
# 246948             Irizo   20                Spain       CM       58
# 246949  Victor Campuzano   21                Spain       ST       63
# 247026        A. Schäfer   19              Hungary       LM       62
# 247076          C. Oliva   22              Uruguay       CM       70
# 247089      Julio Alonso   19                Spain       LB       60
# 247103         D. Hancko   20             Slovakia       LB       63
# 247140         J. Benson   18              England       CM       59
# 247170       Iago Indias   22                Spain       CB       61
# 247204           Emerson   19               Brazil       RB       71
# 247257            Ibañez   19               Brazil       CB       61
# 247328     Unai Vencedor   17                Spain       CM       63
# 247394     D. Kulusevski   18               Sweden       CM       64
# 247411            Altube   18                Spain       GK       60
# 247458         Alex Sola   19                Spain       RB       67
# 247496               Apa   18                Spain       RB       64
# 247500             Edgar   21                Spain       CB       62
# 247501            Garijo   19                Spain       CM       59
# 247502           Tellado   19                Spain       RB       59
# 247558     R. Doratiotto   19                Italy       CF       60
# 247564          F. Verde   18                Italy       ST       62
# 247793            Seoane   21                Spain       CM       65
# 247806       Mikel Carro   19                Spain       CM       64
# 247854       M. El Hacen   20           Mauritania      CDM       68
# 247887         D. Merola   18                Italy       ST       60
# 248148         Zubimendi   19                Spain       CM       58
# 248165          A. Ratiu   20              Romania       RB       61
# 248456       Miguel Marí   21                Spain       CM       64
# 248550       Dani Vivian   18                Spain       CB       64
# 248710           Paulino   21                Spain       RM       64
#
#         Potential                     Team       Value Salary  \
# ID
# 185            65              Bournemouth         0.0      0
# 241            78        Manchester United         0.0    75K
# 246            80        Manchester United         0.0      0
# 450            69           Leicester City         0.0      0
# 768            75                     SPAL   2700000.0    13K
# 1041           75                    Inter         0.0      0
# 1178           75                 Sassuolo    900000.0    30K
# 1198           73                    Milan         0.0      0
# 1238           80                     Roma   1500000.0    50K
# 1419           87          Manchester City         0.0      0
# 1845           83        Manchester United         0.0      0
# 2147           73                  Everton    950000.0    30K
# 2956           76              Aston Villa         0.0      0
# 3912           76                    Lazio         0.0      0
# 4077           74             RCD Espanyol         0.0      0
# 4098           81          Atlético Madrid   5500000.0    50K
# 4731           72                     Roma         0.0      0
# 5099           76                    Milan         0.0      0
# 6908           78                    Inter         0.0      0
# 7142           76                    Genoa         0.0      0
# 7512           76                    Parma         0.0      0
# 7612           63              Bournemouth         0.0     2K
# 7631           76                Sampdoria   3400000.0    20K
# 10535          86             FC Barcelona  15500000.0   150K
# 11141          79                    Lazio   1300000.0    80K
# 11983          77        Tottenham Hotspur    925000.0    25K
# 12259          76                     Roma    900000.0    60K
# 13038          83             FC Barcelona         0.0      0
# 13732          76              Aston Villa   1000000.0    27K
# 17964          72             RCD Espanyol         0.0      0
# ...           ...                      ...         ...    ...
# 246947         73               Real Betis    525000.0     3K
# 246948         72               Real Betis    280000.0     2K
# 246949         74             RCD Espanyol    650000.0     4K
# 247026         77                    Genoa    650000.0     1K
# 247076         78                 Cagliari   2600000.0    15K
# 247089         70               Real Betis    280000.0     1K
# 247103         72               Fiorentina    500000.0     6K
# 247140         72                  Burnley    280000.0     3K
# 247170         67             RCD Espanyol    290000.0     3K
# 247204         83               Real Betis   3600000.0     6K
# 247257         73                 Atalanta    375000.0     2K
# 247328         81  Athletic Club de Bilbao    725000.0     2K
# 247394         80                 Atalanta    925000.0     3K
# 247411         80              Real Madrid    350000.0     3K
# 247458         82            Real Sociedad   1500000.0     3K
# 247496         82       Real Valladolid CF    825000.0     2K
# 247500         71               Real Betis    400000.0     2K
# 247501         72               Real Betis    290000.0     2K
# 247502         72               Real Betis    260000.0     1K
# 247558         75                 Cagliari    450000.0     3K
# 247564         78                 Cagliari    625000.0     3K
# 247793         73              Real Madrid    800000.0    20K
# 247806         75          Atlético Madrid    750000.0     5K
# 247854         81       Real Valladolid CF   1500000.0     5K
# 247887         75                    Inter    425000.0     4K
# 248148         67            Real Sociedad    190000.0     2K
# 248165         73            Villarreal CF    400000.0     3K
# 248456         75                 SD Eibar    775000.0     4K
# 248550         77  Athletic Club de Bilbao    725000.0     2K
# 248710         75         Deportivo Alavés    775000.0     4K
#
#                         League  ... Reactions Short Passing Shot Power  \
# ID                              ...
# 185     English Premier League  ...        64            26         23
# 241     English Premier League  ...        76            85         71
# 246     English Premier League  ...        82            89         88
# 450     English Premier League  ...        67            54         76
# 768            Italian Serie A  ...        72            62         68
# 1041           Italian Serie A  ...        80            84         71
# 1178           Italian Serie A  ...        66            62         72
# 1198           Italian Serie A  ...        88            61      55-13
# 1238           Italian Serie A  ...        79            90         88
# 1419    English Premier League  ...      72-4            79         75
# 1845    English Premier League  ...      76-2          70+9       72+6
# 2147    English Premier League  ...        72            39         13
# 2956    English Premier League  ...        78            83         80
# 3912           Italian Serie A  ...        74            64         84
# 4077    Spain Primera Division  ...        77            74         73
# 4098    Spain Primera Division  ...        77            84         77
# 4731           Italian Serie A  ...        72            74         74
# 5099           Italian Serie A  ...        81            78         79
# 6908           Italian Serie A  ...        82            88         88
# 7142           Italian Serie A  ...        73          61-3         56
# 7512           Italian Serie A  ...        75            65         75
# 7612    English Premier League  ...        67            68         86
# 7631           Italian Serie A  ...        74            86         70
# 10535   Spain Primera Division  ...        90            93         67
# 11141          Italian Serie A  ...        74            69         76
# 11983   English Premier League  ...        73            24         28
# 12259          Italian Serie A  ...        76            79         79
# 13038   Spain Primera Division  ...        81            70         71
# 13732   English Premier League  ...        73            67         61
# 17964   Spain Primera Division  ...        81            72         87
# ...                        ...  ...       ...           ...        ...
# 246947  Spain Primera Division  ...        59            64         59
# 246948  Spain Primera Division  ...        55            64         61
# 246949  Spain Primera Division  ...        62            57         64
# 247026         Italian Serie A  ...        65            62         53
# 247076         Italian Serie A  ...        72            76         70
# 247089  Spain Primera Division  ...        58            54         51
# 247103         Italian Serie A  ...        58            58         46
# 247140  English Premier League  ...        56            60         55
# 247170  Spain Primera Division  ...        59            51         56
# 247204  Spain Primera Division  ...        69            66         65
# 247257         Italian Serie A  ...        49            39         45
# 247328  Spain Primera Division  ...        60            64         65
# 247394         Italian Serie A  ...        63            70         64
# 247411  Spain Primera Division  ...        60            27         20
# 247458  Spain Primera Division  ...        64            65         48
# 247496  Spain Primera Division  ...        60            55         23
# 247500  Spain Primera Division  ...        56            61         45
# 247501  Spain Primera Division  ...        59            63         59
# 247502  Spain Primera Division  ...        63            57         49
# 247558         Italian Serie A  ...        57            57         59
# 247564         Italian Serie A  ...        55            54         58
# 247793  Spain Primera Division  ...        65            65         58
# 247806  Spain Primera Division  ...        64            68         52
# 247854  Spain Primera Division  ...        68            62         51
# 247887         Italian Serie A  ...        55            50         64
# 248148  Spain Primera Division  ...        61            61         53
# 248165  Spain Primera Division  ...        60            59         60
# 248456  Spain Primera Division  ...        63            65         62
# 248550  Spain Primera Division  ...        60            51         46
# 248710  Spain Primera Division  ...        57            63         60
#
#        Sliding Tackle Sprint Speed Stamina Standing Tackle Strength Vision  \
# ID
# 185                12           45      52              11       75     34
# 241                51           60      48              43       61     83
# 246                36           53      34              49       63     91
# 450                24           83      74              26     69+3     76
# 768                76           41      48              80       67     46
# 1041               69           69      55              75       77     69
# 1178               75           31      36              76       75     50
# 1198               19         39-2      31              13       30     57
# 1238               10           34      54              24       75     91
# 1419             78-3         61-3    68-5            79-3     84-1   79-1
# 1845                0        64-10   58-19              24    59+16      0
# 2147               14           36      30              15       77     40
# 2956               70           43      52              62       72     76
# 3912               30           74      47              30       73     66
# 4077               25           68      48              25       45     76
# 4098               69           55      67              77       76     82
# 4731               68           68      67              70       66     72
# 5099               78         68+4    60+5              78       72   74+5
# 6908               60           51      33              70       75     82
# 7142             76-1           53      51            80-1       78     37
# 7512               16        40-23   30-33              19     69-6   77-3
# 7612               64           29      34              68       70     70
# 7631               12           34      34              14       60     86
# 10535              59           65      60              61       60     94
# 11141              22           69      53              26       72     64
# 11983              25           39      37              25       68     25
# 12259              75           67      55              79       77     79
# 13038              82           64      54              85       84     52
# 13732              76           34      50              73       83     59
# 17964              24           68      53              22       63     79
# ...               ...          ...     ...             ...      ...    ...
# 246947             56           65      61              63       67     62
# 246948             38           64      59              44       61     59
# 246949             13           64      56              15       52     52
# 247026             49           78      62              51       34     53
# 247076             68           68      67              72       69     68
# 247089             60           70      60              59       55     44
# 247103             68           53      67              67       69     48
# 247140             47           69      65              55       52     59
# 247170             62           61      65              64       60     44
# 247204             73           84      71              70       73     54
# 247257             72           55      55              70       65     34
# 247328             43           66      67              63       63     64
# 247394             58           69      54              58       54     62
# 247411             14           15      25              14       59     32
# 247458             65           75      79              64       65     45
# 247496             60           86      65              63       55     50
# 247500             58           53      62              65       73     49
# 247501             49           62      52              52       59     61
# 247502             56           72      51              54       51     46
# 247558             18           68      34              17       48     57
# 247564             25           51      54              26       65     55
# 247793             59           74      66              61       54     66
# 247806             59           54      54              63       64     64
# 247854             67           54      72              72       83     58
# 247887             22           65      52              21       60     50
# 248148             48           62      49              39       54     60
# 248165             58           68      61              58       54     52
# 248456             45           65      63              52       58     68
# 248550             63           63      62              64       71     40
# 248710             30           72      57              25       45     64
#
#        Volleys
# ID
# 185         14
# 241         75
# 246         85
# 450         73
# 768         19
# 1041        60
# 1178        33
# 1198      80+2
# 1238        90
# 1419        62
# 1845         0
# 2147        11
# 2956        73
# 3912        74
# 4077        58
# 4098        67
# 4731        64
# 5099        72
# 6908        80
# 7142        46
# 7512        82
# 7612        61
# 7631        79
# 10535       66
# 11141       76
# 11983       25
# 12259       67
# 13038       44
# 13732       55
# 17964       76
# ...        ...
# 246947      42
# 246948      34
# 246949      60
# 247026      44
# 247076      43
# 247089      36
# 247103      48
# 247140      50
# 247170      28
# 247204      44
# 247257      29
# 247328      44
# 247394      42
# 247411       6
# 247458      33
# 247496      27
# 247500      30
# 247501      41
# 247502      39
# 247558      59
# 247564      53
# 247793      44
# 247806      41
# 247854      38
# 247887      43
# 248148      38
# 248165      59
# 248456      45
# 248550      38
# 248710      47
#
# [1995 rows x 44 columns]

# %%
#make the salary column an integer number with the same unit across observations
full_data.Salary = (full_data.Salary.replace(r'[KM]+$', '', regex=True).astype(float) * \
        full_data.Salary.str.extract(r'[\d\.]+([KM]+)', expand=False)
        .fillna(1)
        .replace(['K','M'], [10**3, 10**6]).astype(int))

# %%
numerical_columns_1 = ['Acceleration', 'Aggression', 'Agility', 'Balance',
       'Ball Control', 'Composure', 'Crossing', 'Curve', 'Dribbling',
       'FK Accuracy', 'Finishing', 'GK Diving', 'GK Handling', 'GK Kicking',
       'GK Positioning', 'GK Reflexes', 'Heading Accuracy', 'Interceptions',
       'Jumping', 'Long Passing', 'Long Shots', 'Marking', 'Penalties',
       'Positioning', 'Reactions', 'Short Passing', 'Shot Power',
       'Sliding Tackle', 'Sprint Speed', 'Stamina', 'Standing Tackle',
       'Strength', 'Vision', 'Volleys']

# %%
#before converting the features to integers we need to get rid of "-" in the data
for skill in numerical_columns_1:
    full_data[skill] = full_data[skill].map(lambda x: str(x)[:2])

# %%
#Let's convert the numerical columns to integers
numerical_columns_2 = ['Age','Overall', 'Potential',
       'Value', 'Salary', 'Acceleration', 'Aggression', 'Agility', 'Balance',
       'Ball Control', 'Composure', 'Crossing', 'Curve', 'Dribbling',
       'FK Accuracy', 'Finishing', 'GK Diving', 'GK Handling', 'GK Kicking',
       'GK Positioning', 'GK Reflexes', 'Heading Accuracy', 'Interceptions',
       'Jumping', 'Long Passing', 'Long Shots', 'Marking', 'Penalties',
       'Positioning', 'Reactions', 'Short Passing', 'Shot Power',
       'Sliding Tackle', 'Sprint Speed', 'Stamina', 'Standing Tackle',
       'Strength', 'Vision', 'Volleys']

# %%
#converting numerical columns to int
for column in numerical_columns_2:
    full_data[column] = full_data[column].map(lambda x: int(x))

# %%
full_data.dtypes
# Out:
# Name                object
# Age                  int64
# Country             object
# Position            object
# Overall              int64
# Potential            int64
# Team                object
# Value                int64
# Salary               int64
# League              object
# Acceleration         int64
# Aggression           int64
# Agility              int64
# Balance              int64
# Ball Control         int64
# Composure            int64
# Crossing             int64
# Curve                int64
# Dribbling            int64
# FK Accuracy          int64
# Finishing            int64
# GK Diving            int64
# GK Handling          int64
# GK Kicking           int64
# GK Positioning       int64
# GK Reflexes          int64
# Heading Accuracy     int64
# Interceptions        int64
# Jumping              int64
# Long Passing         int64
# Long Shots           int64
# Marking              int64
# Penalties            int64
# Positioning          int64
# Reactions            int64
# Short Passing        int64
# Shot Power           int64
# Sliding Tackle       int64
# Sprint Speed         int64
# Stamina              int64
# Standing Tackle      int64
# Strength             int64
# Vision               int64
# Volleys              int64
# dtype: object

# %%
full_data.to_csv('full_data.csv', encoding='utf-8')
