# %%
#İmport all required libaries first.
import pandas as pd
import numpy as np
import matplotlib as plot
# %matplotlib inline
import seaborn as sns
from bs4 import BeautifulSoup
import requests

from random import randint
from time import sleep

# %%
url_s = 'https://fmdataba.com/21/fm-2021-best-strikers-center/'
url_aml = 'https://fmdataba.com/21/fm-2021-best-attacking-midfielders-left/'
url_amr = 'https://fmdataba.com/21/fm-2021-best-attacking-midfielders-right/'
url_amc = 'https://fmdataba.com/21/fm-2021-best-attacking-midfielders-center/'

# %%
response = requests.get(url_s)

# %%
response.status_code
# Out:
# 422

# %%
headers = {'Accept-Language': 'en-gb'}
response = requests.get(url_s, headers=headers)
response.status_code
# Out:
# 422

# %%
from fake_useragent import UserAgent
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}

response = requests.get(url_s, headers=headers)
response.status_code
# Out:
# 200

# %%
soup = BeautifulSoup(response.text,"html.parser")

# %%
table = soup.find('table')

# %%
header_list = ['Nation','dummy' ,'Name','Club', 'Age','Value', 'Ove', 'Att', 'Def', 'Tec', 'Men', 'Phy' ,'Spe'] 
df = pd.DataFrame(columns = header_list)

for j in table.find_all('tr')[1:]:
    row_data = j.find_all('td')
    row = [tr.text for tr in row_data]
    if row != ['\n\n\n\n']:
        length = len(df)
        df.loc[length] = row        
df
# Out:
#       Nation dummy                                    Name         Club Age  \
# 0   Argentin                     Lionel MessiAMC, AMR, STC   FC Barcelo  33
# 1   Portugal                Cristiano RonaldoAML, STC, AMR        Zebre  35
# 2     France                    Kylian MbappéAML, AMR, STC   Paris Sain  21
# 3     Brazil                       NeymarML, AMC, AML, STC   Paris Sain  28
# 4     Poland                         Robert LewandowskiSTC   Bayern Mun  31
# 5    England                            Harry KaneSTC, AMC    Tottenham  27
# 6    Senegal                       Sadio ManéAML, AMR, STC    Liverpool  28
# 7      Egypt                    Mohamed SalahAML, AMR, STC    Liverpool  28
# 8   Argentin                         Sergio AgüeroAMC, STC   Manchester  32
# 9     France           Antoine GriezmannAMC, AML, AMR, STC   FC Barcelo  29
# 10   Uruguay                                Luis SuárezSTC   Atlético d  33
# ...

# %%
for i in range(1,10):
    url = 'https://fmdataba.com/21/fm-2021-best-strikers-center/'+str(i)
    headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_10_1) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/39.0.2171.95 Safari/537.36'}
    response = requests.get(url_s, headers=headers)
    sleep(randint(3,10))
    soup = BeautifulSoup(response.text,"html.parser")
    table = soup.find('table') 
    for j in table.find_all('tr')[1:]:
        row_data = j.find_all('td')
        row = [tr.text for tr in row_data]
        if row != ['\n\n\n\n']:
            length = len(df)
            df.loc[length] = row

# %%
df
# Out:
#        Nation dummy                            Name         Club Age    Value  \
# 0    Argentin             Lionel MessiAMC, AMR, STC   FC Barcelo  33  € 50.0M
# 1    Portugal        Cristiano RonaldoAML, STC, AMR        Zebre  35  € 10.0M
# 2      France            Kylian MbappéAML, AMR, STC   Paris Sain  21  € 90.0M
# 3      Brazil               NeymarML, AMC, AML, STC   Paris Sain  28  € 90.0M
# 4      Poland                 Robert LewandowskiSTC   Bayern Mun  31  € 70.0M
# ..        ...   ...                             ...          ...  ..      ...
# 295  Argentin                       Mauro IcardiSTC   Paris Sain  27  € 50.0M
# 296   England               Marcus RashfordAML, STC   Manchester  22  € 60.0M
# 297    Brazil            Gabriel JesusAML, STC, AMR   Manchester  23  € 60.0M
# 298   Germany        Thomas MüllerMR, AMC, AMR, STC   Bayern Mun  30  € 50.0M
# 299     Italy                 Ciro ImmobileAMC, STC        Lazio  30  € 50.0M
#
#     Ove Att Def Tec Men Phy Spe
# ...

# %%
# %pylab inline
# %config InlineBackend.figure_formats = ['retina']

import pandas as pd
import seaborn as sns
sns.set()

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
# Out:
# Populating the interactive namespace from numpy and matplotlib
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magics\pylab.py:159: UserWarning: pylab import has clobbered these variables: ['table', 'title', 'randint', 'plot']
# `%matplotlib` prevents importing * from pylab and numpy
#   warn("pylab import has clobbered these variables: %s"  % clobbered +

# %%
df2 = df[:]

# %%
df2.set_index('Name')
# Out:
#                                   Nation dummy         Club Age    Value Ove  \
# Name
# Lionel MessiAMC, AMR, STC       Argentin         FC Barcelo  33  € 50.0M  16
# Cristiano RonaldoAML, STC, AMR  Portugal              Zebre  35  € 10.0M  15
# Kylian MbappéAML, AMR, STC        France         Paris Sain  21  € 90.0M  13
# NeymarML, AMC, AML, STC           Brazil         Paris Sain  28  € 90.0M  16
# Robert LewandowskiSTC             Poland         Bayern Mun  31  € 70.0M  15
# ...                                  ...   ...          ...  ..      ...  ..
# Mauro IcardiSTC                 Argentin         Paris Sain  27  € 50.0M  13
# Marcus RashfordAML, STC          England         Manchester  22  € 60.0M  14
# Gabriel JesusAML, STC, AMR        Brazil         Manchester  23  € 60.0M  13
# Thomas MüllerMR, AMC, AMR, STC   Germany         Bayern Mun  30  € 50.0M  14
# Ciro ImmobileAMC, STC              Italy              Lazio  30  € 50.0M  15
#
# ...

# %%
df2 = df2 ['Age','Value','Ove',]
