# %%
#İmport all required libaries first.

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn.model_selection import train_test_split, cross_val_score
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression, Ridge, Lasso, LassoCV, RidgeCV
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import KFold

# %%
df = pd.read_csv('stats_big5.txt',sep=";", index_col='PlayerName')

# %%
df.head()
# Out:
#                               Name Position   Age   Min  Goals  Goals.1  \
# PlayerName
# Aaron Connolly      Aaron Connolly       FW  19.0  1258      3     0.21
# Aaron Cresswell    Aaron Cresswell       DF  29.0  2727      3     0.10
# Aaron Leya Iseka  Aaron Leya Iseka       FW  21.0   777      2     0.23
# Aaron Ramsdale      Aaron Ramsdale       GK  21.0  3330      0     0.00
# Aaron Ramsey          Aaron Ramsey       MF  28.0  1051      3     0.26
#
#                   Asists  Asists.1  GoalAstPer90   90s  ...  SuccPressRatio  \
# PlayerName                                              ...
# Aaron Connolly         1      0.07          0.29  14.0  ...            29.5
# Aaron Cresswell        0      0.00          0.10  30.3  ...            33.2
# Aaron Leya Iseka       0      0.00          0.23   8.6  ...            20.4
# Aaron Ramsdale         1      0.03          0.03  37.0  ...            12.5
# Aaron Ramsey           1      0.09          0.34  11.7  ...            28.4
#
#                   MatchPlayed  PointPerMatch  TouchPenArea  SuccDrib  \
# PlayerName
# Aaron Connolly             24           1.13          61.0       6.0
# Aaron Cresswell            31           0.97          26.0      16.0
# Aaron Leya Iseka           22           0.27          39.0       7.0
# Aaron Ramsdale             37           0.92           0.0       0.0
# Aaron Ramsey               24           2.25          61.0      16.0
#
#                   DribLegs  PlayerType  Value  Value2  NetValue
# PlayerName
# Aaron Connolly         1.0     Forward    9.0       M       9.0
# Aaron Cresswell        2.0    Defender   10.0       M      10.0
# Aaron Leya Iseka       0.0     Forward  600.0       K     600.0
# Aaron Ramsdale         0.0  Goalkeeper   20.0       M      20.0
# Aaron Ramsey           0.0  Midfielder   20.0       M      20.0
#
# [5 rows x 41 columns]

# %%
def MorK(x):
    if(x['Value2']=='M'):
        return(1)
    else:
        return(0.001)
    
df['NetValue'] = df.apply(MorK, axis=1)
# Out:
# <ipython-input-86-137055ccce05>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NetValue'] = df.apply(MorK, axis=1)

# %%
df
# Out:
#                               Name Position   Age   Min  Goals  Goals.1  \
# PlayerName
# Aaron Connolly      Aaron Connolly       FW  19.0  1258      3     0.21
# Aaron Cresswell    Aaron Cresswell       DF  29.0  2727      3     0.10
# Aaron Leya Iseka  Aaron Leya Iseka       FW  21.0   777      2     0.23
# Aaron Ramsdale      Aaron Ramsdale       GK  21.0  3330      0     0.00
# Aaron Ramsey          Aaron Ramsey       MF  28.0  1051      3     0.26
# ...                            ...      ...   ...   ...    ...      ...
# Ángel Montoro        Ángel Montoro       MF  31.0   973      2     0.18
# Éder Militão          Éder Militão       DF  21.0  1022      0     0.00
# Édgar Méndez          Édgar Méndez       MF  29.0   864      1     0.10
# Óscar Plano            Óscar Plano       MF  28.0  2505      4     0.14
# Ömer Toprak            Ömer Toprak       DF  30.0   715      0     0.00
#
#                   Asists  Asists.1  GoalAstPer90   90s  ...  MatchPlayed  \
# PlayerName                                              ...
# Aaron Connolly         1      0.07          0.29  14.0  ...           24
# Aaron Cresswell        0      0.00          0.10  30.3  ...           31
# Aaron Leya Iseka       0      0.00          0.23   8.6  ...           22
# Aaron Ramsdale         1      0.03          0.03  37.0  ...           37
# Aaron Ramsey           1      0.09          0.34  11.7  ...           24
# ...                  ...       ...           ...   ...  ...          ...
# Ángel Montoro          5      0.46          0.65  10.8  ...           15
# Éder Militão           0      0.00          0.00  11.4  ...           15
# Édgar Méndez           0      0.00          0.10   9.6  ...           16
# Óscar Plano            2      0.07          0.22  27.8  ...           36
# Ömer Toprak            0      0.00          0.00   7.9  ...           10
#
#                   PointPerMatch  TouchPenArea  SuccDrib  DribLegs  PlayerType  \
# PlayerName
# Aaron Connolly             1.13          61.0       6.0       1.0     Forward
# Aaron Cresswell            0.97          26.0      16.0       2.0    Defender
# Aaron Leya Iseka           0.27          39.0       7.0       0.0     Forward
# Aaron Ramsdale             0.92           0.0       0.0       0.0  Goalkeeper
# Aaron Ramsey               2.25          61.0      16.0       0.0  Midfielder
# ...                         ...           ...       ...       ...         ...
# Ángel Montoro              1.60          13.0       6.0       2.0  Midfielder
# Éder Militão               2.33           4.0       1.0       0.0    Defender
# Édgar Méndez               0.94          17.0      12.0       1.0  Midfielder
# Óscar Plano                1.17          53.0      11.0       1.0  Midfielder
# Ömer Toprak                0.50           5.0       5.0       0.0    Defender
#
#                   Value  Value2  NetValue  logValue
# PlayerName
# Aaron Connolly      9.0       M     1.000  9.104980
# Aaron Cresswell    10.0       M     1.000  9.210340
# Aaron Leya Iseka  600.0       K     0.001  6.396930
# Aaron Ramsdale     20.0       M     1.000  9.903488
# Aaron Ramsey       20.0       M     1.000  9.903488
# ...                 ...     ...       ...       ...
# Ángel Montoro       2.0       M     1.000  7.600902
# Éder Militão       20.0       M     1.000  9.903488
# Édgar Méndez        6.0       M     1.000  8.699515
# Óscar Plano         2.0       M     1.000  7.600902
# Ömer Toprak         5.0       M     1.000  8.517193
#
# [1445 rows x 42 columns]

# %%
df['NetValue'] = df['Value']  * df['NetValue']
df
# Out:
# <ipython-input-88-057151d8aac6>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['NetValue'] = df['Value']  * df['NetValue']
#                               Name Position   Age   Min  Goals  Goals.1  \
# PlayerName
# Aaron Connolly      Aaron Connolly       FW  19.0  1258      3     0.21
# Aaron Cresswell    Aaron Cresswell       DF  29.0  2727      3     0.10
# Aaron Leya Iseka  Aaron Leya Iseka       FW  21.0   777      2     0.23
# Aaron Ramsdale      Aaron Ramsdale       GK  21.0  3330      0     0.00
# Aaron Ramsey          Aaron Ramsey       MF  28.0  1051      3     0.26
# ...                            ...      ...   ...   ...    ...      ...
# Ángel Montoro        Ángel Montoro       MF  31.0   973      2     0.18
# Éder Militão          Éder Militão       DF  21.0  1022      0     0.00
# Édgar Méndez          Édgar Méndez       MF  29.0   864      1     0.10
# Óscar Plano            Óscar Plano       MF  28.0  2505      4     0.14
# Ömer Toprak            Ömer Toprak       DF  30.0   715      0     0.00
#
#                   Asists  Asists.1  GoalAstPer90   90s  ...  MatchPlayed  \
# PlayerName                                              ...
# Aaron Connolly         1      0.07          0.29  14.0  ...           24
# Aaron Cresswell        0      0.00          0.10  30.3  ...           31
# Aaron Leya Iseka       0      0.00          0.23   8.6  ...           22
# Aaron Ramsdale         1      0.03          0.03  37.0  ...           37
# Aaron Ramsey           1      0.09          0.34  11.7  ...           24
# ...                  ...       ...           ...   ...  ...          ...
# Ángel Montoro          5      0.46          0.65  10.8  ...           15
# Éder Militão           0      0.00          0.00  11.4  ...           15
# Édgar Méndez           0      0.00          0.10   9.6  ...           16
# Óscar Plano            2      0.07          0.22  27.8  ...           36
# Ömer Toprak            0      0.00          0.00   7.9  ...           10
#
#                   PointPerMatch  TouchPenArea  SuccDrib  DribLegs  PlayerType  \
# PlayerName
# Aaron Connolly             1.13          61.0       6.0       1.0     Forward
# Aaron Cresswell            0.97          26.0      16.0       2.0    Defender
# Aaron Leya Iseka           0.27          39.0       7.0       0.0     Forward
# Aaron Ramsdale             0.92           0.0       0.0       0.0  Goalkeeper
# Aaron Ramsey               2.25          61.0      16.0       0.0  Midfielder
# ...                         ...           ...       ...       ...         ...
# Ángel Montoro              1.60          13.0       6.0       2.0  Midfielder
# Éder Militão               2.33           4.0       1.0       0.0    Defender
# Édgar Méndez               0.94          17.0      12.0       1.0  Midfielder
# Óscar Plano                1.17          53.0      11.0       1.0  Midfielder
# Ömer Toprak                0.50           5.0       5.0       0.0    Defender
#
#                   Value  Value2  NetValue  logValue
# PlayerName
# Aaron Connolly      9.0       M       9.0  9.104980
# Aaron Cresswell    10.0       M      10.0  9.210340
# Aaron Leya Iseka  600.0       K       0.6  6.396930
# Aaron Ramsdale     20.0       M      20.0  9.903488
# Aaron Ramsey       20.0       M      20.0  9.903488
# ...                 ...     ...       ...       ...
# Ángel Montoro       2.0       M       2.0  7.600902
# Éder Militão       20.0       M      20.0  9.903488
# Édgar Méndez        6.0       M       6.0  8.699515
# Óscar Plano         2.0       M       2.0  7.600902
# Ömer Toprak         5.0       M       5.0  8.517193
#
# [1445 rows x 42 columns]

# %%
df = df[df['NetValue']<100]
# Out:
#                             Name Position   Age   Min  Goals  Goals.1  Asists  \
# PlayerName
# Harry Kane            Harry Kane       FW  26.0  2587     18     0.63       2
# Kevin De Bruyne  Kevin De Bruyne       MF  28.0  2791     13     0.42      20
# Mohamed Salah      Mohamed Salah       FW  27.0  2876     19     0.59      10
# Sadio Mané            Sadio Mané       FW  27.0  2747     18     0.59       7
#
#                  Asists.1  GoalAstPer90   90s  ...  MatchPlayed  \
# PlayerName                                     ...
# Harry Kane           0.07          0.70  28.7  ...           29
# Kevin De Bruyne      0.64          1.06  31.0  ...           35
# Mohamed Salah        0.31          0.91  32.0  ...           34
# Sadio Mané           0.23          0.82  30.5  ...           35
#
#                  PointPerMatch  TouchPenArea  SuccDrib  DribLegs  PlayerType  \
# PlayerName
# Harry Kane                1.62         132.0      28.0       3.0     Forward
# Kevin De Bruyne           2.23         164.0      62.0       1.0  Midfielder
# Mohamed Salah             2.68         317.0      66.0       3.0     Forward
# Sadio Mané                2.57         219.0      76.0       6.0     Forward
#
#                  Value  Value2  NetValue   logValue
# PlayerName
# Harry Kane        90.0       M      90.0  11.407565
# Kevin De Bruyne   90.0       M      90.0  11.407565
# Mohamed Salah     90.0       M      90.0  11.407565
# Sadio Mané        90.0       M      90.0  11.407565
#
# [4 rows x 42 columns]

# %%
df["NetValue"].plot.hist(density=True, bins = 15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
np.log(df["NetValue"]).plot.hist(density=True, bins = 15)
# Out:
# <AxesSubplot:ylabel='Frequency'>

# %%
df['logValue'] = np.log(df['NetValue'])
# Out:
# <ipython-input-97-44b304ba703b>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['logValue'] = np.log(df['NetValue'])

# %%
df = df.fillna(0)
df_for = df[df['PlayerType']=='Forward']
df_mid = df[df['PlayerType']=='Midfielder']
df_def = df[df['PlayerType']=='Defender']

# %%
df_for.describe().T
# Out:
#                  count         mean          std        min          25%  \
# Age              322.0    25.065217     4.016954  17.000000    22.000000
# Min              322.0  1403.509317   878.119334   1.000000   670.500000
# Goals            322.0     5.419255     5.203761   0.000000     1.000000
# Goals.1          322.0     0.318975     0.302814   0.000000     0.140000
# Asists           322.0     2.142857     2.162718   0.000000     1.000000
# Asists.1         322.0     0.137500     0.155014   0.000000     0.026250
# GoalAstPer90     322.0     0.456475     0.335934   0.000000     0.270000
# 90s              322.0    15.594720     9.755804   0.000000     7.425000
# SCA              322.0    41.543478    31.032487   0.000000    19.000000
# SCA90            322.0     2.700326     1.362255   0.000000     1.930000
# ShootPass        322.0    27.854037    21.071022   0.000000    12.000000
# ShootDrib        322.0     4.484472     4.611520   0.000000     1.000000
# GCA              322.0     5.549689     4.680344   0.000000     2.000000
# GCA90            322.0     0.339876     0.264121   0.000000     0.190000
# AssistPass       322.0     3.229814     3.002073   0.000000     1.000000
# AssistDrib       322.0     0.683230     1.129731   0.000000     0.000000
# CompletedPasses  322.0   318.642857   240.172277   0.000000   132.000000
# PassCompRatio    322.0    72.262888     8.656044   0.000000    67.150000
# TotDistPass      322.0  5104.071429  4093.848694   0.000000  2022.250000
# ProgDistPass     322.0  1189.751553  1099.310801   0.000000   375.250000
# Crosses          322.0    20.791925    21.364735   0.000000     5.000000
# PenaltyWon       322.0     0.500000     0.825037   0.000000     0.000000
# AerialWonRate    322.0    33.521118    14.629893   0.000000    25.050000
# ShootOnTarget    322.0    14.658385    11.524108   0.000000     5.000000
# ShootPer90       322.0     2.523012     1.385084   0.000000     1.845000
# GoalPerShoot     322.0     0.117050     0.083247   0.000000     0.060000
# TacklesWon       322.0    10.006211     8.003891   0.000000     4.000000
# TklDribbling     322.0     4.245342     4.195985   0.000000     1.000000
# Blocks           322.0    16.139752    12.105290   0.000000     6.000000
# SuccPressRatio   322.0    26.020186     6.270999   0.000000    23.025000
# MatchPlayed      322.0    23.239130     9.964827   1.000000    17.000000
# PointPerMatch    322.0     1.365404     0.475385   0.000000     1.080000
# TouchPenArea     322.0    76.304348    57.086265   0.000000    33.000000
# SuccDrib         322.0    23.313665    20.912168   0.000000     8.000000
# DribLegs         322.0     1.434783     1.873849   0.000000     0.000000
# Value            322.0    38.903727   125.316099   1.000000     4.000000
# NetValue         322.0    13.153106    16.047927   0.300000     4.000000
# logValue         322.0     1.982790     1.133391  -1.203973     1.386294
#
#                          50%          75%          max
# Age                25.000000    28.000000     37.00000
# Min              1340.000000  2101.750000   3534.00000
# Goals               4.000000     8.000000     28.00000
# Goals.1             0.280000     0.440000      3.60000
# Asists              2.000000     3.000000     10.00000
# Asists.1            0.100000     0.200000      1.10000
# GoalAstPer90        0.420000     0.600000      3.60000
# 90s                14.900000    23.375000     39.20000
# SCA                35.000000    60.000000    186.00000
# SCA90               2.490000     3.290000     16.78500
# ShootPass          24.500000    40.750000    130.00000
# ShootDrib           3.000000     6.000000     28.00000
# GCA                 5.000000     8.000000     31.00000
# GCA90               0.310000     0.470000      2.12000
# AssistPass          3.000000     5.000000     17.00000
# AssistDrib          0.000000     1.000000      7.00000
# CompletedPasses   283.500000   445.000000   1262.00000
# PassCompRatio      72.600000    77.600000    100.00000
# TotDistPass      4422.500000  6954.750000  23156.00000
# ProgDistPass      842.500000  1701.250000   6423.00000
# Crosses            13.000000    30.000000    100.00000
# PenaltyWon          0.000000     1.000000      5.00000
# AerialWonRate      35.750000    42.550000     70.60000
# ShootOnTarget      13.000000    22.000000     59.00000
# ShootPer90          2.405000     2.937500     16.00000
# GoalPerShoot        0.110000     0.170000      0.50000
# TacklesWon          8.500000    14.000000     45.00000
# TklDribbling        3.000000     6.000000     22.00000
# Blocks             14.000000    24.000000     64.00000
# SuccPressRatio     26.000000    28.675000     66.70000
# MatchPlayed        24.000000    32.000000     54.00000
# PointPerMatch       1.335000     1.593750      3.00000
# TouchPenArea       65.500000   107.500000    317.00000
# SuccDrib           17.000000    31.750000    141.00000
# DribLegs            1.000000     2.000000     13.00000
# Value               8.000000    20.000000    900.00000
# NetValue            8.000000    20.000000     90.00000
# logValue            2.079442     2.995732      4.49981

# %%
sns.boxplot(x=df_for["NetValue"])
plt.xlim([0,100])
plt.title("Net Value")
# Out:
# Text(0.5, 1.0, 'Net Value')

# %%
sns.boxplot(x=df_for["Goals"])
plt.xlim([0,40])
plt.title("Goals")
# Out:
# Text(0.5, 1.0, 'Goals')

# %%
plt.figure(figsize=(20,20))
cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
ax = sns.scatterplot(x="TouchPenArea", y="Goals",
                     hue="ShootOnTarget", size ="ShootOnTarget",
                     palette=cmap, sizes=(10, 200),
                     data=df)
plt.xlabel("Touch in Penalty Area")
plt.ylabel("Goals")
# Out:
# Text(0, 0.5, 'Goals')

# %%
plt.figure(figsize=(20,20))
cmap = sns.cubehelix_palette(rot=-.2, as_cmap=True)
ax = sns.scatterplot(x="ShootOnTarget", y="Goals",
                     hue="TouchPenArea", size ="TouchPenArea",
                     palette=cmap, sizes=(10, 200),
                     data=df_for)
plt.xlabel("Touch in Penalty Area")
plt.ylabel("Goals")
# Out:
# Text(0, 0.5, 'Goals')

# %%
plt.figure(figsize=(25,20))
sns.heatmap(df_for.corr(),linewidths=.5, annot=True );
plt.yticks(rotation=360)
plt.show()

# %%
df_for.columns
# Out:
# Index(['Name', 'Position', 'Age', 'Min', 'Goals', 'Goals.1', 'Asists',
#        'Asists.1', 'GoalAstPer90', '90s', 'SCA', 'SCA90', 'ShootPass',
#        'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
#        'CompletedPasses', 'PassCompRatio', 'TotDistPass', 'ProgDistPass',
#        'Crosses', 'PenaltyWon', 'AerialWonRate', 'ShootOnTarget', 'ShootPer90',
#        'GoalPerShoot', 'TacklesWon', 'TklDribbling', 'Blocks',
#        'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
#        'SuccDrib', 'DribLegs', 'PlayerType', 'Value', 'Value2', 'NetValue',
#        'logValue'],
#       dtype='object')

# %%
df.reset_index()
# Out:
#             PlayerName              Name Position   Age   Min  Goals  Goals.1  \
# 0       Aaron Connolly    Aaron Connolly       FW  19.0  1258      3     0.21
# 1      Aaron Cresswell   Aaron Cresswell       DF  29.0  2727      3     0.10
# 2     Aaron Leya Iseka  Aaron Leya Iseka       FW  21.0   777      2     0.23
# 3       Aaron Ramsdale    Aaron Ramsdale       GK  21.0  3330      0     0.00
# 4         Aaron Ramsey      Aaron Ramsey       MF  28.0  1051      3     0.26
# ...                ...               ...      ...   ...   ...    ...      ...
# 1440     Ángel Montoro     Ángel Montoro       MF  31.0   973      2     0.18
# 1441      Éder Militão      Éder Militão       DF  21.0  1022      0     0.00
# 1442      Édgar Méndez      Édgar Méndez       MF  29.0   864      1     0.10
# 1443       Óscar Plano       Óscar Plano       MF  28.0  2505      4     0.14
# 1444       Ömer Toprak       Ömer Toprak       DF  30.0   715      0     0.00
#
#       Asists  Asists.1  GoalAstPer90  ...  MatchPlayed  PointPerMatch  \
# 0          1      0.07          0.29  ...           24           1.13
# 1          0      0.00          0.10  ...           31           0.97
# 2          0      0.00          0.23  ...           22           0.27
# 3          1      0.03          0.03  ...           37           0.92
# 4          1      0.09          0.34  ...           24           2.25
# ...      ...       ...           ...  ...          ...            ...
# 1440       5      0.46          0.65  ...           15           1.60
# 1441       0      0.00          0.00  ...           15           2.33
# 1442       0      0.00          0.10  ...           16           0.94
# 1443       2      0.07          0.22  ...           36           1.17
# 1444       0      0.00          0.00  ...           10           0.50
#
#       TouchPenArea  SuccDrib  DribLegs  PlayerType  Value  Value2  NetValue  \
# 0             61.0       6.0       1.0     Forward    9.0       M       9.0
# 1             26.0      16.0       2.0    Defender   10.0       M      10.0
# 2             39.0       7.0       0.0     Forward  600.0       K       0.6
# 3              0.0       0.0       0.0  Goalkeeper   20.0       M      20.0
# 4             61.0      16.0       0.0  Midfielder   20.0       M      20.0
# ...            ...       ...       ...         ...    ...     ...       ...
# 1440          13.0       6.0       2.0  Midfielder    2.0       M       2.0
# 1441           4.0       1.0       0.0    Defender   20.0       M      20.0
# 1442          17.0      12.0       1.0  Midfielder    6.0       M       6.0
# 1443          53.0      11.0       1.0  Midfielder    2.0       M       2.0
# 1444           5.0       5.0       0.0    Defender    5.0       M       5.0
#
#       logValue
# 0     2.197225
# 1     2.302585
# 2    -0.510826
# 3     2.995732
# 4     2.995732
# ...        ...
# 1440  0.693147
# 1441  2.995732
# 1442  1.791759
# 1443  0.693147
# 1444  1.609438
#
# [1445 rows x 43 columns]

# %%
df.columns = ['Name', 'Position', 'Age', 'Min', 'Goals', 'GoalsPer90', 'Asists',
       'AsistsPer90', 'GoalAstPer90', 'Played90s', 'SCA', 'SCA90', 'ShootPass',
       'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
       'CompletedPasses', 'PassCompRatio', 'TotDistPass', 'ProgDistPass',
       'Crosses', 'PenaltyWon', 'AerialWonRate', 'ShootOnTarget', 'ShootPer90',
       'GoalPerShoot', 'TacklesWon', 'TklDribbling', 'Blocks',
       'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
       'SuccDrib', 'DribLegs', 'PlayerType', 'Value', 'Value2', 'NetValue',
       'logValue']

# %%
df_for.corr()['NetValue']
# Out:
# Age               -0.025870
# Min                0.389326
# Goals              0.515423
# Goals.1            0.235053
# Asists             0.446123
# Asists.1           0.122700
# GoalAstPer90       0.269128
# 90s                0.389576
# SCA                0.500854
# SCA90              0.161752
# ShootPass          0.514621
# ShootDrib          0.435475
# GCA                0.508448
# GCA90              0.215766
# AssistPass         0.488797
# AssistDrib         0.335125
# CompletedPasses    0.505480
# PassCompRatio      0.189749
# TotDistPass        0.485807
# ProgDistPass       0.419506
# Crosses            0.311245
# PenaltyWon         0.249725
# AerialWonRate     -0.023857
# ShootOnTarget      0.501588
# ShootPer90         0.125942
# GoalPerShoot       0.214117
# TacklesWon         0.355246
# TklDribbling       0.266943
# Blocks             0.321075
# SuccPressRatio     0.109980
# MatchPlayed        0.336221
# PointPerMatch      0.438046
# TouchPenArea       0.567883
# SuccDrib           0.421929
# DribLegs           0.290002
# Value             -0.032543
# NetValue           1.000000
# logValue           0.818835
# Name: NetValue, dtype: float64

# %%
df_for.corr()['logValue']
# Out:
# Age               -0.091608
# Min                0.416936
# Goals              0.470494
# Goals.1            0.198683
# Asists             0.420009
# Asists.1           0.080507
# GoalAstPer90       0.216743
# 90s                0.417105
# SCA                0.481499
# SCA90              0.145689
# ShootPass          0.471243
# ShootDrib          0.431678
# GCA                0.467629
# GCA90              0.163677
# AssistPass         0.444605
# AssistDrib         0.306462
# CompletedPasses    0.469980
# PassCompRatio      0.130816
# TotDistPass        0.456988
# ProgDistPass       0.394796
# Crosses            0.329770
# PenaltyWon         0.196053
# AerialWonRate      0.023536
# ShootOnTarget      0.497174
# ShootPer90         0.108408
# GoalPerShoot       0.185969
# TacklesWon         0.356706
# TklDribbling       0.283493
# Blocks             0.364408
# SuccPressRatio     0.022462
# MatchPlayed        0.393931
# PointPerMatch      0.376293
# TouchPenArea       0.511713
# SuccDrib           0.415027
# DribLegs           0.288851
# Value             -0.342094
# NetValue           0.818835
# logValue           1.000000
# Name: logValue, dtype: float64

# %%
y, X = patsy.dmatrices('NetValue ~ Min + Goals +  Asists +   GoalAstPer90 +  SCA + SCA90 + ShootPass + ShootDrib + GCA + GCA90 + AssistPass + AssistDrib + CompletedPasses + PassCompRatio + TotDistPass + ProgDistPass + Crosses + PenaltyWon + AerialWonRate + ShootOnTarget + ShootPer90 + GoalPerShoot + TacklesWon + TklDribbling + Blocks + SuccPressRatio + MatchPlayed + PointPerMatch + TouchPenArea + SuccDrib + DribLegs', data=df, return_type="dataframe")
model = sm.OLS(y, X)
fit = model.fit()
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               NetValue   R-squared:                       0.374
# Model:                            OLS   Adj. R-squared:                  0.360
# Method:                 Least Squares   F-statistic:                     27.21
# Date:                Sat, 02 Jan 2021   Prob (F-statistic):          1.06e-120
# Time:                        23:24:27   Log-Likelihood:                -5377.1
# No. Observations:                1445   AIC:                         1.082e+04
# Df Residuals:                    1413   BIC:                         1.099e+04
# Df Model:                          31
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          -5.4372      2.874     -1.892      0.059     -11.075       0.201
# Min                -0.0032      0.001     -2.274      0.023      -0.006      -0.000
# Goals               0.4448      0.219      2.028      0.043       0.015       0.875
# Asists              0.8591      0.321      2.678      0.008       0.230       1.489
# GoalAstPer90        0.0411      1.959      0.021      0.983      -3.801       3.883
# SCA                -0.0858      0.058     -1.477      0.140      -0.200       0.028
# SCA90              -0.2845      0.419     -0.679      0.497      -1.106       0.537
# ShootPass           0.1018      0.077      1.327      0.185      -0.049       0.252
# ShootDrib           0.2448      0.201      1.219      0.223      -0.149       0.639
# GCA                 0.1719      0.343      0.501      0.616      -0.501       0.845
# GCA90               0.1774      2.123      0.084      0.933      -3.987       4.341
# AssistPass         -0.3173      0.380     -0.836      0.404      -1.062       0.428
# AssistDrib         -0.8117      0.627     -1.295      0.195      -2.041       0.418
# CompletedPasses    -0.0015      0.004     -0.346      0.729      -0.010       0.007
# PassCompRatio       0.0402      0.036      1.111      0.267      -0.031       0.111
# TotDistPass         0.0006      0.000      2.894      0.004       0.000       0.001
# ProgDistPass        0.0002      0.000      0.983      0.326      -0.000       0.001
# Crosses            -0.0266      0.019     -1.386      0.166      -0.064       0.011
# PenaltyWon         -0.8294      0.600     -1.383      0.167      -2.006       0.347
# AerialWonRate      -0.0119      0.015     -0.781      0.435      -0.042       0.018
# ShootOnTarget      -0.2094      0.107     -1.958      0.050      -0.419       0.000
# ShootPer90          0.0475      0.396      0.120      0.905      -0.730       0.825
# GoalPerShoot        2.5408      3.391      0.749      0.454      -4.112       9.194
# TacklesWon          0.1235      0.051      2.437      0.015       0.024       0.223
# TklDribbling       -0.1755      0.077     -2.280      0.023      -0.326      -0.025
# Blocks             -0.0820      0.030     -2.743      0.006      -0.141      -0.023
# SuccPressRatio      0.0118      0.026      0.452      0.651      -0.039       0.063
# MatchPlayed        -0.0692      0.083     -0.833      0.405      -0.232       0.094
# PointPerMatch       5.2719      0.595      8.860      0.000       4.105       6.439
# TouchPenArea        0.1476      0.020      7.376      0.000       0.108       0.187
# SuccDrib            0.0656      0.036      1.831      0.067      -0.005       0.136
# DribLegs            0.3550      0.234      1.519      0.129      -0.104       0.814
# ==============================================================================
# Omnibus:                      443.418   Durbin-Watson:                   1.889
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             1766.242
# Skew:                           1.434   Prob(JB):                         0.00
# Kurtosis:                       7.595   Cond. No.                     2.18e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.18e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
y, X = patsy.dmatrices('NetValue ~ Min + Goals +  Asists +   GoalAstPer90 +  SCA + SCA90 + ShootPass + ShootDrib + GCA + GCA90 + AssistPass + AssistDrib + CompletedPasses + PassCompRatio + TotDistPass + ProgDistPass + Crosses + PenaltyWon + AerialWonRate + ShootOnTarget + ShootPer90 + GoalPerShoot + TacklesWon + TklDribbling + Blocks + SuccPressRatio + MatchPlayed + PointPerMatch + TouchPenArea + SuccDrib + DribLegs', data=df_for, return_type="dataframe")
model = sm.OLS(y, X)
fit = model.fit()
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               NetValue   R-squared:                       0.593
# Model:                            OLS   Adj. R-squared:                  0.550
# Method:                 Least Squares   F-statistic:                     13.63
# Date:                Sat, 02 Jan 2021   Prob (F-statistic):           1.85e-40
# Time:                        23:25:00   Log-Likelihood:                -1205.4
# No. Observations:                 322   AIC:                             2475.
# Df Residuals:                     290   BIC:                             2596.
# Df Model:                          31
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept         -15.3428      7.432     -2.064      0.040     -29.971      -0.715
# Min                -0.0154      0.003     -5.199      0.000      -0.021      -0.010
# Goals               0.9399      0.362      2.596      0.010       0.227       1.652
# Asists             -0.0035      0.629     -0.006      0.996      -1.242       1.235
# GoalAstPer90       -1.7818      2.632     -0.677      0.499      -6.963       3.399
# SCA                -0.0758      0.160     -0.473      0.636      -0.391       0.239
# SCA90              -2.0042      0.761     -2.634      0.009      -3.502      -0.507
# ShootPass          -0.0917      0.201     -0.457      0.648      -0.487       0.304
# ShootDrib           0.3480      0.379      0.917      0.360      -0.399       1.094
# GCA                -0.1106      0.614     -0.180      0.857      -1.319       1.098
# GCA90               1.2877      3.429      0.375      0.708      -5.462       8.037
# AssistPass          0.0559      0.756      0.074      0.941      -1.433       1.544
# AssistDrib         -0.6344      1.008     -0.629      0.530      -2.619       1.350
# CompletedPasses    -0.0327      0.024     -1.335      0.183      -0.081       0.015
# PassCompRatio       0.2019      0.089      2.280      0.023       0.028       0.376
# TotDistPass         0.0026      0.002      1.725      0.086      -0.000       0.006
# ProgDistPass        0.0077      0.002      3.188      0.002       0.003       0.013
# Crosses            -0.1089      0.056     -1.959      0.051      -0.218       0.001
# PenaltyWon         -1.2437      0.937     -1.327      0.186      -3.088       0.601
# AerialWonRate      -0.0542      0.047     -1.161      0.246      -0.146       0.038
# ShootOnTarget      -0.1827      0.176     -1.038      0.300      -0.529       0.164
# ShootPer90         -0.1397      0.590     -0.237      0.813      -1.301       1.021
# GoalPerShoot        7.5847     10.200      0.744      0.458     -12.491      27.660
# TacklesWon          0.3745      0.160      2.335      0.020       0.059       0.690
# TklDribbling       -0.5177      0.289     -1.789      0.075      -1.087       0.052
# Blocks              0.0597      0.103      0.579      0.563      -0.143       0.263
# SuccPressRatio      0.0468      0.103      0.454      0.650      -0.156       0.250
# MatchPlayed        -0.0126      0.152     -0.083      0.934      -0.311       0.286
# PointPerMatch       8.2599      1.579      5.231      0.000       5.152      11.368
# TouchPenArea        0.2811      0.039      7.170      0.000       0.204       0.358
# SuccDrib           -0.0441      0.082     -0.541      0.589      -0.205       0.116
# DribLegs            0.6751      0.481      1.404      0.161      -0.271       1.621
# ==============================================================================
# Omnibus:                       88.599   Durbin-Watson:                   2.061
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              293.098
# Skew:                           1.192   Prob(JB):                     2.26e-64
# Kurtosis:                       7.020   Cond. No.                     1.18e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.18e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
y, X = patsy.dmatrices('NetValue ~ Min + Goals +  Asists +   GoalAstPer90 +  SCA + SCA90 + ShootPass + ShootDrib + GCA + GCA90 + AssistPass + AssistDrib + CompletedPasses + PassCompRatio + TotDistPass + ProgDistPass + Crosses + PenaltyWon + AerialWonRate + ShootOnTarget + ShootPer90 + GoalPerShoot + TacklesWon + TklDribbling + Blocks + SuccPressRatio + MatchPlayed + PointPerMatch + TouchPenArea + SuccDrib + DribLegs', data=df_mid, return_type="dataframe")
model = sm.OLS(y, X)
fit = model.fit()
fit.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:               NetValue   R-squared:                       0.363
# Model:                            OLS   Adj. R-squared:                  0.315
# Method:                 Least Squares   F-statistic:                     7.571
# Date:                Sat, 02 Jan 2021   Prob (F-statistic):           3.95e-25
# Time:                        23:26:01   Log-Likelihood:                -1655.2
# No. Observations:                 444   AIC:                             3374.
# Df Residuals:                     412   BIC:                             3505.
# Df Model:                          31
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Intercept          -6.2914      6.956     -0.904      0.366     -19.965       7.382
# Min                -0.0046      0.003     -1.600      0.110      -0.010       0.001
# Goals              -0.3101      0.412     -0.752      0.453      -1.121       0.501
# Asists              0.6896      0.633      1.089      0.277      -0.555       1.934
# GoalAstPer90       -0.6439      6.776     -0.095      0.924     -13.964      12.676
# SCA                -0.2016      0.091     -2.211      0.028      -0.381      -0.022
# SCA90              -0.2974      0.781     -0.381      0.704      -1.833       1.238
# ShootPass           0.1825      0.119      1.534      0.126      -0.051       0.416
# ShootDrib           0.1695      0.363      0.467      0.641      -0.544       0.883
# GCA                 0.0348      0.602      0.058      0.954      -1.148       1.218
# GCA90               1.5570      4.146      0.376      0.707      -6.592       9.706
# AssistPass         -0.3585      0.629     -0.570      0.569      -1.594       0.877
# AssistDrib         -0.1286      1.203     -0.107      0.915      -2.494       2.236
# CompletedPasses    -0.0099      0.010     -0.963      0.336      -0.030       0.010
# PassCompRatio      -0.0056      0.076     -0.074      0.941      -0.155       0.144
# TotDistPass         0.0012      0.001      2.289      0.023       0.000       0.002
# ProgDistPass        0.0011      0.001      1.137      0.256      -0.001       0.003
# Crosses             0.0333      0.044      0.753      0.452      -0.054       0.120
# PenaltyWon         -0.5730      1.110     -0.516      0.606      -2.754       1.608
# AerialWonRate       0.0064      0.033      0.195      0.845      -0.058       0.071
# ShootOnTarget      -0.0488      0.197     -0.248      0.804      -0.436       0.338
# ShootPer90          0.9066      0.960      0.945      0.345      -0.980       2.794
# GoalPerShoot       16.7464      9.704      1.726      0.085      -2.329      35.822
# TacklesWon          0.0891      0.086      1.033      0.302      -0.080       0.259
# TklDribbling       -0.1460      0.142     -1.030      0.304      -0.425       0.133
# Blocks             -0.0670      0.065     -1.029      0.304      -0.195       0.061
# SuccPressRatio      0.0913      0.086      1.060      0.290      -0.078       0.261
# MatchPlayed        -0.0732      0.148     -0.495      0.621      -0.364       0.217
# PointPerMatch       5.5648      1.264      4.401      0.000       3.079       8.050
# TouchPenArea        0.1909      0.043      4.489      0.000       0.107       0.275
# SuccDrib            0.0483      0.058      0.837      0.403      -0.065       0.162
# DribLegs            0.4411      0.394      1.119      0.264      -0.333       1.216
# ==============================================================================
# Omnibus:                      136.435   Durbin-Watson:                   2.049
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              435.260
# Skew:                           1.414   Prob(JB):                     3.05e-95
# Kurtosis:                       6.941   Cond. No.                     3.57e+05
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.57e+05. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
df_for.reset_index()
# Out:
#             PlayerName               Name Position   Age   Min  Goals  \
# 0       Aaron Connolly     Aaron Connolly       FW  19.0  1258      3
# 1     Aaron Leya Iseka   Aaron Leya Iseka       FW  21.0   777      2
# 2        Adnan Januzaj      Adnan Januzaj       FW  24.0  1167      3
# 3         Adrien Hunou       Adrien Hunou       FW  25.0  1210      8
# 4         Ahmed Kutucu       Ahmed Kutucu       FW  19.0   679      3
# ..                 ...                ...      ...   ...   ...    ...
# 317       Yann Karamoh       Yann Karamoh       FW  21.0   573      1
# 318  Youssef En-Nesyri  Youssef En-Nesyri       FW  22.0  2181      8
# 319     Yussuf Poulsen     Yussuf Poulsen       FW  25.0  1222      5
# 320    Zinedine Ferhat    Zinedine Ferhat       FW  26.0  2246      3
# 321        Ádám Szalai        Ádám Szalai       FW  31.0  1147      1
#
#      Goals.1  Asists  Asists.1  GoalAstPer90  ...  MatchPlayed  PointPerMatch  \
# 0      0.210       1     0.070          0.29  ...           24          1.130
# 1      0.230       0     0.000          0.23  ...           22          0.270
# 2      0.230       3     0.230          0.46  ...           24          1.460
# 3      0.600       1     0.070          0.67  ...           23          1.740
# 4      0.400       2     0.270          0.66  ...           25          0.920
# ..       ...     ...       ...           ...  ...          ...            ...
# 317    0.160       1     0.160          0.31  ...           14          0.430
# 318    0.355       2     0.065          0.42  ...           36          1.195
# 319    0.370       6     0.440          0.81  ...           22          1.770
# 320    0.120       4     0.160          0.28  ...           26          0.960
# 321    0.080       1     0.080          0.16  ...           27          1.220
#
#      TouchPenArea  SuccDrib  DribLegs  PlayerType  Value  Value2  NetValue  \
# 0            61.0       6.0       1.0     Forward    9.0       M       9.0
# 1            39.0       7.0       0.0     Forward  600.0       K       0.6
# 2            44.0      34.0       3.0     Forward   20.0       M      20.0
# 3            57.0      12.0       0.0     Forward    7.0       M       7.0
# 4            21.0      21.0       1.0     Forward    1.0       M       1.0
# ..            ...       ...       ...         ...    ...     ...       ...
# 317          19.0      15.0       2.0     Forward    4.0       M       4.0
# 318         114.0      23.0       3.0     Forward   10.0       M      10.0
# 319          79.0      13.0       0.0     Forward   20.0       M      20.0
# 320          85.0      54.0       3.0     Forward    6.0       M       6.0
# 321          83.0      14.0       1.0     Forward    1.0       M       1.0
#
#      logValue
# 0    2.197225
# 1   -0.510826
# 2    2.995732
# 3    1.945910
# 4    0.000000
# ..        ...
# 317  1.386294
# 318  2.302585
# 319  2.995732
# 320  1.791759
# 321  0.000000
#
# [322 rows x 43 columns]

# %%
# Out:
#                               Name Position   Age   Min  Goals  GoalsPer90  \
# PlayerName
# Aaron Connolly      Aaron Connolly       FW  19.0  1258      3        0.21
# Aaron Cresswell    Aaron Cresswell       DF  29.0  2727      3        0.10
# Aaron Leya Iseka  Aaron Leya Iseka       FW  21.0   777      2        0.23
# Aaron Ramsdale      Aaron Ramsdale       GK  21.0  3330      0        0.00
# Aaron Ramsey          Aaron Ramsey       MF  28.0  1051      3        0.26
# ...                            ...      ...   ...   ...    ...         ...
# Ángel Montoro        Ángel Montoro       MF  31.0   973      2        0.18
# Éder Militão          Éder Militão       DF  21.0  1022      0        0.00
# Édgar Méndez          Édgar Méndez       MF  29.0   864      1        0.10
# Óscar Plano            Óscar Plano       MF  28.0  2505      4        0.14
# Ömer Toprak            Ömer Toprak       DF  30.0   715      0        0.00
#
#                   Asists  AsistsPer90  GoalAstPer90  Played90s  ...  \
# PlayerName                                                      ...
# Aaron Connolly         1         0.07          0.29       14.0  ...
# Aaron Cresswell        0         0.00          0.10       30.3  ...
# Aaron Leya Iseka       0         0.00          0.23        8.6  ...
# Aaron Ramsdale         1         0.03          0.03       37.0  ...
# Aaron Ramsey           1         0.09          0.34       11.7  ...
# ...                  ...          ...           ...        ...  ...
# Ángel Montoro          5         0.46          0.65       10.8  ...
# Éder Militão           0         0.00          0.00       11.4  ...
# Édgar Méndez           0         0.00          0.10        9.6  ...
# Óscar Plano            2         0.07          0.22       27.8  ...
# Ömer Toprak            0         0.00          0.00        7.9  ...
#
#                   MatchPlayed  PointPerMatch  TouchPenArea  SuccDrib  \
# PlayerName
# Aaron Connolly             24           1.13          61.0       6.0
# Aaron Cresswell            31           0.97          26.0      16.0
# Aaron Leya Iseka           22           0.27          39.0       7.0
# Aaron Ramsdale             37           0.92           0.0       0.0
# Aaron Ramsey               24           2.25          61.0      16.0
# ...                       ...            ...           ...       ...
# Ángel Montoro              15           1.60          13.0       6.0
# Éder Militão               15           2.33           4.0       1.0
# Édgar Méndez               16           0.94          17.0      12.0
# Óscar Plano                36           1.17          53.0      11.0
# Ömer Toprak                10           0.50           5.0       5.0
#
#                   DribLegs  PlayerType  Value  Value2  NetValue  logValue
# PlayerName
# Aaron Connolly         1.0     Forward    9.0       M       9.0  2.197225
# Aaron Cresswell        2.0    Defender   10.0       M      10.0  2.302585
# Aaron Leya Iseka       0.0     Forward  600.0       K       0.6 -0.510826
# Aaron Ramsdale         0.0  Goalkeeper   20.0       M      20.0  2.995732
# Aaron Ramsey           0.0  Midfielder   20.0       M      20.0  2.995732
# ...                    ...         ...    ...     ...       ...       ...
# Ángel Montoro          2.0  Midfielder    2.0       M       2.0  0.693147
# Éder Militão           0.0    Defender   20.0       M      20.0  2.995732
# Édgar Méndez           1.0  Midfielder    6.0       M       6.0  1.791759
# Óscar Plano            1.0  Midfielder    2.0       M       2.0  0.693147
# Ömer Toprak            0.0    Defender    5.0       M       5.0  1.609438
#
# [1445 rows x 42 columns]

# %%
x_features = ['Age', 'Min', 'Goals', 'GoalsPer90', 'Asists',
       'AsistsPer90', 'GoalAstPer90', 'Played90s', 'SCA', 'SCA90', 'ShootPass',
       'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
       'CompletedPasses', 'PassCompRatio', 'TotDistPass', 'ProgDistPass',
       'Crosses', 'PenaltyWon', 'AerialWonRate', 'ShootOnTarget', 'ShootPer90',
       'GoalPerShoot', 'TacklesWon', 'TklDribbling', 'Blocks',
       'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
       'SuccDrib', 'DribLegs'] 

X = df_for.reindex(columns=x_features)

y = df_for.loc[:,"NetValue"]

model = sm.OLS(y, X, data=df_for)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               NetValue   R-squared (uncentered):                   0.766
# Model:                            OLS   Adj. R-squared (uncentered):              0.737
# Method:                 Least Squares   F-statistic:                              26.79
# Date:                Sat, 02 Jan 2021   Prob (F-statistic):                    5.79e-71
# Time:                        23:37:31   Log-Likelihood:                         -1199.5
# No. Observations:                 322   AIC:                                      2469.
# Df Residuals:                     287   BIC:                                      2601.
# Df Model:                          35
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Age                -0.5379      0.144     -3.729      0.000      -0.822      -0.254
# Min                -0.2045      0.235     -0.869      0.386      -0.668       0.259
# Goals               0.9661      0.357      2.709      0.007       0.264       1.668
# GoalsPer90         61.0408    156.460      0.390      0.697    -246.913     368.995
# Asists              0.2670      0.746      0.358      0.721      -1.202       1.736
# AsistsPer90        54.5405    156.072      0.349      0.727    -252.651     361.732
# GoalAstPer90      -61.6833    156.499     -0.394      0.694    -369.714     246.348
# Played90s          17.0910     21.183      0.807      0.420     -24.602      58.784
# SCA                -0.0962      0.159     -0.606      0.545      -0.409       0.216
# SCA90              -1.8980      0.771     -2.462      0.014      -3.415      -0.381
# ShootPass          -0.0675      0.199     -0.339      0.735      -0.460       0.325
# ShootDrib           0.4318      0.375      1.153      0.250      -0.306       1.169
# GCA                -0.0948      0.630     -0.150      0.881      -1.335       1.146
# GCA90               2.8981      3.961      0.732      0.465      -4.899      10.695
# AssistPass          0.0239      0.758      0.032      0.975      -1.467       1.515
# AssistDrib         -0.6781      0.997     -0.680      0.497      -2.641       1.285
# CompletedPasses    -0.0275      0.024     -1.159      0.248      -0.074       0.019
# PassCompRatio       0.1695      0.059      2.878      0.004       0.054       0.285
# TotDistPass         0.0024      0.001      1.586      0.114      -0.001       0.005
# ProgDistPass        0.0081      0.002      3.375      0.001       0.003       0.013
# Crosses            -0.1108      0.055     -2.020      0.044      -0.219      -0.003
# PenaltyWon         -1.3810      0.930     -1.485      0.139      -3.211       0.449
# AerialWonRate      -0.0401      0.045     -0.886      0.376      -0.129       0.049
# ShootOnTarget      -0.2333      0.175     -1.332      0.184      -0.578       0.111
# ShootPer90         -0.1849      0.607     -0.305      0.761      -1.379       1.009
# GoalPerShoot        4.6047     10.166      0.453      0.651     -15.405      24.615
# TacklesWon          0.3918      0.159      2.468      0.014       0.079       0.704
# TklDribbling       -0.5917      0.287     -2.065      0.040      -1.156      -0.028
# Blocks              0.0439      0.102      0.431      0.667      -0.157       0.245
# SuccPressRatio      0.0430      0.101      0.426      0.670      -0.156       0.242
# MatchPlayed        -0.0174      0.150     -0.116      0.908      -0.313       0.278
# PointPerMatch       7.8846      1.499      5.261      0.000       4.935      10.834
# TouchPenArea        0.2865      0.039      7.338      0.000       0.210       0.363
# SuccDrib           -0.0988      0.082     -1.208      0.228      -0.260       0.062
# DribLegs            0.6632      0.476      1.393      0.165      -0.274       1.600
# ==============================================================================
# Omnibus:                      100.546   Durbin-Watson:                   2.088
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              377.533
# Skew:                           1.314   Prob(JB):                     1.05e-82
# Kurtosis:                       7.608   Cond. No.                     3.16e+06
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 3.16e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x_features = ['Age', 'Min', 'Goals', 'GoalsPer90', 'Asists',
       'AsistsPer90', 'GoalAstPer90', 'Played90s', 'SCA', 'SCA90', 'ShootPass',
       'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
       'CompletedPasses', 'PassCompRatio', 'TotDistPass', 'ProgDistPass',
       'Crosses', 'PenaltyWon', 'AerialWonRate', 'ShootOnTarget', 'ShootPer90',
       'GoalPerShoot', 'TacklesWon', 'TklDribbling', 'Blocks',
       'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
       'SuccDrib', 'DribLegs'] 

X = df_mid.reindex(columns=x_features)

y = df_mid.loc[:,"NetValue"]

model = sm.OLS(y, X, data=df_for)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               NetValue   R-squared (uncentered):                   0.661
# Model:                            OLS   Adj. R-squared (uncentered):              0.632
# Method:                 Least Squares   F-statistic:                              22.75
# Date:                Sat, 02 Jan 2021   Prob (F-statistic):                    3.58e-75
# Time:                        23:37:33   Log-Likelihood:                         -1651.0
# No. Observations:                 444   AIC:                                      3372.
# Df Residuals:                     409   BIC:                                      3515.
# Df Model:                          35
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Age                -0.3705      0.131     -2.825      0.005      -0.628      -0.113
# Min                -0.0876      0.189     -0.463      0.644      -0.460       0.285
# Goals              -0.1696      0.438     -0.387      0.699      -1.031       0.692
# GoalsPer90        -50.6277    130.051     -0.389      0.697    -306.279     205.023
# Asists              0.6747      0.760      0.887      0.375      -0.820       2.170
# AsistsPer90       -47.7781    129.466     -0.369      0.712    -302.281     206.725
# GoalAstPer90       48.8861    129.611      0.377      0.706    -205.902     303.674
# Played90s           7.4592     17.039      0.438      0.662     -26.035      40.953
# SCA                -0.1956      0.091     -2.148      0.032      -0.375      -0.017
# SCA90              -0.1784      0.780     -0.229      0.819      -1.712       1.355
# ShootPass           0.1688      0.119      1.423      0.156      -0.064       0.402
# ShootDrib           0.2001      0.362      0.553      0.581      -0.511       0.912
# GCA                 0.0497      0.634      0.078      0.938      -1.198       1.297
# GCA90               0.2273      5.249      0.043      0.965     -10.092      10.547
# AssistPass         -0.3465      0.627     -0.553      0.581      -1.579       0.886
# AssistDrib         -0.2471      1.205     -0.205      0.838      -2.617       2.123
# CompletedPasses    -0.0087      0.010     -0.860      0.390      -0.029       0.011
# PassCompRatio       0.0167      0.049      0.341      0.733      -0.079       0.113
# TotDistPass         0.0011      0.001      2.136      0.033    8.62e-05       0.002
# ProgDistPass        0.0012      0.001      1.245      0.214      -0.001       0.003
# Crosses             0.0416      0.044      0.949      0.343      -0.045       0.128
# PenaltyWon         -0.4157      1.106     -0.376      0.707      -2.590       1.759
# AerialWonRate       0.0163      0.033      0.500      0.618      -0.048       0.081
# ShootOnTarget      -0.1176      0.198     -0.594      0.553      -0.507       0.272
# ShootPer90          0.7835      1.036      0.756      0.450      -1.254       2.821
# GoalPerShoot       18.9362     12.029      1.574      0.116      -4.710      42.582
# TacklesWon          0.0574      0.086      0.666      0.506      -0.112       0.227
# TklDribbling       -0.0997      0.142     -0.702      0.483      -0.379       0.180
# Blocks             -0.0623      0.065     -0.961      0.337      -0.190       0.065
# SuccPressRatio      0.1087      0.070      1.556      0.120      -0.029       0.246
# MatchPlayed        -0.0372      0.148     -0.251      0.802      -0.329       0.255
# PointPerMatch       5.4608      1.260      4.334      0.000       2.984       7.938
# TouchPenArea        0.1956      0.042      4.621      0.000       0.112       0.279
# SuccDrib            0.0308      0.058      0.533      0.595      -0.083       0.144
# DribLegs            0.4399      0.392      1.122      0.263      -0.331       1.211
# ==============================================================================
# Omnibus:                      141.382   Durbin-Watson:                   2.052
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              477.186
# Skew:                           1.444   Prob(JB):                    2.40e-104
# Kurtosis:                       7.177   Cond. No.                     7.09e+06
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 7.09e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x_features = ['Age', 'Min', 'Goals', 'GoalsPer90', 'Asists',
       'AsistsPer90', 'GoalAstPer90', 'Played90s', 'SCA', 'SCA90', 'ShootPass',
       'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
       'CompletedPasses', 'PassCompRatio', 'TotDistPass', 'ProgDistPass',
       'Crosses', 'PenaltyWon', 'AerialWonRate', 'ShootOnTarget', 'ShootPer90',
       'GoalPerShoot', 'TacklesWon', 'TklDribbling', 'Blocks',
       'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
       'SuccDrib', 'DribLegs'] 

X = df_def.reindex(columns=x_features)

y = df_def.loc[:,"NetValue"]

model = sm.OLS(y, X, data=df_for)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               NetValue   R-squared (uncentered):                   0.664
# Model:                            OLS   Adj. R-squared (uncentered):              0.641
# Method:                 Least Squares   F-statistic:                              29.59
# Date:                Sat, 02 Jan 2021   Prob (F-statistic):                   1.23e-101
# Time:                        23:37:35   Log-Likelihood:                         -1959.5
# No. Observations:                 560   AIC:                                      3989.
# Df Residuals:                     525   BIC:                                      4140.
# Df Model:                          35
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Age                -0.4301      0.089     -4.838      0.000      -0.605      -0.255
# Min                -0.2110      0.143     -1.474      0.141      -0.492       0.070
# Goals              -0.2126      0.590     -0.360      0.719      -1.372       0.947
# GoalsPer90         29.9001    121.272      0.247      0.805    -208.338     268.139
# Asists              0.3724      0.684      0.545      0.586      -0.971       1.715
# AsistsPer90        36.5388    121.481      0.301      0.764    -202.110     275.187
# GoalAstPer90      -31.6533    120.678     -0.262      0.793    -268.725     205.418
# Played90s          18.9758     12.875      1.474      0.141      -6.317      44.268
# SCA                -0.1294      0.109     -1.182      0.238      -0.344       0.086
# SCA90               1.5714      0.977      1.609      0.108      -0.347       3.490
# ShootPass          -0.1294      0.130     -0.992      0.322      -0.386       0.127
# ShootDrib           0.6701      0.430      1.557      0.120      -0.175       1.515
# GCA                 1.5456      0.665      2.322      0.021       0.238       2.853
# GCA90              -9.8177      6.774     -1.449      0.148     -23.126       3.490
# AssistPass         -0.8641      0.660     -1.309      0.191      -2.161       0.433
# AssistDrib         -2.8133      1.361     -2.067      0.039      -5.487      -0.140
# CompletedPasses     0.0132      0.005      2.478      0.014       0.003       0.024
# PassCompRatio       0.0575      0.037      1.555      0.121      -0.015       0.130
# TotDistPass         0.0002      0.000      0.800      0.424      -0.000       0.001
# ProgDistPass       -0.0009      0.000     -1.778      0.076      -0.002    8.93e-05
# Crosses             0.0260      0.031      0.842      0.400      -0.035       0.087
# PenaltyWon         -3.8799      1.373     -2.826      0.005      -6.577      -1.183
# AerialWonRate       0.0731      0.024      3.078      0.002       0.026       0.120
# ShootOnTarget      -0.2438      0.243     -1.005      0.316      -0.721       0.233
# ShootPer90         -0.2136      1.279     -0.167      0.867      -2.726       2.299
# GoalPerShoot        4.9697      4.437      1.120      0.263      -3.746      13.686
# TacklesWon         -0.0460      0.072     -0.643      0.520      -0.187       0.095
# TklDribbling       -0.1018      0.092     -1.109      0.268      -0.282       0.079
# Blocks             -0.0113      0.041     -0.278      0.781      -0.091       0.068
# SuccPressRatio      0.0106      0.059      0.181      0.856      -0.105       0.126
# MatchPlayed        -0.1571      0.180     -0.872      0.383      -0.511       0.197
# PointPerMatch       3.7693      0.813      4.636      0.000       2.172       5.366
# TouchPenArea        0.1886      0.043      4.359      0.000       0.104       0.274
# SuccDrib            0.0489      0.059      0.824      0.411      -0.068       0.166
# DribLegs            0.2230      0.373      0.598      0.550      -0.509       0.955
# ==============================================================================
# Omnibus:                      166.426   Durbin-Watson:                   1.813
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              655.906
# Skew:                           1.312   Prob(JB):                    3.73e-143
# Kurtosis:                       7.607   Cond. No.                     1.20e+07
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.2e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
# now i just re-run ols for def- mid and for with log of the value

# %%
x_features = ['Age', 'Min', 'Goals', 'GoalsPer90', 'Asists',
       'AsistsPer90', 'GoalAstPer90', 'Played90s', 'SCA', 'SCA90', 'ShootPass',
       'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
       'CompletedPasses', 'PassCompRatio', 'TotDistPass', 'ProgDistPass',
       'Crosses', 'PenaltyWon', 'AerialWonRate', 'ShootOnTarget', 'ShootPer90',
       'GoalPerShoot', 'TacklesWon', 'TklDribbling', 'Blocks',
       'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
       'SuccDrib', 'DribLegs'] 

X = df_for.reindex(columns=x_features)

y = df_for.loc[:,"logValue"]

model = sm.OLS(y, X, data=df_for)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               logValue   R-squared (uncentered):                   0.867
# Model:                            OLS   Adj. R-squared (uncentered):              0.851
# Method:                 Least Squares   F-statistic:                              53.35
# Date:                Sat, 02 Jan 2021   Prob (F-statistic):                   2.75e-105
# Time:                        23:36:58   Log-Likelihood:                         -398.18
# No. Observations:                 322   AIC:                                      866.4
# Df Residuals:                     287   BIC:                                      998.5
# Df Model:                          35
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Age                -0.0458      0.012     -3.823      0.000      -0.069      -0.022
# Min                -0.0133      0.020     -0.682      0.496      -0.052       0.025
# Goals               0.0343      0.030      1.159      0.247      -0.024       0.093
# GoalsPer90          4.9141     12.991      0.378      0.706     -20.655      30.484
# Asists              0.0407      0.062      0.657      0.512      -0.081       0.163
# AsistsPer90         4.1519     12.959      0.320      0.749     -21.354      29.658
# GoalAstPer90       -4.8331     12.994     -0.372      0.710     -30.409      20.743
# Played90s           1.1480      1.759      0.653      0.514      -2.314       4.610
# SCA                 0.0104      0.013      0.787      0.432      -0.016       0.036
# SCA90              -0.0889      0.064     -1.390      0.166      -0.215       0.037
# ShootPass          -0.0241      0.017     -1.456      0.147      -0.057       0.008
# ShootDrib           0.0310      0.031      0.996      0.320      -0.030       0.092
# GCA                -0.0212      0.052     -0.406      0.685      -0.124       0.082
# GCA90               0.1024      0.329      0.311      0.756      -0.545       0.750
# AssistPass          0.0130      0.063      0.207      0.836      -0.111       0.137
# AssistDrib         -0.0134      0.083     -0.162      0.871      -0.176       0.150
# CompletedPasses    -0.0038      0.002     -1.912      0.057      -0.008       0.000
# PassCompRatio       0.0226      0.005      4.613      0.000       0.013       0.032
# TotDistPass         0.0002      0.000      1.983      0.048    1.85e-06       0.000
# ProgDistPass        0.0003      0.000      1.309      0.192      -0.000       0.001
# Crosses            -0.0015      0.005     -0.331      0.741      -0.010       0.007
# PenaltyWon         -0.1170      0.077     -1.516      0.131      -0.269       0.035
# AerialWonRate       0.0030      0.004      0.800      0.424      -0.004       0.010
# ShootOnTarget      -0.0017      0.015     -0.119      0.906      -0.030       0.027
# ShootPer90         -0.0235      0.050     -0.466      0.641      -0.123       0.076
# GoalPerShoot        0.0864      0.844      0.102      0.919      -1.575       1.748
# TacklesWon          0.0177      0.013      1.340      0.181      -0.008       0.044
# TklDribbling       -0.0402      0.024     -1.690      0.092      -0.087       0.007
# Blocks              0.0105      0.008      1.237      0.217      -0.006       0.027
# SuccPressRatio     -0.0048      0.008     -0.578      0.564      -0.021       0.012
# MatchPlayed         0.0197      0.012      1.584      0.114      -0.005       0.044
# PointPerMatch       0.6737      0.124      5.414      0.000       0.429       0.919
# TouchPenArea        0.0119      0.003      3.661      0.000       0.005       0.018
# SuccDrib           -0.0077      0.007     -1.132      0.259      -0.021       0.006
# DribLegs            0.0359      0.040      0.908      0.365      -0.042       0.114
# ==============================================================================
# Omnibus:                        8.497   Durbin-Watson:                   1.960
# Prob(Omnibus):                  0.014   Jarque-Bera (JB):                8.668
# Skew:                          -0.333   Prob(JB):                       0.0131
# Kurtosis:                       3.449   Cond. No.                     3.16e+06
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 3.16e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x_features = ['Age', 'Min', 'Goals', 'GoalsPer90', 'Asists',
       'AsistsPer90', 'GoalAstPer90', 'Played90s', 'SCA', 'SCA90', 'ShootPass',
       'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
       'CompletedPasses', 'PassCompRatio', 'TotDistPass', 'ProgDistPass',
       'Crosses', 'PenaltyWon', 'AerialWonRate', 'ShootOnTarget', 'ShootPer90',
       'GoalPerShoot', 'TacklesWon', 'TklDribbling', 'Blocks',
       'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
       'SuccDrib', 'DribLegs'] 

X = df_mid.reindex(columns=x_features)

y = df_mid.loc[:,"logValue"]

model = sm.OLS(y, X, data=df_for)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               logValue   R-squared (uncentered):                   0.830
# Model:                            OLS   Adj. R-squared (uncentered):              0.815
# Method:                 Least Squares   F-statistic:                              57.02
# Date:                Sat, 02 Jan 2021   Prob (F-statistic):                   6.77e-135
# Time:                        23:37:00   Log-Likelihood:                         -589.88
# No. Observations:                 444   AIC:                                      1250.
# Df Residuals:                     409   BIC:                                      1393.
# Df Model:                          35
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Age                -0.0534      0.012     -4.447      0.000      -0.077      -0.030
# Min                 0.0181      0.017      1.045      0.297      -0.016       0.052
# Goals              -0.0977      0.040     -2.434      0.015      -0.177      -0.019
# GoalsPer90          5.9929     11.917      0.503      0.615     -17.432      29.418
# Asists              0.0134      0.070      0.193      0.847      -0.124       0.150
# AsistsPer90         5.6535     11.863      0.477      0.634     -17.667      28.973
# GoalAstPer90       -5.1885     11.876     -0.437      0.662     -28.535      18.158
# Played90s          -1.6371      1.561     -1.049      0.295      -4.706       1.432
# SCA                -0.0087      0.008     -1.038      0.300      -0.025       0.008
# SCA90              -0.0438      0.071     -0.613      0.540      -0.184       0.097
# ShootPass           0.0107      0.011      0.984      0.326      -0.011       0.032
# ShootDrib           0.0085      0.033      0.257      0.798      -0.057       0.074
# GCA                 0.0068      0.058      0.116      0.907      -0.108       0.121
# GCA90               0.1424      0.481      0.296      0.767      -0.803       1.088
# AssistPass         -0.0293      0.057     -0.509      0.611      -0.142       0.084
# AssistDrib         -0.0057      0.110     -0.052      0.959      -0.223       0.211
# CompletedPasses    -0.0004      0.001     -0.421      0.674      -0.002       0.001
# PassCompRatio       0.0117      0.004      2.612      0.009       0.003       0.021
# TotDistPass      4.431e-05   4.65e-05      0.953      0.341   -4.71e-05       0.000
# ProgDistPass     5.974e-05   9.16e-05      0.652      0.515      -0.000       0.000
# Crosses             0.0035      0.004      0.869      0.385      -0.004       0.011
# PenaltyWon         -0.0795      0.101     -0.784      0.433      -0.279       0.120
# AerialWonRate       0.0051      0.003      1.694      0.091      -0.001       0.011
# ShootOnTarget       0.0013      0.018      0.069      0.945      -0.034       0.037
# ShootPer90          0.0618      0.095      0.651      0.516      -0.125       0.248
# GoalPerShoot        1.3163      1.102      1.194      0.233      -0.850       3.483
# TacklesWon         -0.0003      0.008     -0.039      0.969      -0.016       0.015
# TklDribbling       -0.0041      0.013     -0.313      0.755      -0.030       0.022
# Blocks             -0.0064      0.006     -1.075      0.283      -0.018       0.005
# SuccPressRatio      0.0080      0.006      1.251      0.212      -0.005       0.021
# MatchPlayed         0.0253      0.014      1.861      0.063      -0.001       0.052
# PointPerMatch       0.5005      0.115      4.335      0.000       0.274       0.727
# TouchPenArea        0.0107      0.004      2.765      0.006       0.003       0.018
# SuccDrib            0.0012      0.005      0.223      0.823      -0.009       0.012
# DribLegs            0.0260      0.036      0.724      0.469      -0.045       0.097
# ==============================================================================
# Omnibus:                       15.793   Durbin-Watson:                   2.017
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               17.101
# Skew:                          -0.411   Prob(JB):                     0.000193
# Kurtosis:                       3.500   Cond. No.                     7.09e+06
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 7.09e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x_features = ['Age', 'Min', 'Goals', 'GoalsPer90', 'Asists',
       'AsistsPer90', 'GoalAstPer90', 'Played90s', 'SCA', 'SCA90', 'ShootPass',
       'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
       'CompletedPasses', 'PassCompRatio', 'TotDistPass', 'ProgDistPass',
       'Crosses', 'PenaltyWon', 'AerialWonRate', 'ShootOnTarget', 'ShootPer90',
       'GoalPerShoot', 'TacklesWon', 'TklDribbling', 'Blocks',
       'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
       'SuccDrib', 'DribLegs'] 

X = df_def.reindex(columns=x_features)

y = df_def.loc[:,"logValue"]

model = sm.OLS(y, X, data=df_for)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:               logValue   R-squared (uncentered):                   0.788
# Model:                            OLS   Adj. R-squared (uncentered):              0.774
# Method:                 Least Squares   F-statistic:                              55.86
# Date:                Sat, 02 Jan 2021   Prob (F-statistic):                   3.23e-153
# Time:                        23:37:02   Log-Likelihood:                         -748.74
# No. Observations:                 560   AIC:                                      1567.
# Df Residuals:                     525   BIC:                                      1719.
# Df Model:                          35
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Age                -0.0837      0.010     -8.184      0.000      -0.104      -0.064
# Min                -0.0147      0.016     -0.893      0.372      -0.047       0.018
# Goals              -0.0732      0.068     -1.077      0.282      -0.207       0.060
# GoalsPer90          6.4434     13.957      0.462      0.645     -20.974      33.861
# Asists              0.0103      0.079      0.131      0.896      -0.144       0.165
# AsistsPer90         6.4335     13.981      0.460      0.646     -21.032      33.899
# GoalAstPer90       -6.0494     13.888     -0.436      0.663     -33.333      21.234
# Played90s           1.3370      1.482      0.902      0.367      -1.574       4.248
# SCA                -0.0182      0.013     -1.445      0.149      -0.043       0.007
# SCA90               0.2428      0.112      2.160      0.031       0.022       0.464
# ShootPass          -0.0131      0.015     -0.869      0.385      -0.043       0.016
# ShootDrib           0.0104      0.050      0.209      0.834      -0.087       0.108
# GCA                 0.0933      0.077      1.218      0.224      -0.057       0.244
# GCA90              -1.6032      0.780     -2.056      0.040      -3.135      -0.072
# AssistPass          0.0250      0.076      0.329      0.742      -0.124       0.174
# AssistDrib         -0.1281      0.157     -0.818      0.414      -0.436       0.180
# CompletedPasses     0.0012      0.001      1.907      0.057   -3.53e-05       0.002
# PassCompRatio       0.0206      0.004      4.844      0.000       0.012       0.029
# TotDistPass     -2.222e-05      3e-05     -0.740      0.460   -8.12e-05    3.68e-05
# ProgDistPass     -3.61e-05   5.52e-05     -0.654      0.513      -0.000    7.23e-05
# Crosses             0.0042      0.004      1.183      0.237      -0.003       0.011
# PenaltyWon         -0.2116      0.158     -1.339      0.181      -0.522       0.099
# AerialWonRate       0.0087      0.003      3.186      0.002       0.003       0.014
# ShootOnTarget       0.0048      0.028      0.171      0.864      -0.050       0.060
# ShootPer90          0.1111      0.147      0.755      0.451      -0.178       0.400
# GoalPerShoot        0.6863      0.511      1.344      0.180      -0.317       1.689
# TacklesWon         -0.0085      0.008     -1.031      0.303      -0.025       0.008
# TklDribbling       -0.0087      0.011     -0.819      0.413      -0.029       0.012
# Blocks             -0.0001      0.005     -0.029      0.977      -0.009       0.009
# SuccPressRatio      0.0091      0.007      1.348      0.178      -0.004       0.022
# MatchPlayed         0.0135      0.021      0.653      0.514      -0.027       0.054
# PointPerMatch       0.3117      0.094      3.331      0.001       0.128       0.495
# TouchPenArea        0.0161      0.005      3.242      0.001       0.006       0.026
# SuccDrib            0.0030      0.007      0.433      0.665      -0.010       0.016
# DribLegs            0.0494      0.043      1.152      0.250      -0.035       0.134
# ==============================================================================
# Omnibus:                       20.047   Durbin-Watson:                   1.866
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               21.253
# Skew:                          -0.452   Prob(JB):                     2.43e-05
# Kurtosis:                       3.307   Cond. No.                     1.20e+07
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.2e+07. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
