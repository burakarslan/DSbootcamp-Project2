# %%
#İmport all required libaries first.

import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from sklearn import preprocessing
from sklearn.model_selection import train_test_split, cross_val_score
import statsmodels.api as sm
from sklearn.linear_model import LinearRegression, Ridge, Lasso, LassoCV, RidgeCV
from sklearn.preprocessing import StandardScaler, PolynomialFeatures
from sklearn.model_selection import KFold

from sklearn.linear_model import Lasso, LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv('stats_big5leagues.txt',sep=";", index_col='PlayerName')

# %%
df[df['Comp']=='de Bundesliga'].sort_values('Goals',ascending=False).head(30)
# Out:
#                                         Name Position   Age   Min  Goals  \
# PlayerName
# Timo Werner                      Timo Werner       FW  23.0  2795     28
# Wout Weghorst                  Wout Weghorst       FW  26.0  2739     16
# Jhon Córdoba                    Jhon Córdoba       FW  26.0  1998     13
# Florian Niederlechner  Florian Niederlechner       FW  28.0  2720     13
# Robin Quaison                  Robin Quaison       FW  25.0  2602     13
# Sebastian Andersson      Sebastian Andersson       FW  28.0  2682     12
# Kai Havertz                      Kai Havertz       MF  20.0  2454     12
# Nils Petersen                  Nils Petersen       FW  30.0  2436     11
# Kevin Volland                  Kevin Volland       FW  27.0  2047     10
# Alassane Pléa                  Alassane Pléa       FW  26.0  2143     10
# Marcus Thuram                  Marcus Thuram       FW  21.0  2202     10
# Lars Stindl                      Lars Stindl       MF  30.0  1432      9
# Martin Hinteregger        Martin Hinteregger       DF  26.0  2721      8
# Breel Embolo                    Breel Embolo       FW  22.0  1550      8
# Bas Dost                            Bas Dost       FW  30.0  1475      8
# Lucas Höler                      Lucas Höler       FW  25.0  2485      8
# Milot Rashica                  Milot Rashica       FW  23.0  2264      8
# Christoph Baumgartner  Christoph Baumgartner       MF  19.0  1493      7
# Lucas Alario                    Lucas Alario       FW  26.0  1174      7
# Suat Serdar                      Suat Serdar       MF  22.0  1599      7
# Dodi Lukebakio                Dodi Lukebakio       FW  21.0  2031      7
# Gonçalo Paciência          Gonçalo Paciência       FW  24.0  1283      7
# Marius Bülter                  Marius Bülter       MF  26.0  2321      7
# Erik Thommy                      Erik Thommy       DF  24.0  2259      6
# Ruben Vargas                    Ruben Vargas       FW  20.0  2530      6
# Patrick Herrmann            Patrick Herrmann       FW  28.0  1453      6
# Ihlas Bebou                      Ihlas Bebou       FW  25.0  2102      6
# Amine Harit                      Amine Harit       MF  22.0  2102      6
# Renato Steffen                Renato Steffen       MF  27.0  1585      6
# Marcus Ingvartsen          Marcus Ingvartsen       MF  23.0  1716      5
#
#                        Goals.1  Asists  Asists.1  GoalAstPer90   90s  ...  \
# PlayerName                                                            ...
# Timo Werner               0.90       8      0.26          1.16  31.1  ...
# Wout Weghorst             0.53       3      0.10          0.62  30.4  ...
# Jhon Córdoba              0.59       2      0.09          0.68  22.2  ...
# Florian Niederlechner     0.43       6      0.20          0.63  30.2  ...
# Robin Quaison             0.45       2      0.07          0.52  28.9  ...
# Sebastian Andersson       0.40       1      0.03          0.44  29.8  ...
# Kai Havertz               0.44       6      0.22          0.66  27.3  ...
# Nils Petersen             0.41       2      0.07          0.48  27.1  ...
# Kevin Volland             0.44       7      0.31          0.75  22.7  ...
# Alassane Pléa             0.42      10      0.42          0.84  23.8  ...
# Marcus Thuram             0.41       8      0.33          0.74  24.5  ...
# Lars Stindl               0.57       3      0.19          0.75  15.9  ...
# Martin Hinteregger        0.26       1      0.03          0.30  30.2  ...
# Breel Embolo              0.46       5      0.29          0.75  17.2  ...
# Bas Dost                  0.49       2      0.12          0.61  16.4  ...
# Lucas Höler               0.29       2      0.07          0.36  27.6  ...
# Milot Rashica             0.32       5      0.20          0.52  25.2  ...
# Christoph Baumgartner     0.42       2      0.12          0.54  16.6  ...
# Lucas Alario              0.54       1      0.08          0.61  13.0  ...
# Suat Serdar               0.39       0      0.00          0.39  17.8  ...
# Dodi Lukebakio            0.31       6      0.27          0.58  22.6  ...
# Gonçalo Paciência         0.49       3      0.21          0.70  14.3  ...
# Marius Bülter             0.27       1      0.04          0.31  25.8  ...
# Erik Thommy               0.24       4      0.16          0.40  25.1  ...
# Ruben Vargas              0.21       1      0.04          0.25  28.1  ...
# Patrick Herrmann          0.37       6      0.37          0.74  16.1  ...
# Ihlas Bebou               0.26       1      0.04          0.30  23.4  ...
# Amine Harit               0.26       4      0.17          0.43  23.4  ...
# Renato Steffen            0.34       3      0.17          0.51  17.6  ...
# Marcus Ingvartsen         0.26       2      0.10          0.37  19.1  ...
#
#                        SuccPressRatio  MatchPlayed  PointPerMatch  \
# PlayerName
# Timo Werner                      24.6           34           1.94
# Wout Weghorst                    28.1           32           1.34
# Jhon Córdoba                     25.3           29           1.03
# Florian Niederlechner            23.8           33           1.09
# Robin Quaison                    22.7           32           1.06
# Sebastian Andersson              24.7           33           1.15
# Kai Havertz                      30.7           30           1.93
# Nils Petersen                    25.2           34           1.41
# Kevin Volland                    30.3           27           1.74
# Alassane Pléa                    23.3           27           1.74
# Marcus Thuram                    23.0           31           1.81
# Lars Stindl                      28.6           25           1.80
# Martin Hinteregger               35.6           31           1.35
# Breel Embolo                     24.1           28           1.86
# Bas Dost                         29.4           24           1.50
# Lucas Höler                      23.8           34           1.41
# Milot Rashica                    30.5           28           0.89
# Christoph Baumgartner            28.0           26           1.46
# Lucas Alario                     27.6           24           1.58
# Suat Serdar                      31.7           20           1.65
# Dodi Lukebakio                   24.1           30           1.13
# Gonçalo Paciência                27.0           23           1.22
# Marius Bülter                    26.6           32           1.19
# Erik Thommy                      30.0           34           0.88
# Ruben Vargas                     24.4           33           1.00
# Patrick Herrmann                 29.0           27           2.11
# Ihlas Bebou                      25.7           32           1.53
# Amine Harit                      29.6           25           1.36
# Renato Steffen                   30.5           27           1.37
# Marcus Ingvartsen                26.8           28           1.25
#
#                        TouchPenArea  SuccDrib  DribLegs  PlayerType  Value  \
# PlayerName
# Timo Werner                   266.0      66.0       4.0     Forward   60.0
# Wout Weghorst                 173.0      28.0       0.0     Forward    9.0
# Jhon Córdoba                  126.0      26.0       0.0     Forward    8.0
# Florian Niederlechner         155.0      33.0       4.0     Forward    6.0
# Robin Quaison                 100.0      41.0       0.0     Forward    7.0
# Sebastian Andersson           135.0      25.0       2.0     Forward    5.0
# Kai Havertz                   149.0      59.0       7.0  Midfielder   40.0
# Nils Petersen                 118.0       9.0       2.0     Forward    4.0
# Kevin Volland                 144.0      24.0       2.0     Forward   20.0
# Alassane Pléa                 136.0      48.0       1.0     Forward   20.0
# Marcus Thuram                 157.0      69.0       3.0     Forward   10.0
# Lars Stindl                    62.0      14.0       2.0  Midfielder    2.0
# Martin Hinteregger             55.0      10.0       1.0    Defender    7.0
# Breel Embolo                   97.0      36.0       7.0     Forward    8.0
# Bas Dost                       76.0       4.0       1.0     Forward    8.0
# Lucas Höler                   134.0      37.0       1.0     Forward    4.0
# Milot Rashica                  83.0      65.0       1.0     Forward    8.0
# Christoph Baumgartner          93.0      22.0       2.0  Midfielder    2.0
# Lucas Alario                   89.0      16.0       1.0     Forward   10.0
# Suat Serdar                    34.0      46.0       2.0  Midfielder    6.0
# Dodi Lukebakio                 70.0      54.0       3.0     Forward    8.0
# Gonçalo Paciência              91.0      26.0       2.0     Forward    4.0
# Marius Bülter                  78.0      66.0       5.0  Midfielder    3.0
# Erik Thommy                    72.0      47.0       0.0    Defender    4.0
# Ruben Vargas                   96.0      58.0       7.0     Forward    4.0
# Patrick Herrmann               82.0      16.0       0.0     Forward    7.0
# Ihlas Bebou                    95.0      53.0       4.0     Forward    6.0
# Amine Harit                    73.0      59.0       1.0  Midfielder   10.0
# Renato Steffen                 50.0      34.0       1.0  Midfielder    4.0
# Marcus Ingvartsen              58.0      22.0       1.0  Midfielder    2.0
#
#                        Value2           Comp
# PlayerName
# Timo Werner                 M  de Bundesliga
# Wout Weghorst               M  de Bundesliga
# Jhon Córdoba                M  de Bundesliga
# Florian Niederlechner       M  de Bundesliga
# Robin Quaison               M  de Bundesliga
# Sebastian Andersson         M  de Bundesliga
# Kai Havertz                 M  de Bundesliga
# Nils Petersen               M  de Bundesliga
# Kevin Volland               M  de Bundesliga
# Alassane Pléa               M  de Bundesliga
# Marcus Thuram               M  de Bundesliga
# Lars Stindl                 M  de Bundesliga
# Martin Hinteregger          M  de Bundesliga
# Breel Embolo                M  de Bundesliga
# Bas Dost                    M  de Bundesliga
# Lucas Höler                 M  de Bundesliga
# Milot Rashica               M  de Bundesliga
# Christoph Baumgartner       M  de Bundesliga
# Lucas Alario                M  de Bundesliga
# Suat Serdar                 M  de Bundesliga
# Dodi Lukebakio              M  de Bundesliga
# Gonçalo Paciência           M  de Bundesliga
# Marius Bülter               M  de Bundesliga
# Erik Thommy                 M  de Bundesliga
# Ruben Vargas                M  de Bundesliga
# Patrick Herrmann            M  de Bundesliga
# Ihlas Bebou                 M  de Bundesliga
# Amine Harit                 M  de Bundesliga
# Renato Steffen              M  de Bundesliga
# Marcus Ingvartsen           M  de Bundesliga
#
# [30 rows x 41 columns]

# %%
df_tm = pd.read_csv('data/tm_marketvalues.csv',sep=",", index_col='player')

# %%
sns.distplot((df_tm['t_value']) )
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='t_value', ylabel='Density'>

# %%
df_tm['t_value']=df_tm['t_value'].astype(float)

# %%
sns.distplot(np.log(df_tm['t_value']) )
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='t_value', ylabel='Density'>

# %%
df = df.merge(df_tm,left_index=True, right_index=True)

# %%
def MorK(x):
    if(x['Value2']=='M'):
        return(1)
    else:
        return(0.001)
    
df['NetValue'] = df.apply(MorK, axis=1)
df['NetValue'] = df['Value']  * df['NetValue']
df
# Out:
#                               Name Position   Age   Min  Goals  Goals.1  \
# PlayerName
# Aaron Connolly      Aaron Connolly       FW  19.0  1258      3     0.21
# Aaron Cresswell    Aaron Cresswell       DF  29.0  2727      3     0.10
# Aaron Leya Iseka  Aaron Leya Iseka       FW  21.0   777      2     0.23
# Aaron Ramsdale      Aaron Ramsdale       GK  21.0  3330      0     0.00
# Aaron Ramsey          Aaron Ramsey       MF  28.0  1051      3     0.26
# ...                            ...      ...   ...   ...    ...      ...
# Ángel Montoro        Ángel Montoro       MF  31.0   973      2     0.18
# Éder Militão          Éder Militão       DF  21.0  1022      0     0.00
# Édgar Méndez          Édgar Méndez       MF  29.0   864      1     0.10
# Óscar Plano            Óscar Plano       MF  28.0  2505      4     0.14
# Ömer Toprak            Ömer Toprak       DF  30.0   715      0     0.00
#
#                   Asists  Asists.1  GoalAstPer90   90s  ...  MatchPlayed  \
# PlayerName                                              ...
# Aaron Connolly         1      0.07          0.29  14.0  ...           24
# Aaron Cresswell        0      0.00          0.10  30.3  ...           31
# Aaron Leya Iseka       0      0.00          0.23   8.6  ...           22
# Aaron Ramsdale         1      0.03          0.03  37.0  ...           37
# Aaron Ramsey           1      0.09          0.34  11.7  ...           24
# ...                  ...       ...           ...   ...  ...          ...
# Ángel Montoro          5      0.46          0.65  10.8  ...           15
# Éder Militão           0      0.00          0.00  11.4  ...           15
# Édgar Méndez           0      0.00          0.10   9.6  ...           16
# Óscar Plano            2      0.07          0.22  27.8  ...           36
# Ömer Toprak            0      0.00          0.00   7.9  ...           10
#
#                   PointPerMatch  TouchPenArea  SuccDrib  DribLegs  PlayerType  \
# PlayerName
# Aaron Connolly             1.13          61.0       6.0       1.0     Forward
# Aaron Cresswell            0.97          26.0      16.0       2.0    Defender
# Aaron Leya Iseka           0.27          39.0       7.0       0.0     Forward
# Aaron Ramsdale             0.92           0.0       0.0       0.0  Goalkeeper
# Aaron Ramsey               2.25          61.0      16.0       0.0  Midfielder
# ...                         ...           ...       ...       ...         ...
# Ángel Montoro              1.60          13.0       6.0       2.0  Midfielder
# Éder Militão               2.33           4.0       1.0       0.0    Defender
# Édgar Méndez               0.94          17.0      12.0       1.0  Midfielder
# Óscar Plano                1.17          53.0      11.0       1.0  Midfielder
# Ömer Toprak                0.50           5.0       5.0       0.0    Defender
#
#                   Value  Value2                Comp  NetValue
# PlayerName
# Aaron Connolly      9.0       M  eng Premier League       9.0
# Aaron Cresswell    10.0       M  eng Premier League      10.0
# Aaron Leya Iseka  600.0       K          fr Ligue 1       0.6
# Aaron Ramsdale     20.0       M  eng Premier League      20.0
# Aaron Ramsey       20.0       M          it Serie A      20.0
# ...                 ...     ...                 ...       ...
# Ángel Montoro       2.0       M          es La Liga       2.0
# Éder Militão       20.0       M          es La Liga      20.0
# Édgar Méndez        6.0       M          es La Liga       6.0
# Óscar Plano         2.0       M          es La Liga       2.0
# Ömer Toprak         5.0       M       de Bundesliga       5.0
#
# [1448 rows x 42 columns]

# %%
df2.sort_values('t_value',ascending=False)
# Out:
#                             Name Position   Age   Min  Goals  Goals.1  Asists  \
# Sadio Mané            Sadio Mané       FW  27.0  2747     18     0.59       7
# Harry Kane            Harry Kane       FW  26.0  2587     18     0.63       2
# Kevin De Bruyne  Kevin De Bruyne       MF  28.0  2791     13     0.42      20
# Mohamed Salah      Mohamed Salah       FW  27.0  2876     19     0.59      10
# Raheem Sterling  Raheem Sterling       FW  24.0  2651     20     0.68       1
# ...                          ...      ...   ...   ...    ...      ...     ...
# Djibril Sidibé    Djibril Sidibé       DF  27.0  1824      0     0.00       4
# Benjamin André    Benjamin André       MF  28.0  2054      2     0.09       1
# Alfred Gomis        Alfred Gomis       GK  25.0  1619      0     0.00       0
# Mounir Chouiar    Mounir Chouiar       MF  20.0  1506      4     0.24       0
# Ibrahima Niane    Ibrahima Niane       FW  20.0   951      3     0.28       0
#
#                  Asists.1  GoalAstPer90   90s  ...  MatchPlayed  \
# Sadio Mané           0.23          0.82  30.5  ...           35
# Harry Kane           0.07          0.70  28.7  ...           29
# Kevin De Bruyne      0.64          1.06  31.0  ...           35
# Mohamed Salah        0.31          0.91  32.0  ...           34
# Raheem Sterling      0.03          0.71  29.5  ...           33
# ...                   ...           ...   ...  ...          ...
# Djibril Sidibé       0.20          0.20  20.3  ...           25
# Benjamin André       0.04          0.13  22.8  ...           26
# Alfred Gomis         0.00          0.00  18.0  ...           19
# Mounir Chouiar       0.00          0.24  16.7  ...           20
# Ibrahima Niane       0.00          0.28  10.6  ...           21
#
#                  PointPerMatch  TouchPenArea  SuccDrib  DribLegs  PlayerType  \
# Sadio Mané                2.57         219.0      76.0       6.0     Forward
# Harry Kane                1.62         132.0      28.0       3.0     Forward
# Kevin De Bruyne           2.23         164.0      62.0       1.0  Midfielder
# Mohamed Salah             2.68         317.0      66.0       3.0     Forward
# Raheem Sterling           2.00         296.0      59.0       3.0     Forward
# ...                        ...           ...       ...       ...         ...
# Djibril Sidibé            1.32          19.0      14.0       4.0    Defender
# Benjamin André            1.88          23.0      23.0       0.0  Midfielder
# Alfred Gomis              1.32           0.0       1.0       0.0  Goalkeeper
# Mounir Chouiar            1.05          61.0      75.0       1.0  Midfielder
# Ibrahima Niane            1.19          31.0      26.0       4.0     Forward
#
#                  Value  Value2                Comp  t_value
# Sadio Mané        90.0       M  eng Premier League    120.0
# Harry Kane        90.0       M  eng Premier League    120.0
# Kevin De Bruyne   90.0       M  eng Premier League    120.0
# Mohamed Salah     90.0       M  eng Premier League    120.0
# Raheem Sterling   80.0       M  eng Premier League    110.0
# ...                ...     ...                 ...      ...
# Djibril Sidibé     8.0       M  eng Premier League     10.0
# Benjamin André    10.0       M          fr Ligue 1     10.0
# Alfred Gomis       4.0       M          fr Ligue 1      9.0
# Mounir Chouiar     3.0       M          fr Ligue 1      9.0
# Ibrahima Niane     2.0       M          fr Ligue 1      9.0
#
# [289 rows x 42 columns]

# %%
df = df.merge(df_tm,left_index=True, right_index=True)
df
# Out:
#                                 Name Position   Age   Min  Goals   Goals.1  \
# Aaron Ramsey            Aaron Ramsey       MF  28.0  1051      3  0.260000
# Aaron Wan-Bissaka  Aaron Wan-Bissaka       DF  21.0  3070      0  0.000000
# Abdou Diallo            Abdou Diallo       DF  23.0  1201      0  0.000000
# Adama Traoré            Adama Traoré       MF  24.0  7274     10  0.076667
# Adil Aouchiche        Adil Aouchiche       MF  17.0    64      0  0.000000
# ...                              ...      ...   ...   ...    ...       ...
# Youssouf Fofana      Youssouf Fofana       MF  20.0  1618      1  0.045000
# Yussuf Poulsen        Yussuf Poulsen       FW  25.0  1222      5  0.370000
# Álex Remiro              Álex Remiro       GK  24.0  2250      0  0.000000
# Ángel Correa            Ángel Correa       MF  24.0  2061      5  0.220000
# Éder Militão            Éder Militão       DF  21.0  1022      0  0.000000
#
#                    Asists  Asists.1  GoalAstPer90   90s  ...  PointPerMatch  \
# Aaron Ramsey            1  0.090000         0.340  11.7  ...           2.25
# Aaron Wan-Bissaka       4  0.120000         0.120  34.1  ...           1.77
# Abdou Diallo            1  0.070000         0.070  13.3  ...           2.44
# Adama Traoré           26  0.223333         0.300  80.8  ...           1.09
# Adil Aouchiche          0  0.000000         0.000   0.7  ...           3.00
# ...                   ...       ...           ...   ...  ...            ...
# Youssouf Fofana         2  0.150000         0.195  18.0  ...           1.63
# Yussuf Poulsen          6  0.440000         0.810  13.6  ...           1.77
# Álex Remiro             0  0.000000         0.000  25.0  ...           1.48
# Ángel Correa            6  0.260000         0.480  22.9  ...           1.79
# Éder Militão            0  0.000000         0.000  11.4  ...           2.33
#
#                    TouchPenArea  SuccDrib  DribLegs  PlayerType  Value  \
# Aaron Ramsey               61.0      16.0       0.0  Midfielder   20.0
# Aaron Wan-Bissaka          46.0      59.0       3.0    Defender   60.0
# Abdou Diallo                8.0      17.0       1.0    Defender    9.0
# Adama Traoré              256.0     372.0      10.0  Midfielder  600.0
# Adil Aouchiche              1.0       3.0       0.0  Midfielder  800.0
# ...                         ...       ...       ...         ...    ...
# Youssouf Fofana            27.0      22.0       3.0  Midfielder    4.0
# Yussuf Poulsen             79.0      13.0       0.0     Forward   20.0
# Álex Remiro                 1.0       1.0       0.0  Goalkeeper   20.0
# Ángel Correa              139.0      41.0       2.0  Midfielder   40.0
# Éder Militão                4.0       1.0       0.0    Defender   20.0
#
#                    Value2                Comp  NetValue  t_value
# Aaron Ramsey            M          it Serie A      20.0     20.0
# Aaron Wan-Bissaka       M  eng Premier League      60.0     40.0
# Abdou Diallo            M          fr Ligue 1       9.0     25.0
# Adama Traoré            M          fr Ligue 1     600.0     40.0
# Adil Aouchiche          K          fr Ligue 1       0.8     10.0
# ...                   ...                 ...       ...      ...
# Youssouf Fofana         M          fr Ligue 1       4.0     13.0
# Yussuf Poulsen          M       de Bundesliga      20.0     25.0
# Álex Remiro             M          es La Liga      20.0     20.0
# Ángel Correa            M          es La Liga      40.0     40.0
# Éder Militão            M          es La Liga      20.0     30.0
#
# [289 rows x 43 columns]

# %%
df.columns
# Out:
# Index(['Name', 'Position', 'Age', 'Min', 'Goals', 'Goals.1', 'Asists',
#        'Asists.1', 'GoalAstPer90', '90s', 'SCA', 'SCA90', 'ShootPass',
#        'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
#        'CompletedPasses', 'PassCompRatio', 'TotDistPass', 'ProgDistPass',
#        'Crosses', 'PenaltyWon', 'AerialWonRate', 'ShootOnTarget', 'ShootPer90',
#        'GoalPerShoot', 'TacklesWon', 'TklDribbling', 'Blocks',
#        'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
#        'SuccDrib', 'DribLegs', 'Value', 'NetValue', 't_value', 'log_t_value',
#        'Age2', 'Winner', 'PlayerType_Defender', 'PlayerType_Forward',
#        'PlayerType_Midfielder', 'League_Bundesliga', 'League_La Liga',
#        'League_Ligue 1', 'League_Premier League', 'League_Serie A',
#        'AgeGroups'],
#       dtype='object')

# %%
fmvalue=df['NetValue']
tmvalue=df['t_value']

plt.figure(figsize=(15,15))

predicted_bar = sns.jointplot(fmvalue, tmvalue)
plt.xlabel ('FM 2021 values')
plt.ylabel ('Transfermarkt Values')
predicted_bar.savefig('fm vs tm values.svg')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
fmvalue=df['NetValue']
tmvalue=df['t_value']

plt.figure(figsize=(15,15))

predicted_bar = sns.jointplot(np.log(fmvalue), np.log(tmvalue))
plt.xlabel('FM 2021 values')
plt.ylabel('Transfermarkt Values')
predicted_bar.savefig('fm vs tm values.svg')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-531-dccf6bc08102> in <module>
#       5
#       6 predicted_bar = sns.jointplot(np.log(fmvalue), np.log(tmvalue))
# ----> 7 sns.xlabel('FM 2021 values')
#       8 plt.ylabel('Transfermarkt Values')
#       9 predicted_bar.savefig('fm vs tm values.svg')
#
# AttributeError: module 'seaborn' has no attribute 'xlabel'

# %%
plt.figure(figsize=(15,15))
np.log(df["NetValue"]).plot.hist(density=True, bins = 30)
np.log(df["t_value"]).plot.hist(density=True, bins = 30)
predicted_bar.savefig('fm vs tm values bar chart.svg')

# %%
plt.figure(figsize=(20,20))
sns.heatmap(df.corr(),linewidths=.5, annot=True );
plt.yticks(rotation=360)
plt.show()

# %%
df.columns
# Out:
# Index(['Name', 'Position', 'Age', 'Min', 'Goals', 'Goals.1', 'Asists',
#        'Asists.1', 'GoalAstPer90', '90s', 'SCA', 'SCA90', 'ShootPass',
#        'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
#        'CompletedPasses', 'PassCompRatio', 'TotDistPass', 'ProgDistPass',
#        'Crosses', 'PenaltyWon', 'AerialWonRate', 'ShootOnTarget', 'ShootPer90',
#        'GoalPerShoot', 'TacklesWon', 'TklDribbling', 'Blocks',
#        'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
#        'SuccDrib', 'DribLegs', 'PlayerType', 'Value', 'Value2', 'Comp',
#        't_value'],
#       dtype='object')

# %%
plt.figure(figsize=(15,15))

ax = sns.boxplot(x="PlayerType", y="t_value", data=value_grouped_positions2, whis=np.inf)
ax = sns.swarmplot(x="PlayerType", y="t_value", data=value_grouped_positions2, color=".2")

# %%
plt.figure(figsize=(15,15))

sns.violinplot('PlayerType', 't_value' ,data = value_grouped_positions2, inner=None)
ax = sns.swarmplot(x="PlayerType", y="t_value", data=value_grouped_positions2,     color="white", edgecolor="gray")
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
plt.figure(figsize=(10,10))

sns.swarmplot(x="PlayerType", y="t_value", data=df[df['PlayerType']!='Goalkeeper'])
grouped_bar.savefig('swarm_playertpe value tm.svg')

# %%
df[['Comp','League']] = df['Comp'].str.split(" ", 1, expand=True)

# %%
df.drop('Comp', axis=1, inplace=True)
df.drop('Value2', axis=1, inplace=True)
df.head(3)
# Out:
#                                 Name Position   Age   Min  Goals  Goals.1  \
# Aaron Ramsey            Aaron Ramsey       MF  28.0  1051      3     0.26
# Aaron Wan-Bissaka  Aaron Wan-Bissaka       DF  21.0  3070      0     0.00
# Abdou Diallo            Abdou Diallo       DF  23.0  1201      0     0.00
#
#                    Asists  Asists.1  GoalAstPer90   90s  ...  SuccPressRatio  \
# Aaron Ramsey            1      0.09          0.34  11.7  ...            28.4
# Aaron Wan-Bissaka       4      0.12          0.12  34.1  ...            28.8
# Abdou Diallo            1      0.07          0.07  13.3  ...            37.3
#
#                    MatchPlayed  PointPerMatch  TouchPenArea  SuccDrib  \
# Aaron Ramsey                24           2.25          61.0      16.0
# Aaron Wan-Bissaka           35           1.77          46.0      59.0
# Abdou Diallo                16           2.44           8.0      17.0
#
#                    DribLegs  PlayerType  Value  t_value          League
# Aaron Ramsey            0.0  Midfielder   20.0   20.00          Serie A
# Aaron Wan-Bissaka       3.0    Defender   60.0   40.00   Premier League
# Abdou Diallo            1.0    Defender    9.0   25.00          Ligue 1
#
# [3 rows x 41 columns]

# %%
value_grouped_positions = df.groupby(['League','PlayerType'])['Age'].mean().reset_index().sort_values('Age',ascending = False)
grouped_bar = sns.catplot('PlayerType', 'Age', hue ='League', kind = 'bar', saturation=.5,data = value_grouped_positions )
#plt.xticks(rotation=45)
plt.xlabel('Grouped Positions')
plt.ylabel('Average Age')
plt.title("Average Age of players by League")
grouped_bar.savefig('PlayerValuebyLeague tm.svg')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 289 entries, Aaron Ramsey to Éder Militão
# Data columns (total 42 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             289 non-null    object
#  1   Position         289 non-null    object
#  2   Age              289 non-null    float64
#  3   Min              289 non-null    int64
#  4   Goals            289 non-null    int64
#  5   Goals.1          289 non-null    float64
#  6   Asists           289 non-null    int64
#  7   Asists.1         289 non-null    float64
#  8   GoalAstPer90     289 non-null    float64
#  9   90s              289 non-null    float64
#  10  SCA              289 non-null    float64
#  11  SCA90            289 non-null    float64
#  12  ShootPass        289 non-null    float64
#  13  ShootDrib        289 non-null    float64
#  14  GCA              289 non-null    float64
#  15  GCA90            289 non-null    float64
#  16  AssistPass       289 non-null    float64
#  17  AssistDrib       289 non-null    float64
#  18  CompletedPasses  289 non-null    float64
#  19  PassCompRatio    289 non-null    float64
#  20  TotDistPass      289 non-null    float64
#  21  ProgDistPass     289 non-null    float64
#  22  Crosses          289 non-null    int64
#  23  PenaltyWon       289 non-null    float64
#  24  AerialWonRate    289 non-null    float64
#  25  ShootOnTarget    289 non-null    int64
#  26  ShootPer90       289 non-null    float64
#  27  GoalPerShoot     289 non-null    float64
#  28  TacklesWon       289 non-null    int64
#  29  TklDribbling     289 non-null    float64
#  30  Blocks           289 non-null    float64
#  31  SuccPressRatio   289 non-null    float64
#  32  MatchPlayed      289 non-null    int64
#  33  PointPerMatch    289 non-null    float64
#  34  TouchPenArea     289 non-null    float64
#  35  SuccDrib         289 non-null    float64
#  36  DribLegs         289 non-null    float64
#  37  PlayerType       289 non-null    object
#  38  Value            289 non-null    float64
#  39  t_value          289 non-null    object
#  40  League           289 non-null    object
#  41  v_value          289 non-null    float64
# dtypes: float64(30), int64(7), object(5)
# memory usage: 97.1+ KB

# %%
x_features = ['Age', 'Min', 'Goals', 'Goals.1', 'Asists',
       'Asists.1', 'GoalAstPer90', '90s', 'SCA', 'SCA90', 'ShootPass',
       'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
       'CompletedPasses', 'PassCompRatio', 'TotDistPass', 'ProgDistPass',
       'Crosses', 'PenaltyWon', 'AerialWonRate', 'ShootOnTarget', 'ShootPer90',
       'GoalPerShoot', 'TacklesWon', 'TklDribbling', 'Blocks',
       'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
       'SuccDrib', 'DribLegs'] 

X = df.reindex(columns=x_features)

y = df.loc[:,"v_value"]

model = sm.OLS(y, X, data=df)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                v_value   R-squared (uncentered):                   0.865
# Model:                            OLS   Adj. R-squared (uncentered):              0.847
# Method:                 Least Squares   F-statistic:                              46.68
# Date:                Sun, 10 Jan 2021   Prob (F-statistic):                    3.95e-91
# Time:                        13:14:21   Log-Likelihood:                         -1157.9
# No. Observations:                 289   AIC:                                      2386.
# Df Residuals:                     254   BIC:                                      2514.
# Df Model:                          35
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Age                -1.1072      0.291     -3.801      0.000      -1.681      -0.534
# Min                -0.6481      0.346     -1.874      0.062      -1.329       0.033
# Goals               1.6613      0.714      2.326      0.021       0.255       3.068
# Goals.1          -141.0973    218.693     -0.645      0.519    -571.780     289.585
# Asists              1.5685      1.160      1.352      0.178      -0.716       3.853
# Asists.1         -137.4894    218.400     -0.630      0.530    -567.596     292.617
# GoalAstPer90      131.2717    218.570      0.601      0.549    -299.168     561.711
# 90s                58.1142     31.115      1.868      0.063      -3.161     119.390
# SCA                -0.1565      0.161     -0.974      0.331      -0.473       0.160
# SCA90               0.3174      2.215      0.143      0.886      -4.045       4.680
# ShootPass           0.2867      0.196      1.460      0.145      -0.100       0.673
# ShootDrib           0.0938      0.495      0.189      0.850      -0.882       1.070
# GCA                 0.4894      1.095      0.447      0.655      -1.667       2.646
# GCA90              10.1020     15.742      0.642      0.522     -20.900      41.104
# AssistPass         -1.4168      0.935     -1.515      0.131      -3.258       0.424
# AssistDrib         -2.2305      1.505     -1.482      0.140      -5.194       0.733
# CompletedPasses    -0.0296      0.012     -2.515      0.013      -0.053      -0.006
# PassCompRatio       0.2805      0.099      2.841      0.005       0.086       0.475
# TotDistPass         0.0019      0.001      3.194      0.002       0.001       0.003
# ProgDistPass        0.0012      0.001      1.644      0.101      -0.000       0.003
# Crosses            -0.0164      0.052     -0.314      0.754      -0.119       0.087
# PenaltyWon          0.5154      1.450      0.355      0.723      -2.341       3.372
# AerialWonRate      -0.0981      0.064     -1.523      0.129      -0.225       0.029
# ShootOnTarget      -0.2822      0.285     -0.989      0.324      -0.844       0.280
# ShootPer90         -1.5849      2.766     -0.573      0.567      -7.032       3.862
# GoalPerShoot       29.2387     17.708      1.651      0.100      -5.635      64.113
# TacklesWon          0.4316      0.132      3.260      0.001       0.171       0.692
# TklDribbling       -0.4028      0.216     -1.861      0.064      -0.829       0.024
# Blocks             -0.0903      0.094     -0.964      0.336      -0.275       0.094
# SuccPressRatio      0.0239      0.160      0.149      0.882      -0.292       0.340
# MatchPlayed        -0.4041      0.270     -1.494      0.136      -0.937       0.129
# PointPerMatch      11.5707      2.223      5.206      0.000       7.194      15.948
# TouchPenArea        0.1963      0.045      4.368      0.000       0.108       0.285
# SuccDrib           -0.0274      0.075     -0.366      0.715      -0.175       0.120
# DribLegs            0.8088      0.548      1.477      0.141      -0.269       1.887
# ==============================================================================
# Omnibus:                       74.540   Durbin-Watson:                   2.126
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):              250.876
# Skew:                           1.087   Prob(JB):                     3.33e-55
# Kurtosis:                       7.013   Cond. No.                     9.57e+06
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 9.57e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x_features = ['Age', 'Min', 'Goals', 'Goals.1', 'Asists',
       'Asists.1', 'GoalAstPer90', '90s', 'SCA', 'SCA90', 'ShootPass',
       'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
       'CompletedPasses', 'PassCompRatio', 'TotDistPass', 'ProgDistPass',
       'Crosses', 'PenaltyWon', 'AerialWonRate', 'ShootOnTarget', 'ShootPer90',
       'GoalPerShoot', 'TacklesWon', 'TklDribbling', 'Blocks',
       'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
       'SuccDrib', 'DribLegs'] 

X = df.reindex(columns=x_features)

y = df.loc[:,"v_value"]

model = sm.OLS(np.log(y), X, data=df)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:                v_value   R-squared (uncentered):                   0.984
# Model:                            OLS   Adj. R-squared (uncentered):              0.982
# Method:                 Least Squares   F-statistic:                              442.1
# Date:                Sun, 10 Jan 2021   Prob (F-statistic):                   3.79e-207
# Time:                        13:19:11   Log-Likelihood:                         -158.64
# No. Observations:                 289   AIC:                                      387.3
# Df Residuals:                     254   BIC:                                      515.6
# Df Model:                          35
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Age                -0.0106      0.009     -1.158      0.248      -0.029       0.007
# Min                -0.0217      0.011     -1.996      0.047      -0.043      -0.000
# Goals               0.0399      0.022      1.773      0.077      -0.004       0.084
# Goals.1            -4.9898      6.890     -0.724      0.470     -18.558       8.579
# Asists              0.0098      0.037      0.269      0.788      -0.062       0.082
# Asists.1           -4.4356      6.881     -0.645      0.520     -17.986       9.115
# GoalAstPer90        4.5283      6.886      0.658      0.511      -9.032      18.089
# 90s                 1.9621      0.980      2.002      0.046       0.032       3.893
# SCA                 0.0010      0.005      0.206      0.837      -0.009       0.011
# SCA90               0.0024      0.070      0.035      0.972      -0.135       0.140
# ShootPass           0.0012      0.006      0.193      0.847      -0.011       0.013
# ShootDrib          -0.0073      0.016     -0.466      0.641      -0.038       0.023
# GCA                -0.0154      0.034     -0.447      0.655      -0.083       0.053
# GCA90               0.6463      0.496      1.303      0.194      -0.330       1.623
# AssistPass         -0.0203      0.029     -0.688      0.492      -0.078       0.038
# AssistDrib         -0.0128      0.047     -0.269      0.788      -0.106       0.081
# CompletedPasses    -0.0010      0.000     -2.752      0.006      -0.002      -0.000
# PassCompRatio       0.0245      0.003      7.878      0.000       0.018       0.031
# TotDistPass      4.594e-05   1.83e-05      2.506      0.013    9.84e-06     8.2e-05
# ProgDistPass     2.594e-05   2.31e-05      1.122      0.263   -1.96e-05    7.15e-05
# Crosses             0.0008      0.002      0.501      0.617      -0.002       0.004
# PenaltyWon          0.0121      0.046      0.265      0.792      -0.078       0.102
# AerialWonRate      -0.0017      0.002     -0.844      0.399      -0.006       0.002
# ShootOnTarget      -0.0097      0.009     -1.078      0.282      -0.027       0.008
# ShootPer90          0.0216      0.087      0.247      0.805      -0.150       0.193
# GoalPerShoot        0.8984      0.558      1.610      0.109      -0.200       1.997
# TacklesWon          0.0121      0.004      2.904      0.004       0.004       0.020
# TklDribbling       -0.0151      0.007     -2.217      0.028      -0.029      -0.002
# Blocks              0.0011      0.003      0.361      0.718      -0.005       0.007
# SuccPressRatio      0.0010      0.005      0.190      0.850      -0.009       0.011
# MatchPlayed         0.0024      0.009      0.282      0.778      -0.014       0.019
# PointPerMatch       0.4435      0.070      6.334      0.000       0.306       0.581
# TouchPenArea        0.0044      0.001      3.103      0.002       0.002       0.007
# SuccDrib           -0.0005      0.002     -0.232      0.816      -0.005       0.004
# DribLegs            0.0270      0.017      1.568      0.118      -0.007       0.061
# ==============================================================================
# Omnibus:                        8.696   Durbin-Watson:                   2.097
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                8.595
# Skew:                           0.401   Prob(JB):                       0.0136
# Kurtosis:                       3.264   Cond. No.                     9.57e+06
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 9.57e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X_train, X_test, y_train, y_test = train_test_split(X, np.log(y), test_size=.2, random_state=10)
lm = LinearRegression()
lm.fit(X_train,y_train)
print('score : ' +str( lm.score(X,np.log(y)) )) 
predicted_bar = sns.jointplot(lm.predict(X), np.log(y))
plt.xlabel ('Predicted Values')
plt.ylabel ('Real Values')
'''predicted_bar.savefig('predicted_bar.svg')
'''
# Out:
# score : 0.4688762931889312
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# "predicted_bar.savefig('predicted_bar.svg')\n"

# %%
df['log_t_value']=np.log(df['t_value'])

# %%
x_features = ['Age', 'Min', 'Goals', 'Goals.1', 'Asists',
       'Asists.1', 'GoalAstPer90', '90s', 'SCA', 'SCA90', 'ShootPass',
       'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
       'CompletedPasses', 'PassCompRatio', 'TotDistPass', 'ProgDistPass',
       'Crosses', 'PenaltyWon', 'AerialWonRate', 'ShootOnTarget', 'ShootPer90',
       'GoalPerShoot', 'TacklesWon', 'TklDribbling', 'Blocks',
       'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
       'SuccDrib', 'DribLegs',] 

X = df.reindex(columns=x_features)

y = df.loc[:,"log_t_value"]

model = sm.OLS(y, X, data=df)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            log_t_value   R-squared (uncentered):                   0.984
# Model:                            OLS   Adj. R-squared (uncentered):              0.982
# Method:                 Least Squares   F-statistic:                              442.1
# Date:                Sat, 09 Jan 2021   Prob (F-statistic):                   3.79e-207
# Time:                        15:35:59   Log-Likelihood:                         -158.64
# No. Observations:                 289   AIC:                                      387.3
# Df Residuals:                     254   BIC:                                      515.6
# Df Model:                          35
# Covariance Type:            nonrobust
# ===================================================================================
#                       coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------
# Age                -0.0106      0.009     -1.158      0.248      -0.029       0.007
# Min                -0.0217      0.011     -1.996      0.047      -0.043      -0.000
# Goals               0.0399      0.022      1.773      0.077      -0.004       0.084
# Goals.1            -4.9898      6.890     -0.724      0.470     -18.558       8.579
# Asists              0.0098      0.037      0.269      0.788      -0.062       0.082
# Asists.1           -4.4356      6.881     -0.645      0.520     -17.986       9.115
# GoalAstPer90        4.5283      6.886      0.658      0.511      -9.032      18.089
# 90s                 1.9621      0.980      2.002      0.046       0.032       3.893
# SCA                 0.0010      0.005      0.206      0.837      -0.009       0.011
# SCA90               0.0024      0.070      0.035      0.972      -0.135       0.140
# ShootPass           0.0012      0.006      0.193      0.847      -0.011       0.013
# ShootDrib          -0.0073      0.016     -0.466      0.641      -0.038       0.023
# GCA                -0.0154      0.034     -0.447      0.655      -0.083       0.053
# GCA90               0.6463      0.496      1.303      0.194      -0.330       1.623
# AssistPass         -0.0203      0.029     -0.688      0.492      -0.078       0.038
# AssistDrib         -0.0128      0.047     -0.269      0.788      -0.106       0.081
# CompletedPasses    -0.0010      0.000     -2.752      0.006      -0.002      -0.000
# PassCompRatio       0.0245      0.003      7.878      0.000       0.018       0.031
# TotDistPass      4.594e-05   1.83e-05      2.506      0.013    9.84e-06     8.2e-05
# ProgDistPass     2.594e-05   2.31e-05      1.122      0.263   -1.96e-05    7.15e-05
# Crosses             0.0008      0.002      0.501      0.617      -0.002       0.004
# PenaltyWon          0.0121      0.046      0.265      0.792      -0.078       0.102
# AerialWonRate      -0.0017      0.002     -0.844      0.399      -0.006       0.002
# ShootOnTarget      -0.0097      0.009     -1.078      0.282      -0.027       0.008
# ShootPer90          0.0216      0.087      0.247      0.805      -0.150       0.193
# GoalPerShoot        0.8984      0.558      1.610      0.109      -0.200       1.997
# TacklesWon          0.0121      0.004      2.904      0.004       0.004       0.020
# TklDribbling       -0.0151      0.007     -2.217      0.028      -0.029      -0.002
# Blocks              0.0011      0.003      0.361      0.718      -0.005       0.007
# SuccPressRatio      0.0010      0.005      0.190      0.850      -0.009       0.011
# MatchPlayed         0.0024      0.009      0.282      0.778      -0.014       0.019
# PointPerMatch       0.4435      0.070      6.334      0.000       0.306       0.581
# TouchPenArea        0.0044      0.001      3.103      0.002       0.002       0.007
# SuccDrib           -0.0005      0.002     -0.232      0.816      -0.005       0.004
# DribLegs            0.0270      0.017      1.568      0.118      -0.007       0.061
# ==============================================================================
# Omnibus:                        8.696   Durbin-Watson:                   2.097
# Prob(Omnibus):                  0.013   Jarque-Bera (JB):                8.595
# Skew:                           0.401   Prob(JB):                       0.0136
# Kurtosis:                       3.264   Cond. No.                     9.57e+06
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 9.57e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3, random_state=23)
lm = LinearRegression()
lm.fit(X_train,y_train)
print('score : ' +str( lm.score(X,y) )) 
predicted_bar = sns.jointplot(lm.predict(X), y, kind="reg")
plt.xlabel ('Predicted Values')
plt.ylabel ('Real Values')
'''predicted_bar.savefig('predicted_bar.svg')
'''
# Out:
# score : 0.4248502251318047
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# "predicted_bar.savefig('predicted_bar.svg')\n"

# %%
x_features = ['Age', 'Min', 'Goals', 'Goals.1', 'Asists',
       'Asists.1', 'GoalAstPer90', '90s', 'SCA', 'SCA90', 'ShootPass',
       'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
      'ShootOnTarget',        'GoalPerShoot',        'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea' ] 

X = df[ (df['PlayerType'] == 'Forward') ].reindex(columns=x_features)

y = df[ (df['PlayerType'] == 'Forward') ].loc[:,"log_t_value"]

model = sm.OLS(y, X, data=df)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            log_t_value   R-squared (uncentered):                   0.985
# Model:                            OLS   Adj. R-squared (uncentered):              0.979
# Method:                 Least Squares   F-statistic:                              175.0
# Date:                Sat, 09 Jan 2021   Prob (F-statistic):                    2.75e-46
# Time:                        15:36:04   Log-Likelihood:                         -45.274
# No. Observations:                  82   AIC:                                      134.5
# Df Residuals:                      60   BIC:                                      187.5
# Df Model:                          22
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Age               -0.0164      0.019     -0.877      0.384      -0.054       0.021
# Min               -0.0231      0.024     -0.972      0.335      -0.071       0.024
# Goals              0.0375      0.042      0.899      0.372      -0.046       0.121
# Goals.1           12.2349     16.365      0.748      0.458     -20.500      44.970
# Asists            -0.0167      0.089     -0.188      0.852      -0.195       0.161
# Asists.1          13.7060     16.350      0.838      0.405     -18.998      46.410
# GoalAstPer90     -12.9657     16.473     -0.787      0.434     -45.917      19.985
# 90s                2.1058      2.136      0.986      0.328      -2.168       6.379
# SCA                0.0074      0.013      0.563      0.575      -0.019       0.034
# SCA90              0.1106      0.118      0.939      0.352      -0.125       0.346
# ShootPass         -0.0104      0.015     -0.690      0.493      -0.041       0.020
# ShootDrib         -0.0039      0.025     -0.154      0.878      -0.054       0.047
# GCA               -0.0435      0.069     -0.634      0.528      -0.181       0.094
# GCA90              0.7271      1.121      0.648      0.519      -1.516       2.970
# AssistPass        -0.0104      0.050     -0.210      0.835      -0.110       0.089
# AssistDrib        -0.0198      0.074     -0.267      0.790      -0.168       0.128
# ShootOnTarget     -0.0173      0.014     -1.230      0.224      -0.045       0.011
# GoalPerShoot       2.5400      1.465      1.734      0.088      -0.390       5.470
# SuccPressRatio     0.0160      0.015      1.061      0.293      -0.014       0.046
# MatchPlayed        0.0241      0.016      1.496      0.140      -0.008       0.056
# PointPerMatch      0.8158      0.150      5.424      0.000       0.515       1.117
# TouchPenArea       0.0036      0.002      1.533      0.131      -0.001       0.008
# ==============================================================================
# Omnibus:                        4.989   Durbin-Watson:                   1.829
# Prob(Omnibus):                  0.083   Jarque-Bera (JB):                4.299
# Skew:                           0.440   Prob(JB):                        0.117
# Kurtosis:                       3.696   Cond. No.                     1.09e+06
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.09e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=23)
lm = LinearRegression()
lm.fit(X_train,y_train)
print('score : ' +str( lm.score(X,y) )) 
predicted_bar = sns.jointplot(lm.predict(X), y, kind="reg")
plt.xlabel ('Predicted Values')
plt.ylabel ('Real Values')
#predicted_bar.savefig('predicted_bar.svg')
# Out:
# score : 0.6186722024970996
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(27.0, 0.5, 'Real Values')

# %%
df['Age2'] = ( 33 - df['Age'] ) ** 2

# %%
df['Winner'] = ( df['MatchPlayed'] * df['PointPerMatch']  ) ** 2

# %%
x_features = ['Age', 'Min', 'Goals', 'Goals.1', 'Asists',
       'Asists.1', 'GoalAstPer90', '90s', 'SCA', 'SCA90', 'ShootPass',
       'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
      'ShootOnTarget',        'GoalPerShoot',        'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
             'Winner', 'Age2'] 

X = df[ (df['PlayerType'] == 'Forward') ].reindex(columns=x_features)

y = df[ (df['PlayerType'] == 'Forward') ].loc[:,"log_t_value"]

model = sm.OLS(y, X, data=df)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            log_t_value   R-squared (uncentered):                   0.988
# Model:                            OLS   Adj. R-squared (uncentered):              0.983
# Method:                 Least Squares   F-statistic:                              203.8
# Date:                Sat, 09 Jan 2021   Prob (F-statistic):                    2.04e-47
# Time:                        15:36:17   Log-Likelihood:                         -34.239
# No. Observations:                  82   AIC:                                      116.5
# Df Residuals:                      58   BIC:                                      174.2
# Df Model:                          24
# Covariance Type:            nonrobust
# ==================================================================================
#                      coef    std err          t      P>|t|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# Age                0.0346      0.026      1.311      0.195      -0.018       0.087
# Min               -0.0109      0.021     -0.510      0.612      -0.054       0.032
# Goals              0.0024      0.038      0.064      0.949      -0.074       0.079
# Goals.1           10.6996     14.595      0.733      0.466     -18.516      39.915
# Asists            -0.0294      0.081     -0.364      0.717      -0.191       0.132
# Asists.1          11.8542     14.600      0.812      0.420     -17.370      41.079
# GoalAstPer90     -10.7087     14.693     -0.729      0.469     -40.120      18.703
# 90s                0.9997      1.926      0.519      0.606      -2.856       4.856
# SCA                0.0069      0.012      0.567      0.573      -0.017       0.031
# SCA90              0.1095      0.105      1.040      0.303      -0.101       0.320
# ShootPass         -0.0076      0.014     -0.544      0.588      -0.036       0.020
# ShootDrib         -0.0162      0.023     -0.698      0.488      -0.063       0.030
# GCA                0.0225      0.063      0.358      0.722      -0.103       0.148
# GCA90             -0.3747      1.032     -0.363      0.718      -2.441       1.692
# AssistPass        -0.0159      0.044     -0.358      0.722      -0.105       0.073
# AssistDrib        -0.0404      0.066     -0.608      0.545      -0.173       0.093
# ShootOnTarget     -0.0134      0.013     -1.058      0.294      -0.039       0.012
# GoalPerShoot       2.7196      1.310      2.076      0.042       0.097       5.342
# SuccPressRatio    -0.0121      0.015     -0.778      0.440      -0.043       0.019
# MatchPlayed        0.0024      0.019      0.131      0.897      -0.035       0.040
# PointPerMatch      0.3200      0.255      1.257      0.214      -0.190       0.830
# TouchPenArea       0.0061      0.002      2.709      0.009       0.002       0.011
# Winner          7.483e-05   8.89e-05      0.841      0.404      -0.000       0.000
# Age2               0.0055      0.002      3.548      0.001       0.002       0.009
# ==============================================================================
# Omnibus:                       11.977   Durbin-Watson:                   2.008
# Prob(Omnibus):                  0.003   Jarque-Bera (JB):               20.055
# Skew:                           0.534   Prob(JB):                     4.42e-05
# Kurtosis:                       5.175   Cond. No.                     1.82e+06
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 1.82e+06. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=23)
lm = LinearRegression()
lm.fit(X_train,y_train)
print('score : ' +str( lm.score(X,y) )) 
# exp of the results to see their real life values 
x_chart = np.exp( lm.predict(X) ) 
y_chart = np.exp(y)
predicted_bar = sns.jointplot(x_chart, y_chart, kind="reg")
plt.xlabel ('Predicted Values')
plt.ylabel ('Real Values')

predicted_bar.savefig('real_predicted_bar.svg')
# Out:
# score : 0.6209415434304938
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df = pd.get_dummies(df,columns=['PlayerType'])
df = pd.get_dummies(df,columns=['League'])

# %%
df = df[df['PlayerType_Goalkeeper']==0]
df.drop('PlayerType_Goalkeeper', axis=1, inplace=True)

# %%
x_features = ['Age', 'Min', 'Goals', 'Goals.1', 'Asists',
       'Asists.1', 'GoalAstPer90', '90s', 'SCA', 'SCA90', 'ShootPass',
       'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
      'ShootOnTarget',        'GoalPerShoot',        'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
             'Winner', 'Age2','PlayerType_Defender', 'PlayerType_Forward',
         'PlayerType_Midfielder', 'League_Bundesliga',
       'League_La Liga', 'League_Ligue 1', 'League_Premier League',
       'League_Serie A'    ] 

X = df.reindex(columns=x_features)

y = df.loc[:,"log_t_value"]

model = sm.OLS(y, X, data=df)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log_t_value   R-squared:                       0.705
# Model:                            OLS   Adj. R-squared:                  0.668
# Method:                 Least Squares   F-statistic:                     19.31
# Date:                Sat, 09 Jan 2021   Prob (F-statistic):           1.47e-48
# Time:                        15:36:26   Log-Likelihood:                -53.656
# No. Observations:                 274   AIC:                             169.3
# Df Residuals:                     243   BIC:                             281.3
# Df Model:                          30
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Age                      -0.1428      0.037     -3.898      0.000      -0.215      -0.071
# Min                       0.0025      0.008      0.322      0.748      -0.013       0.018
# Goals                     0.0382      0.016      2.423      0.016       0.007       0.069
# Goals.1                   0.7298      4.833      0.151      0.880      -8.789      10.249
# Asists                    0.0206      0.024      0.841      0.401      -0.028       0.069
# Asists.1                  0.7852      4.836      0.162      0.871      -8.741      10.311
# GoalAstPer90             -0.8675      4.847     -0.179      0.858     -10.416       8.681
# 90s                      -0.2087      0.711     -0.293      0.769      -1.610       1.193
# SCA                      -0.0028      0.003     -0.796      0.427      -0.010       0.004
# SCA90                    -0.0255      0.042     -0.601      0.549      -0.109       0.058
# ShootPass                 0.0069      0.004      1.695      0.091      -0.001       0.015
# ShootDrib                 0.0092      0.008      1.180      0.239      -0.006       0.025
# GCA                       0.0064      0.024      0.272      0.786      -0.040       0.053
# GCA90                     0.2442      0.352      0.694      0.488      -0.449       0.937
# AssistPass               -0.0209      0.020     -1.069      0.286      -0.059       0.018
# AssistDrib               -0.0570      0.030     -1.875      0.062      -0.117       0.003
# ShootOnTarget            -0.0053      0.005     -0.958      0.339      -0.016       0.006
# GoalPerShoot              0.6306      0.366      1.723      0.086      -0.090       1.351
# SuccPressRatio            0.0155      0.005      3.173      0.002       0.006       0.025
# MatchPlayed              -0.0182      0.007     -2.435      0.016      -0.033      -0.003
# PointPerMatch             0.2997      0.075      3.970      0.000       0.151       0.448
# TouchPenArea              0.0005      0.001      0.560      0.576      -0.001       0.002
# Winner                 1.966e-05   2.22e-05      0.884      0.377   -2.41e-05    6.35e-05
# Age2                     -0.0051      0.002     -2.703      0.007      -0.009      -0.001
# PlayerType_Defender       3.5570      0.690      5.155      0.000       2.198       4.916
# PlayerType_Forward        3.6210      0.686      5.275      0.000       2.269       4.973
# PlayerType_Midfielder     3.6739      0.689      5.331      0.000       2.317       5.031
# League_Bundesliga         2.0438      0.411      4.975      0.000       1.235       2.853
# League_La Liga            2.2513      0.418      5.385      0.000       1.428       3.075
# League_Ligue 1            1.7489      0.415      4.217      0.000       0.932       2.566
# League_Premier League     2.6556      0.416      6.387      0.000       1.837       3.475
# League_Serie A            2.1524      0.413      5.210      0.000       1.339       2.966
# ==============================================================================
# Omnibus:                        4.490   Durbin-Watson:                   1.818
# Prob(Omnibus):                  0.106   Jarque-Bera (JB):                4.156
# Skew:                           0.274   Prob(JB):                        0.125
# Kurtosis:                       3.255   Cond. No.                     1.18e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 2.78e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=23)
lm = LinearRegression()
lm.fit(X_train,y_train)
print('score : ' +str( lm.score(X,y) )) 
# exp of the results to see their real life values 
'''x_chart = np.exp( lm.predict(X) ) 
y_chart = np.exp(y)
'''
predicted_bar = sns.jointplot(lm.predict(X), y, kind="reg")
plt.xlabel ('Predicted Values')
plt.ylabel ('Real Values')

predicted_bar.savefig('real_predicted_bar.svg')
# Out:
# score : 0.6892479664910155
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x_features = ['Age', 'Min', 'Goals', 'Goals.1', 'Asists',
       'Asists.1', 'GoalAstPer90', '90s', 'SCA', 'SCA90', 'ShootPass',
       'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
      'ShootOnTarget',        'GoalPerShoot',        'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
             'Winner', 'Age2','PlayerType_Defender', 'PlayerType_Forward',
         'PlayerType_Midfielder', 'League_Bundesliga',
       'League_La Liga', 'League_Ligue 1', 'League_Premier League',
       'League_Serie A'    ] 

X = df.reindex(columns=x_features)
y = df.loc[:,"log_t_value"]

# %%
X, X_test, y, y_test = train_test_split(X, y, test_size=.2, random_state=23)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=.25, random_state=23)

# %%
#set up the 3 models we're choosing from:

lm = LinearRegression()

#Feature scaling for train, val, and test so that we can run our ridge model on each
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train.values)
X_val_scaled = scaler.transform(X_val.values)
X_test_scaled = scaler.transform(X_test.values)

lm_reg = Ridge(alpha=1)

#Feature transforms for train, val, and test so that we can run our poly model on each
poly = PolynomialFeatures(degree=2) 

X_train_poly = poly.fit_transform(X_train.values)
X_val_poly = poly.transform(X_val.values)
X_test_poly = poly.transform(X_test.values)

lm_poly = LinearRegression()

# %%
#validate

lm.fit(X_train, y_train)
print(f'Linear Regression val R^2: {lm.score(X_val, y_val):.3f}')

lm_reg.fit(X_train_scaled, y_train)
print(f'Ridge Regression val R^2: {lm_reg.score(X_val_scaled, y_val):.3f}')

lm_poly.fit(X_train_poly, y_train)
print(f'Degree 2 polynomial regression val R^2: {lm_poly.score(X_val_poly, y_val):.3f}')
# Out:
# Linear Regression val R^2: 0.789
# Ridge Regression val R^2: 0.777
# Degree 2 polynomial regression val R^2: -11.338

# %%
lm.fit(X,y)
print(f'Linear Regression test R^2: {lm.score(X_test, y_test):.3f}')
lm_reg.fit(X,y)
print(f'Linear Regression test R^2: {lm_reg.score(X_test, y_test):.3f}')
lm_poly.fit(X,y)
print(f'Linear Regression test R^2: {lm_poly.score(X_test, y_test):.3f}')
# Out:
# Linear Regression test R^2: 0.495
# Linear Regression test R^2: 0.509
# Linear Regression test R^2: 0.495

# %%
df
# Out:
#                                   Name Position   Age   Min  Goals  Goals.1  \
# Aaron Ramsey              Aaron Ramsey       MF  28.0  1051      3    0.260
# Aaron Wan-Bissaka    Aaron Wan-Bissaka       DF  21.0  3070      0    0.000
# Abdou Diallo              Abdou Diallo       DF  23.0  1201      0    0.000
# Adil Aouchiche          Adil Aouchiche       MF  17.0    64      0    0.000
# Alessandro Bastoni  Alessandro Bastoni       DF  20.0  1921      2    0.090
# ...                                ...      ...   ...   ...    ...      ...
# Youssef En-Nesyri    Youssef En-Nesyri       FW  22.0  2181      8    0.355
# Youssouf Fofana        Youssouf Fofana       MF  20.0  1618      1    0.045
# Yussuf Poulsen          Yussuf Poulsen       FW  25.0  1222      5    0.370
# Ángel Correa              Ángel Correa       MF  24.0  2061      5    0.220
# Éder Militão              Éder Militão       DF  21.0  1022      0    0.000
#
#                     Asists  Asists.1  GoalAstPer90   90s  ...   Age2  \
# Aaron Ramsey             1     0.090         0.340  11.7  ...   25.0
# Aaron Wan-Bissaka        4     0.120         0.120  34.1  ...  144.0
# Abdou Diallo             1     0.070         0.070  13.3  ...  100.0
# Adil Aouchiche           0     0.000         0.000   0.7  ...  256.0
# Alessandro Bastoni       0     0.000         0.090  21.3  ...  169.0
# ...                    ...       ...           ...   ...  ...    ...
# Youssef En-Nesyri        2     0.065         0.420  24.2  ...  121.0
# Youssouf Fofana          2     0.150         0.195  18.0  ...  169.0
# Yussuf Poulsen           6     0.440         0.810  13.6  ...   64.0
# Ángel Correa             6     0.260         0.480  22.9  ...   81.0
# Éder Militão             0     0.000         0.000  11.4  ...  144.0
#
#                        Winner  PlayerType_Defender  PlayerType_Forward  \
# Aaron Ramsey        2916.0000                    0                   0
# Aaron Wan-Bissaka   3837.8025                    1                   0
# Abdou Diallo        1524.1216                    1                   0
# Adil Aouchiche         9.0000                    0                   0
# Alessandro Bastoni  2500.0000                    1                   0
# ...                       ...                  ...                 ...
# Youssef En-Nesyri   1850.7204                    0                   1
# Youssouf Fofana     1062.7600                    0                   0
# Yussuf Poulsen      1516.3236                    0                   1
# Ángel Correa        3489.2649                    0                   0
# Éder Militão        1221.5025                    1                   0
#
#                     PlayerType_Midfielder  League_Bundesliga  League_La Liga  \
# Aaron Ramsey                            1                  0               0
# Aaron Wan-Bissaka                       0                  0               0
# Abdou Diallo                            0                  0               0
# Adil Aouchiche                          1                  0               0
# Alessandro Bastoni                      0                  0               0
# ...                                   ...                ...             ...
# Youssef En-Nesyri                       0                  0               1
# Youssouf Fofana                         1                  0               0
# Yussuf Poulsen                          0                  1               0
# Ángel Correa                            1                  0               1
# Éder Militão                            0                  0               1
#
#                     League_Ligue 1  League_Premier League  League_Serie A
# Aaron Ramsey                     0                      0               1
# Aaron Wan-Bissaka                0                      1               0
# Abdou Diallo                     1                      0               0
# Adil Aouchiche                   1                      0               0
# Alessandro Bastoni               0                      0               1
# ...                            ...                    ...             ...
# Youssef En-Nesyri                0                      0               0
# Youssouf Fofana                  1                      0               0
# Yussuf Poulsen                   0                      0               0
# Ángel Correa                     0                      0               0
# Éder Militão                     0                      0               0
#
# [272 rows x 50 columns]

# %%
x_features = ['Age', 'Min', 'Goals', 'Goals.1', 'Asists',
       'Asists.1', 'GoalAstPer90', '90s', 'SCA', 'SCA90', 'ShootPass',
       'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
      'ShootOnTarget',        'GoalPerShoot',        'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
             'Winner', 'Age2', 'PlayerType_Forward',
         'PlayerType_Midfielder', 'League_Bundesliga',
       'League_La Liga', 'League_Ligue 1', 'League_Premier League',
       'League_Serie A'    ] 

X = df[df['PlayerType_Defender']==0].reindex(columns=x_features)

y = df[df['PlayerType_Defender']==0].loc[:,"log_t_value"]

model = sm.OLS(y, X, data=df)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log_t_value   R-squared:                       0.762
# Model:                            OLS   Adj. R-squared:                  0.718
# Method:                 Least Squares   F-statistic:                     17.29
# Date:                Sat, 09 Jan 2021   Prob (F-statistic):           1.91e-35
# Time:                        15:36:46   Log-Likelihood:                -25.638
# No. Observations:                 187   AIC:                             111.3
# Df Residuals:                     157   BIC:                             208.2
# Df Model:                          29
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Age                      -0.1614      0.042     -3.834      0.000      -0.245      -0.078
# Min                       0.0041      0.009      0.445      0.657      -0.014       0.022
# Goals                     0.0368      0.017      2.210      0.029       0.004       0.070
# Goals.1                  -4.2605      5.823     -0.732      0.465     -15.763       7.242
# Asists                    0.0247      0.029      0.848      0.398      -0.033       0.082
# Asists.1                 -4.3939      5.799     -0.758      0.450     -15.848       7.060
# GoalAstPer90              4.2694      5.826      0.733      0.465      -7.238      15.777
# 90s                      -0.3525      0.831     -0.424      0.672      -1.993       1.288
# SCA                      -0.0039      0.004     -0.991      0.323      -0.012       0.004
# SCA90                    -0.0043      0.053     -0.082      0.935      -0.109       0.100
# ShootPass                 0.0092      0.005      2.044      0.043       0.000       0.018
# ShootDrib                 0.0006      0.008      0.074      0.941      -0.016       0.017
# GCA                       0.0011      0.026      0.043      0.965      -0.049       0.052
# GCA90                     0.3460      0.373      0.929      0.354      -0.390       1.082
# AssistPass               -0.0226      0.021     -1.084      0.280      -0.064       0.019
# AssistDrib               -0.0365      0.033     -1.119      0.265      -0.101       0.028
# ShootOnTarget            -0.0090      0.006     -1.565      0.120      -0.020       0.002
# GoalPerShoot              0.3363      0.493      0.683      0.496      -0.637       1.309
# SuccPressRatio            0.0092      0.006      1.450      0.149      -0.003       0.022
# MatchPlayed              -0.0185      0.009     -2.118      0.036      -0.036      -0.001
# PointPerMatch             0.1811      0.109      1.665      0.098      -0.034       0.396
# TouchPenArea              0.0013      0.001      1.396      0.165      -0.001       0.003
# Winner                 5.426e-05    3.8e-05      1.428      0.155   -2.08e-05       0.000
# Age2                     -0.0063      0.002     -2.876      0.005      -0.011      -0.002
# PlayerType_Forward        4.7204      0.914      5.164      0.000       2.915       6.526
# PlayerType_Midfielder     4.8167      0.921      5.230      0.000       2.997       6.636
# League_Bundesliga         1.7832      0.365      4.887      0.000       1.063       2.504
# League_La Liga            1.9358      0.373      5.190      0.000       1.199       2.673
# League_Ligue 1            1.5240      0.372      4.093      0.000       0.789       2.260
# League_Premier League     2.4079      0.372      6.471      0.000       1.673       3.143
# League_Serie A            1.8862      0.369      5.108      0.000       1.157       2.616
# ==============================================================================
# Omnibus:                       14.523   Durbin-Watson:                   2.039
# Prob(Omnibus):                  0.001   Jarque-Bera (JB):               16.176
# Skew:                           0.605   Prob(JB):                     0.000307
# Kurtosis:                       3.781   Cond. No.                     1.16e+16
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 1.75e-23. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
 
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=23)
lm = LinearRegression()
lm.fit(X_train,y_train)
print('score : ' +str( lm.score(X,y) )) 
# exp of the results to see their real life values 
'''x_chart = np.exp( lm.predict(X) ) 
y_chart = np.exp(y)
'''
predicted_bar = sns.jointplot(lm.predict(X), y, kind="reg")
plt.xlabel ('Predicted Values')
plt.ylabel ('Real Values')

predicted_bar.savefig('forvetmid_predicted_bar.svg')
# Out:
# score : 0.7480083533192421
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
X, X_test, y, y_test = train_test_split(X, y, test_size=.2, random_state=23)
X_train, X_val, y_train, y_val = train_test_split(X, y, test_size=.25, random_state=23)

x_features = [  'Goals',   'Asists',
              'ShootDrib', 'GCA',   'AssistPass', 'AssistDrib',
      'ShootOnTarget',            'SuccPressRatio', 'MatchPlayed', 'PointPerMatch',  
             'Winner', 'Age2', 'PlayerType_Forward',
         'PlayerType_Midfielder', 'League_Bundesliga',
       'League_La Liga', 'League_Ligue 1', 'League_Premier League',
       'League_Serie A'    ] 

X = df[df['PlayerType_Defender']==0].reindex(columns=x_features)

y = df[df['PlayerType_Defender']==0].loc[:,"log_t_value"]
#set up the 3 models we're choosing from:

lm = LinearRegression()

#Feature scaling for train, val, and test so that we can run our ridge model on each
scaler = StandardScaler()

X_train_scaled = scaler.fit_transform(X_train.values)
X_val_scaled = scaler.transform(X_val.values)
X_test_scaled = scaler.transform(X_test.values)

lm_reg = Ridge(alpha=1)

#Feature transforms for train, val, and test so that we can run our poly model on each
poly = PolynomialFeatures(degree=2) 

X_train_poly = poly.fit_transform(X_train.values)
X_val_poly = poly.transform(X_val.values)
X_test_poly = poly.transform(X_test.values)

lm_poly = LinearRegression()

#validate

lm.fit(X_train, y_train)
print(f'Linear Regression val R^2: {lm.score(X_val, y_val):.3f}')

lm_reg.fit(X_train_scaled, y_train)
print(f'Ridge Regression val R^2: {lm_reg.score(X_val_scaled, y_val):.3f}')

lm_poly.fit(X_train_poly, y_train)
print(f'Degree 2 polynomial regression val R^2: {lm_poly.score(X_val_poly, y_val):.3f}')
# Out:
# Linear Regression val R^2: 0.529
# Ridge Regression val R^2: 0.535
# Degree 2 polynomial regression val R^2: -6.450

# %%
x_features = [ 'Goals',   'Asists',
              'ShootDrib', 'GCA',   'AssistPass', 'AssistDrib',
      'ShootOnTarget',            'SuccPressRatio', 'MatchPlayed', 'PointPerMatch',  
             'Winner', 'Age2', 'PlayerType_Forward',
         'PlayerType_Midfielder', 'League_Bundesliga',
       'League_La Liga', 'League_Ligue 1', 'League_Premier League',
       'League_Serie A'     ] 

X = df[df['PlayerType_Defender']==0].reindex(columns=x_features)

y = df[df['PlayerType_Defender']==0].loc[:,"log_t_value"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=23)
lm = LinearRegression()
lm.fit(X_train,y_train)
print('score : ' +str( lm.score(X,y) )) 
# exp of the results to see their real life values 
'''x_chart = np.exp( lm.predict(X) ) 
y_chart = np.exp(y)
'''
predicted_bar = sns.jointplot(lm.predict(X), y, kind="reg")
plt.xlabel ('Predicted Values')
plt.ylabel ('Real Values')

predicted_bar.savefig('forvetmid_predicted_bar.svg')
# Out:
# score : 0.6906313320926394
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x_features = [  'Goals',  'Asists',  'MatchPlayed', 'PointPerMatch' , 'Winner', 'Age2',    ] 

X = df[df['PlayerType_Defender']==0].reindex(columns=x_features)

y = df[df['PlayerType_Defender']==0].loc[:,"log_t_value"]

model = sm.OLS(y, X, data=df)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                                  OLS Regression Results
# =======================================================================================
# Dep. Variable:            log_t_value   R-squared (uncentered):                   0.978
# Model:                            OLS   Adj. R-squared (uncentered):              0.977
# Method:                 Least Squares   F-statistic:                              1324.
# Date:                Sat, 09 Jan 2021   Prob (F-statistic):                   1.23e-146
# Time:                        15:37:01   Log-Likelihood:                         -134.12
# No. Observations:                 187   AIC:                                      280.2
# Df Residuals:                     181   BIC:                                      299.6
# Df Model:                           6
# Covariance Type:            nonrobust
# =================================================================================
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# Goals             0.0315      0.007      4.205      0.000       0.017       0.046
# Asists            0.0059      0.014      0.411      0.681      -0.022       0.034
# MatchPlayed       0.0508      0.004     12.588      0.000       0.043       0.059
# PointPerMatch     1.0780      0.058     18.485      0.000       0.963       1.193
# Winner           -0.0002   3.15e-05     -4.794      0.000      -0.000   -8.88e-05
# Age2              0.0022      0.001      3.413      0.001       0.001       0.004
# ==============================================================================
# Omnibus:                        4.265   Durbin-Watson:                   1.821
# Prob(Omnibus):                  0.119   Jarque-Bera (JB):                4.490
# Skew:                           0.194   Prob(JB):                        0.106
# Kurtosis:                       3.652   Cond. No.                     4.68e+03
# ==============================================================================
#
# Notes:
# [1] R² is computed without centering (uncentered) since the model does not contain a constant.
# [2] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [3] The condition number is large, 4.68e+03. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
x_features = ['Age', 'Min', 'Goals', 'Goals.1', 'Asists',
       'Asists.1', 'GoalAstPer90', '90s', 'SCA', 'SCA90', 'ShootPass',
       'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
      'ShootOnTarget',        'GoalPerShoot',        'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
             'Winner', 'Age2', 'PlayerType_Forward',
         'PlayerType_Midfielder', 'League_Bundesliga',
       'League_La Liga', 'League_Ligue 1', 'League_Premier League',
       'League_Serie A'    ] 

X = df[df['PlayerType_Midfielder']==1].reindex(columns=x_features)

y = df[df['PlayerType_Midfielder']==1].loc[:,"log_t_value"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=23)
lm = LinearRegression()
lm.fit(X_train,y_train)
print('score : ' +str( lm.score(X,y) )) 
# exp of the results to see their real life values 
'''x_chart = np.exp( lm.predict(X) ) 
y_chart = np.exp(y)
'''
predicted_bar = sns.jointplot(lm.predict(X), y, kind="reg")
plt.xlabel ('Predicted Values')
plt.ylabel ('Real Values')

predicted_bar.savefig('74mid_predicted_bar.svg')  

X = df[df['PlayerType_Forward']==1].reindex(columns=x_features)

y = df[df['PlayerType_Forward']==1].loc[:,"log_t_value"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=23)
lm = LinearRegression()
lm.fit(X_train,y_train)
print('score : ' +str( lm.score(X,y) )) 
# exp of the results to see their real life values 
'''x_chart = np.exp( lm.predict(X) ) 
y_chart = np.exp(y)
'''
predicted_bar = sns.jointplot(lm.predict(X), y, kind="reg")
plt.xlabel ('Predicted Values')
plt.ylabel ('Real Values')

predicted_bar.savefig('83forvet_predicted_bar.svg')
# Out:
# score : 0.6870677453805456
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# score : 0.8370754669226547
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x_features = ['Age', 'Min', 'Goals', 'Goals.1', 'Asists',
       'Asists.1', 'GoalAstPer90', '90s', 'SCA', 'SCA90', 'ShootPass',
      'ShootOnTarget',       'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
             'Winner', 'Age2', 
         'PlayerType_Midfielder', 'League_Bundesliga',
       'League_La Liga', 'League_Ligue 1', 'League_Premier League',
       'League_Serie A'    ] 

X = df[df['PlayerType_Forward']==1].reindex(columns=x_features)

y = df[df['PlayerType_Forward']==1].loc[:,"log_t_value"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=23)
lm = LinearRegression()
lm.fit(X_train,y_train)
print('score : ' +str( lm.score(X,y) )) 
# exp of the results to see their real life values 
'''x_chart = np.exp( lm.predict(X) ) 
y_chart = np.exp(y)
'''
predicted_bar = sns.jointplot(lm.predict(X), y, kind="reg")
plt.xlabel ('Predicted Values')
plt.ylabel ('Real Values')

predicted_bar.savefig('833forvet_predicted_bar.svg')
# Out:
# score : 0.8325552510905646
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x_chart = np.exp( lm.predict(X) ) 
y_chart = np.exp(y)

predicted_bar = sns.jointplot(x_chart, y_chart, kind="reg")
plt.xlabel ('Predicted Values')
plt.ylabel ('Real Values')

predicted_bar.savefig('833_real_forvet_predicted_bar.svg')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x_features = [  'Min', 'Goals',  'Asists',
          'ShootDrib','AssistPass', 'AssistDrib',
      'ShootOnTarget',        'GoalPerShoot',        'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
             'Winner', 'Age2',  'League_Bundesliga',
       'League_La Liga', 'League_Ligue 1', 'League_Premier League',
       'League_Serie A'   ] 

X =  df[df['PlayerType_Defender']==0].reindex(columns=x_features)

y =  df[df['PlayerType_Defender']==0].loc[:,"log_t_value"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=23)
lm = LinearRegression()
lm.fit(X_train,y_train)
print('score : ' +str( lm.score(X,y) )) 
# exp of the results to see their real life values 
'''x_chart = np.exp( lm.predict(X) ) 
y_chart = np.exp(y)
'''
predicted_bar = sns.jointplot(lm.predict(X), y, kind="reg")
plt.xlabel ('Predicted Values')
plt.ylabel ('Real Values')

predicted_bar.savefig('070_all_df_predicted_bar.svg')
# Out:
# score : 0.718065555171256
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 289 entries, Aaron Ramsey to Éder Militão
# Data columns (total 42 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             289 non-null    object
#  1   Position         289 non-null    object
#  2   Age              289 non-null    float64
#  3   Min              289 non-null    int64
#  4   Goals            289 non-null    int64
#  5   Goals.1          289 non-null    float64
#  6   Asists           289 non-null    int64
#  7   Asists.1         289 non-null    float64
#  8   GoalAstPer90     289 non-null    float64
#  9   90s              289 non-null    float64
#  10  SCA              289 non-null    float64
#  11  SCA90            289 non-null    float64
#  12  ShootPass        289 non-null    float64
#  13  ShootDrib        289 non-null    float64
#  14  GCA              289 non-null    float64
#  15  GCA90            289 non-null    float64
#  16  AssistPass       289 non-null    float64
#  17  AssistDrib       289 non-null    float64
#  18  CompletedPasses  289 non-null    float64
#  19  PassCompRatio    289 non-null    float64
#  20  TotDistPass      289 non-null    float64
#  21  ProgDistPass     289 non-null    float64
#  22  Crosses          289 non-null    int64
#  23  PenaltyWon       289 non-null    float64
#  24  AerialWonRate    289 non-null    float64
#  25  ShootOnTarget    289 non-null    int64
#  26  ShootPer90       289 non-null    float64
#  27  GoalPerShoot     289 non-null    float64
#  28  TacklesWon       289 non-null    int64
#  29  TklDribbling     289 non-null    float64
#  30  Blocks           289 non-null    float64
#  31  SuccPressRatio   289 non-null    float64
#  32  MatchPlayed      289 non-null    int64
#  33  PointPerMatch    289 non-null    float64
#  34  TouchPenArea     289 non-null    float64
#  35  SuccDrib         289 non-null    float64
#  36  DribLegs         289 non-null    float64
#  37  PlayerType       289 non-null    object
#  38  Value            289 non-null    float64
#  39  t_value          289 non-null    object
#  40  League           289 non-null    object
#  41  v_value          289 non-null    float64
# dtypes: float64(30), int64(7), object(5)
# memory usage: 107.1+ KB

# %%
from sklearn.model_selection import cross_val_score
lm = LinearRegression()

cross_val_score(lm, X, y, # estimator, features, target
                cv=5, # number of folds 
                scoring='r2') # scoring metric
# Out:
# array([0.68366359, 0.62289403, 0.57799775, 0.76219478, 0.69389848])

# %%
kf = KFold(n_splits=5, shuffle=True, random_state = 71)
cross_val_score(lm, X, y, cv=kf, scoring='r2')
# Out:
# array([0.63024625, 0.74543679, 0.61227608, 0.5857625 , 0.59543835])

# %%
from sklearn.model_selection import cross_val_score

kf = KFold(n_splits=5, shuffle=True, random_state = 77)

print(np.mean(cross_val_score(lm, X, y, cv=kf, scoring='r2')))
print(np.mean(cross_val_score(lm_reg, X, y, cv=kf, scoring='r2')))
print(np.mean(cross_val_score(lm_poly, X, y, cv=kf, scoring='r2')))
# Out:
# 0.6320418597314889
# 0.6648520445015308
# 0.6320418597314889

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_test_scaled = scaler.transform(X_test)

lm_reg = Ridge(alpha=1)
lm_reg.fit(X_scaled,y)
print(f'Ridge Regression test R^2: {lm_reg.score(X_test_scaled, y_test):.3f}')
# Out:
# Ridge Regression test R^2: 0.789

# %%
plt.figure(figsize=(15,15))
sns.catplot(x = 'Age',y='v_value',data=df, color='blue')

# %%
def age_grouper(x):
    if x['Age'] < 20 :
        return(1)
    if x['Age'] <= 24 :
        return(2)
    if x['Age'] <= 28 :
        return(2)
    if x['Age'] <= 32 :
        return(4)
    else:
        return(5)

# %%
# https://stackoverflow.com/questions/26886653/pandas-create-new-column-based-on-values-from-other-columns-apply-a-function-o 
# todo : sonra daha başka çözümlere bakacağım. 

df['AgeGroups'] = df.apply(lambda row: age_grouper(row), axis=1)
df.head(2)
# Out:
#                                 Name Position   Age   Min  Goals  Goals.1  \
# Aaron Ramsey            Aaron Ramsey       MF  28.0  1051      3     0.26
# Aaron Wan-Bissaka  Aaron Wan-Bissaka       DF  21.0  3070      0     0.00
#
#                    Asists  Asists.1  GoalAstPer90   90s  ...     Winner  \
# Aaron Ramsey            1      0.09          0.34  11.7  ...  2916.0000
# Aaron Wan-Bissaka       4      0.12          0.12  34.1  ...  3837.8025
#
#                    PlayerType_Defender  PlayerType_Forward  \
# Aaron Ramsey                         0                   0
# Aaron Wan-Bissaka                    1                   0
#
#                    PlayerType_Midfielder  League_Bundesliga  League_La Liga  \
# Aaron Ramsey                           1                  0               0
# Aaron Wan-Bissaka                      0                  0               0
#
#                    League_Ligue 1  League_Premier League  League_Serie A  \
# Aaron Ramsey                    0                      0               1
# Aaron Wan-Bissaka               0                      1               0
#
#                    AgeGroups
# Aaron Ramsey               2
# Aaron Wan-Bissaka          2
#
# [2 rows x 52 columns]

# %%
df
# Out:
#                                 Name Position   Age   Min  Goals   Goals.1  \
# Aaron Ramsey            Aaron Ramsey       MF  28.0  1051      3  0.260000
# Aaron Wan-Bissaka  Aaron Wan-Bissaka       DF  21.0  3070      0  0.000000
# Abdou Diallo            Abdou Diallo       DF  23.0  1201      0  0.000000
# Adama Traoré            Adama Traoré       MF  24.0  7274     10  0.076667
# Adil Aouchiche        Adil Aouchiche       MF  17.0    64      0  0.000000
# ...                              ...      ...   ...   ...    ...       ...
# Youssef En-Nesyri  Youssef En-Nesyri       FW  22.0  2181      8  0.355000
# Youssouf Fofana      Youssouf Fofana       MF  20.0  1618      1  0.045000
# Yussuf Poulsen        Yussuf Poulsen       FW  25.0  1222      5  0.370000
# Ángel Correa            Ángel Correa       MF  24.0  2061      5  0.220000
# Éder Militão            Éder Militão       DF  21.0  1022      0  0.000000
#
#                    Asists  Asists.1  GoalAstPer90   90s  ...      Winner  \
# Aaron Ramsey            1  0.090000         0.340  11.7  ...   2916.0000
# Aaron Wan-Bissaka       4  0.120000         0.120  34.1  ...   3837.8025
# Abdou Diallo            1  0.070000         0.070  13.3  ...   1524.1216
# Adama Traoré           26  0.223333         0.300  80.8  ...  13857.9984
# Adil Aouchiche          0  0.000000         0.000   0.7  ...      9.0000
# ...                   ...       ...           ...   ...  ...         ...
# Youssef En-Nesyri       2  0.065000         0.420  24.2  ...   1850.7204
# Youssouf Fofana         2  0.150000         0.195  18.0  ...   1062.7600
# Yussuf Poulsen          6  0.440000         0.810  13.6  ...   1516.3236
# Ángel Correa            6  0.260000         0.480  22.9  ...   3489.2649
# Éder Militão            0  0.000000         0.000  11.4  ...   1221.5025
#
#                    PlayerType_Defender  PlayerType_Forward  \
# Aaron Ramsey                         0                   0
# Aaron Wan-Bissaka                    1                   0
# Abdou Diallo                         1                   0
# Adama Traoré                         0                   0
# Adil Aouchiche                       0                   0
# ...                                ...                 ...
# Youssef En-Nesyri                    0                   1
# Youssouf Fofana                      0                   0
# Yussuf Poulsen                       0                   1
# Ángel Correa                         0                   0
# Éder Militão                         1                   0
#
#                    PlayerType_Midfielder  League_Bundesliga  League_La Liga  \
# Aaron Ramsey                           1                  0               0
# Aaron Wan-Bissaka                      0                  0               0
# Abdou Diallo                           0                  0               0
# Adama Traoré                           1                  0               0
# Adil Aouchiche                         1                  0               0
# ...                                  ...                ...             ...
# Youssef En-Nesyri                      0                  0               1
# Youssouf Fofana                        1                  0               0
# Yussuf Poulsen                         0                  1               0
# Ángel Correa                           1                  0               1
# Éder Militão                           0                  0               1
#
#                    League_Ligue 1  League_Premier League  League_Serie A  \
# Aaron Ramsey                    0                      0               1
# Aaron Wan-Bissaka               0                      1               0
# Abdou Diallo                    1                      0               0
# Adama Traoré                    1                      0               0
# Adil Aouchiche                  1                      0               0
# ...                           ...                    ...             ...
# Youssef En-Nesyri               0                      0               0
# Youssouf Fofana                 1                      0               0
# Yussuf Poulsen                  0                      0               0
# Ángel Correa                    0                      0               0
# Éder Militão                    0                      0               0
#
#                    AgeGroups
# Aaron Ramsey               2
# Aaron Wan-Bissaka          2
# Abdou Diallo               2
# Adama Traoré               2
# Adil Aouchiche             1
# ...                      ...
# Youssef En-Nesyri          2
# Youssouf Fofana            2
# Yussuf Poulsen             2
# Ángel Correa               2
# Éder Militão               2
#
# [274 rows x 52 columns]

# %%
x_features = [  'Min', 'Goals',  'Asists',
          'ShootDrib','AssistPass', 'AssistDrib',
      'ShootOnTarget',        'GoalPerShoot',        'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
             'Winner', 'League_Bundesliga',
       'League_La Liga', 'League_Ligue 1', 'League_Premier League',
       'League_Serie A'  , 'AgeGroups'  ] 

X =  df[df['PlayerType_Defender']==0].reindex(columns=x_features)

y =  df[df['PlayerType_Defender']==0].loc[:,"log_t_value"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=23)
lm = LinearRegression()
lm.fit(X_train,y_train)
print('score : ' +str( lm.score(X,y) )) 
# exp of the results to see their real life values 
'''x_chart = np.exp( lm.predict(X) ) 
y_chart = np.exp(y)
'''
predicted_bar = sns.jointplot(lm.predict(X), y, kind="reg")
plt.xlabel ('Predicted Values')
plt.ylabel ('Real Values')

#predicted_bar.savefig('072_all_df_predicted_bar.svg')
# Out:
# score : 0.7271920218681982
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# Text(27.0, 0.5, 'Real Values')

# %%
x_features = [  'Min', 'Goals', 'Goals.1', 'Asists',
       'Asists.1', 'GoalAstPer90', '90s', 'SCA', 'SCA90', 'ShootPass',
      'ShootOnTarget',       'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
             'Winner', 'AgeGroups', 
         'PlayerType_Midfielder', 'League_Bundesliga',
       'League_La Liga', 'League_Ligue 1', 'League_Premier League',
       'League_Serie A'    ] 

X = df[df['PlayerType_Forward']==1].reindex(columns=x_features)

y = df[df['PlayerType_Forward']==1].loc[:,"log_t_value"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=23)
lm = LinearRegression()
lm.fit(X_train,y_train)
print('score : ' +str( lm.score(X,y) )) 
# exp of the results to see their real life values 
'''x_chart = np.exp( lm.predict(X) ) 
y_chart = np.exp(y)
'''
predicted_bar = sns.jointplot(lm.predict(X), y, kind="reg", color = 'Purple')
plt.xlabel ('Predicted Values')
plt.ylabel ('Real Values')

predicted_bar.savefig('079forvet_predicted_bar.svg')
# Out:
# score : 0.777037171809805
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(

# %%
x_features = [  'Min', 'Goals',  'Asists',
        'SCA',   'ShootPass',
      'ShootOnTarget',       'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
             'Winner', 'AgeGroups', 
         'PlayerType_Midfielder', 'League_Bundesliga',
       'League_La Liga', 'League_Ligue 1', 'League_Premier League',
       'League_Serie A'    ] 

X = df[df['PlayerType_Forward']==1].reindex(columns=x_features)

y = df[df['PlayerType_Forward']==1].loc[:,"log_t_value"]

model = sm.OLS(y, X, data=df)
results = model.fit()
results.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:            log_t_value   R-squared:                       0.819
# Model:                            OLS   Adj. R-squared:                  0.778
# Method:                 Least Squares   F-statistic:                     19.94
# Date:                Sat, 09 Jan 2021   Prob (F-statistic):           6.89e-19
# Time:                        15:40:09   Log-Likelihood:                -7.2806
# No. Observations:                  82   AIC:                             46.56
# Df Residuals:                      66   BIC:                             85.07
# Df Model:                          15
# Covariance Type:            nonrobust
# =========================================================================================
#                             coef    std err          t      P>|t|      [0.025      0.975]
# -----------------------------------------------------------------------------------------
# Min                       0.0002      0.000      1.452      0.151   -6.59e-05       0.000
# Goals                     0.0208      0.015      1.428      0.158      -0.008       0.050
# Asists                   -0.0026      0.019     -0.137      0.892      -0.041       0.035
# SCA                       0.0010      0.005      0.215      0.831      -0.009       0.011
# ShootPass                -0.0004      0.007     -0.063      0.950      -0.014       0.013
# ShootOnTarget            -0.0033      0.008     -0.404      0.687      -0.020       0.013
# MatchPlayed              -0.0086      0.013     -0.655      0.515      -0.035       0.018
# PointPerMatch             0.4001      0.168      2.380      0.020       0.065       0.736
# TouchPenArea              0.0020      0.001      1.398      0.167      -0.001       0.005
# Winner                 -3.42e-06   5.72e-05     -0.060      0.953      -0.000       0.000
# AgeGroups                -0.2277      0.068     -3.344      0.001      -0.364      -0.092
# PlayerType_Midfielder  1.097e-15   1.74e-16      6.317      0.000     7.5e-16    1.44e-15
# League_Bundesliga         2.5479      0.451      5.649      0.000       1.647       3.448
# League_La Liga            2.5066      0.483      5.195      0.000       1.543       3.470
# League_Ligue 1            2.1280      0.439      4.847      0.000       1.252       3.005
# League_Premier League     3.1130      0.458      6.790      0.000       2.198       4.028
# League_Serie A            2.5221      0.470      5.364      0.000       1.583       3.461
# ==============================================================================
# Omnibus:                       21.999   Durbin-Watson:                   1.638
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):               32.566
# Skew:                           1.130   Prob(JB):                     8.48e-08
# Kurtosis:                       5.103   Cond. No.                     4.49e+20
# ==============================================================================
#
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The smallest eigenvalue is 4.88e-33. This might indicate that there are
# strong multicollinearity problems or that the design matrix is singular.
# """

# %%
x_features = [  'Goals',   'Asists',
        'GoalAstPer90',  'SCA',   'ShootPass',
       'ShootDrib', 'GCA',   'AssistPass', 'AssistDrib',
       'Crosses', 'PenaltyWon', 'AerialWonRate', 'ShootOnTarget', 'ShootPer90',
       'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
       'SuccDrib', 'DribLegs',   
       'Winner',  'League_Bundesliga', 'League_La Liga',
       'League_Ligue 1', 'League_Premier League', 'League_Serie A',
       'AgeGroups'  ] 


X = df[ (df['MatchPlayed']>20 ) & (df['PlayerType_Forward']==1) ].reindex(columns=x_features)

y = df[ (df['MatchPlayed']>20 ) & (df['PlayerType_Forward']==1) ].loc[:,"log_t_value"]

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.2, random_state=23)
lm = LinearRegression()
lm.fit(X_train,y_train)
print('score : ' +str( lm.score(X,y) )) 
# exp of the results to see their real life values 
'''x_chart = np.exp( lm.predict(X) ) 
y_chart = np.exp(y)
'''
predicted_bar = sns.jointplot( x= lm.predict(X), y= y ,marker=".", marginal_kws=dict(bins=25, fill=False) , kind="reg" )
plt.xlabel ('Predicted Values')
plt.ylabel ('Real Values')
#predicted_bar.savefig('0791forvet_predicted_bar.svg')
# Out:
# score : 0.8534235513527565
# Text(27.0, 0.5, 'Real Values')

# %%
df_forvet = df[ (df['MatchPlayed']>20 ) & (df['PlayerType_Forward']==1) ]
df_forvet['tahmin'] = lm.predict(X)
# Out:
# <ipython-input-417-0d0ed28db466>:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_forvet['tahmin'] = lm.predict(X)

# %%
df_forvet['Prediction'] = np.exp(df_forvet['tahmin'])
# Out:
# <ipython-input-418-97d89c413d3c>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_forvet['Prediction'] = np.exp(df_forvet['tahmin'])

# %%
df_forvet
# Out:
#                                     Name Position   Age   Min  Goals  Goals.1  \
# Alexander Isak            Alexander Isak       FW  19.0  1507      9    0.540
# Alexandre Lacazette  Alexandre Lacazette       FW  28.0  1874     10    0.480
# Andrea Belotti            Andrea Belotti       FW  25.0  3008     16    0.480
# Andrea Petagna            Andrea Petagna       FW  24.0  3032     12    0.360
# André Silva                  André Silva       FW  23.0  1635     12    0.345
# ...                                  ...      ...   ...   ...    ...      ...
# Victor Osimhen            Victor Osimhen       FW  20.0  2287     13    0.510
# Willian José                Willian José       FW  27.0  2011     11    0.490
# Wout Weghorst              Wout Weghorst       FW  26.0  2739     16    0.530
# Youssef En-Nesyri      Youssef En-Nesyri       FW  22.0  2181      8    0.355
# Yussuf Poulsen            Yussuf Poulsen       FW  25.0  1222      5    0.370
#
#                      Asists  Asists.1  GoalAstPer90   90s  ...  \
# Alexander Isak            1     0.060          0.60  16.7  ...
# Alexandre Lacazette       4     0.190          0.67  20.8  ...
# Andrea Belotti            3     0.090          0.57  33.4  ...
# Andrea Petagna            1     0.030          0.39  33.7  ...
# André Silva               3     0.085          0.43  18.2  ...
# ...                     ...       ...           ...   ...  ...
# Victor Osimhen            4     0.160          0.67  25.4  ...
# Willian José              1     0.040          0.54  22.3  ...
# Wout Weghorst             3     0.100          0.62  30.4  ...
# Youssef En-Nesyri         2     0.065          0.42  24.2  ...
# Yussuf Poulsen            6     0.440          0.81  13.6  ...
#
#                      PlayerType_Forward  PlayerType_Midfielder  \
# Alexander Isak                        1                      0
# Alexandre Lacazette                   1                      0
# Andrea Belotti                        1                      0
# Andrea Petagna                        1                      0
# André Silva                           1                      0
# ...                                 ...                    ...
# Victor Osimhen                        1                      0
# Willian José                          1                      0
# Wout Weghorst                         1                      0
# Youssef En-Nesyri                     1                      0
# Yussuf Poulsen                        1                      0
#
#                      League_Bundesliga  League_La Liga  League_Ligue 1  \
# Alexander Isak                       0               1               0
# Alexandre Lacazette                  0               0               0
# Andrea Belotti                       0               0               0
# Andrea Petagna                       0               0               0
# André Silva                          0               0               0
# ...                                ...             ...             ...
# Victor Osimhen                       0               0               1
# Willian José                         0               1               0
# Wout Weghorst                        1               0               0
# Youssef En-Nesyri                    0               1               0
# Yussuf Poulsen                       1               0               0
#
#                      League_Premier League  League_Serie A  AgeGroups  \
# Alexander Isak                           0               0          1
# Alexandre Lacazette                      1               0          2
# Andrea Belotti                           0               1          2
# Andrea Petagna                           0               1          2
# André Silva                              0               1          2
# ...                                    ...             ...        ...
# Victor Osimhen                           0               0          2
# Willian José                             0               0          2
# Wout Weghorst                            0               0          2
# Youssef En-Nesyri                        0               0          2
# Yussuf Poulsen                           0               0          2
#
#                        tahmin  Prediction
# Alexander Isak       3.069140   21.523390
# Alexandre Lacazette  3.483240   32.565067
# Andrea Belotti       3.400502   29.979149
# Andrea Petagna       3.105535   22.321152
# André Silva          3.639444   38.070657
# ...                       ...         ...
# Victor Osimhen       3.396354   29.855059
# Willian José         2.795083   16.363982
# Wout Weghorst        3.592709   36.332363
# Youssef En-Nesyri    2.883601   17.878539
# Yussuf Poulsen       3.147337   23.273998
#
# [74 rows x 53 columns]

# %%
df_forvet['difference'] = df_forvet['Prediction']-df_forvet['t_value']
# Out:
# <ipython-input-420-4a7158a20bdc>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_forvet['difference'] = df_forvet['Prediction']-df_forvet['t_value']

# %%
# Out:
#                                     Name Position   Age   Min  Goals  Goals.1  \
# Alexander Isak            Alexander Isak       FW  19.0  1507      9    0.540
# Alexandre Lacazette  Alexandre Lacazette       FW  28.0  1874     10    0.480
# Andrea Belotti            Andrea Belotti       FW  25.0  3008     16    0.480
# Andrea Petagna            Andrea Petagna       FW  24.0  3032     12    0.360
# André Silva                  André Silva       FW  23.0  1635     12    0.345
# ...                                  ...      ...   ...   ...    ...      ...
# Victor Osimhen            Victor Osimhen       FW  20.0  2287     13    0.510
# Willian José                Willian José       FW  27.0  2011     11    0.490
# Wout Weghorst              Wout Weghorst       FW  26.0  2739     16    0.530
# Youssef En-Nesyri      Youssef En-Nesyri       FW  22.0  2181      8    0.355
# Yussuf Poulsen            Yussuf Poulsen       FW  25.0  1222      5    0.370
#
#                      Asists  Asists.1  GoalAstPer90   90s  ...  \
# Alexander Isak            1     0.060          0.60  16.7  ...
# Alexandre Lacazette       4     0.190          0.67  20.8  ...
# Andrea Belotti            3     0.090          0.57  33.4  ...
# Andrea Petagna            1     0.030          0.39  33.7  ...
# André Silva               3     0.085          0.43  18.2  ...
# ...                     ...       ...           ...   ...  ...
# Victor Osimhen            4     0.160          0.67  25.4  ...
# Willian José              1     0.040          0.54  22.3  ...
# Wout Weghorst             3     0.100          0.62  30.4  ...
# Youssef En-Nesyri         2     0.065          0.42  24.2  ...
# Yussuf Poulsen            6     0.440          0.81  13.6  ...
#
#                      PlayerType_Midfielder  League_Bundesliga  League_La Liga  \
# Alexander Isak                           0                  0               1
# Alexandre Lacazette                      0                  0               0
# Andrea Belotti                           0                  0               0
# Andrea Petagna                           0                  0               0
# André Silva                              0                  0               0
# ...                                    ...                ...             ...
# Victor Osimhen                           0                  0               0
# Willian José                             0                  0               1
# Wout Weghorst                            0                  1               0
# Youssef En-Nesyri                        0                  0               1
# Yussuf Poulsen                           0                  1               0
#
#                      League_Ligue 1  League_Premier League  League_Serie A  \
# Alexander Isak                    0                      0               0
# Alexandre Lacazette               0                      1               0
# Andrea Belotti                    0                      0               1
# Andrea Petagna                    0                      0               1
# André Silva                       0                      0               1
# ...                             ...                    ...             ...
# Victor Osimhen                    1                      0               0
# Willian José                      0                      0               0
# Wout Weghorst                     0                      0               0
# Youssef En-Nesyri                 0                      0               0
# Yussuf Poulsen                    0                      0               0
#
#                      AgeGroups    tahmin  Prediction  difference
# Alexander Isak               1  3.069140   21.523390   -0.476610
# Alexandre Lacazette          2  3.483240   32.565067   -2.434933
# Andrea Belotti               2  3.400502   29.979149  -10.020851
# Andrea Petagna               2  3.105535   22.321152    5.321152
# André Silva                  2  3.639444   38.070657   10.070657
# ...                        ...       ...         ...         ...
# Victor Osimhen               2  3.396354   29.855059  -20.144941
# Willian José                 2  2.795083   16.363982   -3.636018
# Wout Weghorst                2  3.592709   36.332363    6.332363
# Youssef En-Nesyri            2  2.883601   17.878539    2.878539
# Yussuf Poulsen               2  3.147337   23.273998   -1.726002
#
# [74 rows x 54 columns]

# %%
df_forvet_x =  df_forvet[df_forvet['League_Premier League']==1].sort_values('t_value',ascending=False).loc[:,['Name', 't_value', 'Prediction', 'difference']].head(50)

# %%
df_forvet_x.columns = ['PlayerName', 'Transfermarkt Value', 'Prediction', 'Difference']

# %%
df_forvet_x
# Out:
#                                           PlayerName  Transfermarkt Value  \
# Mohamed Salah                          Mohamed Salah                120.0
# Harry Kane                                Harry Kane                120.0
# Sadio Mané                                Sadio Mané                120.0
# Raheem Sterling                      Raheem Sterling                110.0
# Marcus Rashford                      Marcus Rashford                 80.0
# Roberto Firmino                      Roberto Firmino                 72.0
# Bernardo Silva                        Bernardo Silva                 70.0
# Richarlison                              Richarlison                 60.0
# Christian Pulisic                  Christian Pulisic                 60.0
# Phil Foden                                Phil Foden                 60.0
# Gabriel Jesus                          Gabriel Jesus                 60.0
# Anthony Martial                      Anthony Martial                 55.0
# Mason Greenwood                      Mason Greenwood                 50.0
# Jack Grealish                          Jack Grealish                 50.0
# Riyad Mahrez                            Riyad Mahrez                 48.0
# Dominic Calvert-Lewin          Dominic Calvert-Lewin                 45.0
# Nicolas Pépé                            Nicolas Pépé                 40.0
# Pierre-Emerick Aubameyang  Pierre-Emerick Aubameyang                 40.0
# Diogo Jota                                Diogo Jota                 40.0
# Raúl Jiménez                            Raúl Jiménez                 40.0
# Tammy Abraham                          Tammy Abraham                 40.0
# Sergio Agüero                          Sergio Agüero                 35.0
# Alexandre Lacazette              Alexandre Lacazette                 35.0
# Callum Hudson-Odoi                Callum Hudson-Odoi                 35.0
# Sébastien Haller                    Sébastien Haller                 30.0
# Moise Kean                                Moise Kean                 25.0
#
#                            Prediction  Difference
# Mohamed Salah              155.318826   35.318826
# Harry Kane                  92.070160  -27.929840
# Sadio Mané                 114.180262   -5.819738
# Raheem Sterling            123.729914   13.729914
# Marcus Rashford             70.329963   -9.670037
# Roberto Firmino             61.710520  -10.289480
# Bernardo Silva              46.966574  -23.033426
# Richarlison                 46.549537  -13.450463
# Christian Pulisic           48.336902  -11.663098
# Phil Foden                  56.552633   -3.447367
# Gabriel Jesus               47.389728  -12.610272
# Anthony Martial             57.795870    2.795870
# Mason Greenwood             45.297065   -4.702935
# Jack Grealish               43.081864   -6.918136
# Riyad Mahrez                51.430697    3.430697
# Dominic Calvert-Lewin       53.338864    8.338864
# Nicolas Pépé                36.905394   -3.094606
# Pierre-Emerick Aubameyang   39.929488   -0.070512
# Diogo Jota                  41.584178    1.584178
# Raúl Jiménez                72.393873   32.393873
# Tammy Abraham               51.913139   11.913139
# Sergio Agüero               37.190653    2.190653
# Alexandre Lacazette         32.565067   -2.434933
# Callum Hudson-Odoi          52.801773   17.801773
# Sébastien Haller            37.046302    7.046302
# Moise Kean                  25.875327    0.875327

# %%
df
# Out:
#                               Name Position   Age   Min  Goals  Goals.1  \
# PlayerName
# Aaron Connolly      Aaron Connolly       FW  19.0  1258      3     0.21
# Aaron Cresswell    Aaron Cresswell       DF  29.0  2727      3     0.10
# Aaron Leya Iseka  Aaron Leya Iseka       FW  21.0   777      2     0.23
# Aaron Ramsdale      Aaron Ramsdale       GK  21.0  3330      0     0.00
# Aaron Ramsey          Aaron Ramsey       MF  28.0  1051      3     0.26
# ...                            ...      ...   ...   ...    ...      ...
# Ángel Montoro        Ángel Montoro       MF  31.0   973      2     0.18
# Éder Militão          Éder Militão       DF  21.0  1022      0     0.00
# Édgar Méndez          Édgar Méndez       MF  29.0   864      1     0.10
# Óscar Plano            Óscar Plano       MF  28.0  2505      4     0.14
# Ömer Toprak            Ömer Toprak       DF  30.0   715      0     0.00
#
#                   Asists  Asists.1  GoalAstPer90   90s  ...  SuccPressRatio  \
# PlayerName                                              ...
# Aaron Connolly         1      0.07          0.29  14.0  ...            29.5
# Aaron Cresswell        0      0.00          0.10  30.3  ...            33.2
# Aaron Leya Iseka       0      0.00          0.23   8.6  ...            20.4
# Aaron Ramsdale         1      0.03          0.03  37.0  ...            12.5
# Aaron Ramsey           1      0.09          0.34  11.7  ...            28.4
# ...                  ...       ...           ...   ...  ...             ...
# Ángel Montoro          5      0.46          0.65  10.8  ...            26.9
# Éder Militão           0      0.00          0.00  11.4  ...            33.7
# Édgar Méndez           0      0.00          0.10   9.6  ...            22.4
# Óscar Plano            2      0.07          0.22  27.8  ...            29.1
# Ömer Toprak            0      0.00          0.00   7.9  ...            26.0
#
#                   MatchPlayed  PointPerMatch  TouchPenArea  SuccDrib  \
# PlayerName
# Aaron Connolly             24           1.13          61.0       6.0
# Aaron Cresswell            31           0.97          26.0      16.0
# Aaron Leya Iseka           22           0.27          39.0       7.0
# Aaron Ramsdale             37           0.92           0.0       0.0
# Aaron Ramsey               24           2.25          61.0      16.0
# ...                       ...            ...           ...       ...
# Ángel Montoro              15           1.60          13.0       6.0
# Éder Militão               15           2.33           4.0       1.0
# Édgar Méndez               16           0.94          17.0      12.0
# Óscar Plano                36           1.17          53.0      11.0
# Ömer Toprak                10           0.50           5.0       5.0
#
#                   DribLegs  PlayerType  Value  Value2                Comp
# PlayerName
# Aaron Connolly         1.0     Forward    9.0       M  eng Premier League
# Aaron Cresswell        2.0    Defender   10.0       M  eng Premier League
# Aaron Leya Iseka       0.0     Forward  600.0       K          fr Ligue 1
# Aaron Ramsdale         0.0  Goalkeeper   20.0       M  eng Premier League
# Aaron Ramsey           0.0  Midfielder   20.0       M          it Serie A
# ...                    ...         ...    ...     ...                 ...
# Ángel Montoro          2.0  Midfielder    2.0       M          es La Liga
# Éder Militão           0.0    Defender   20.0       M          es La Liga
# Édgar Méndez           1.0  Midfielder    6.0       M          es La Liga
# Óscar Plano            1.0  Midfielder    2.0       M          es La Liga
# Ömer Toprak            0.0    Defender    5.0       M       de Bundesliga
#
# [1448 rows x 41 columns]

# %%
df
# Out:
#                                 Name Position   Age   Min  Goals   Goals.1  \
# Aaron Ramsey            Aaron Ramsey       MF  28.0  1051      3  0.260000
# Aaron Wan-Bissaka  Aaron Wan-Bissaka       DF  21.0  3070      0  0.000000
# Abdou Diallo            Abdou Diallo       DF  23.0  1201      0  0.000000
# Adama Traoré            Adama Traoré       MF  24.0  7274     10  0.076667
# Adil Aouchiche        Adil Aouchiche       MF  17.0    64      0  0.000000
# ...                              ...      ...   ...   ...    ...       ...
# Youssef En-Nesyri  Youssef En-Nesyri       FW  22.0  2181      8  0.355000
# Youssouf Fofana      Youssouf Fofana       MF  20.0  1618      1  0.045000
# Yussuf Poulsen        Yussuf Poulsen       FW  25.0  1222      5  0.370000
# Ángel Correa            Ángel Correa       MF  24.0  2061      5  0.220000
# Éder Militão            Éder Militão       DF  21.0  1022      0  0.000000
#
#                    Asists  Asists.1  GoalAstPer90   90s  ...      Winner  \
# Aaron Ramsey            1  0.090000         0.340  11.7  ...   2916.0000
# Aaron Wan-Bissaka       4  0.120000         0.120  34.1  ...   3837.8025
# Abdou Diallo            1  0.070000         0.070  13.3  ...   1524.1216
# Adama Traoré           26  0.223333         0.300  80.8  ...  13857.9984
# Adil Aouchiche          0  0.000000         0.000   0.7  ...      9.0000
# ...                   ...       ...           ...   ...  ...         ...
# Youssef En-Nesyri       2  0.065000         0.420  24.2  ...   1850.7204
# Youssouf Fofana         2  0.150000         0.195  18.0  ...   1062.7600
# Yussuf Poulsen          6  0.440000         0.810  13.6  ...   1516.3236
# Ángel Correa            6  0.260000         0.480  22.9  ...   3489.2649
# Éder Militão            0  0.000000         0.000  11.4  ...   1221.5025
#
#                    PlayerType_Defender  PlayerType_Forward  \
# Aaron Ramsey                         0                   0
# Aaron Wan-Bissaka                    1                   0
# Abdou Diallo                         1                   0
# Adama Traoré                         0                   0
# Adil Aouchiche                       0                   0
# ...                                ...                 ...
# Youssef En-Nesyri                    0                   1
# Youssouf Fofana                      0                   0
# Yussuf Poulsen                       0                   1
# Ángel Correa                         0                   0
# Éder Militão                         1                   0
#
#                    PlayerType_Midfielder  League_Bundesliga  League_La Liga  \
# Aaron Ramsey                           1                  0               0
# Aaron Wan-Bissaka                      0                  0               0
# Abdou Diallo                           0                  0               0
# Adama Traoré                           1                  0               0
# Adil Aouchiche                         1                  0               0
# ...                                  ...                ...             ...
# Youssef En-Nesyri                      0                  0               1
# Youssouf Fofana                        1                  0               0
# Yussuf Poulsen                         0                  1               0
# Ángel Correa                           1                  0               1
# Éder Militão                           0                  0               1
#
#                    League_Ligue 1  League_Premier League  League_Serie A  \
# Aaron Ramsey                    0                      0               1
# Aaron Wan-Bissaka               0                      1               0
# Abdou Diallo                    1                      0               0
# Adama Traoré                    1                      0               0
# Adil Aouchiche                  1                      0               0
# ...                           ...                    ...             ...
# Youssef En-Nesyri               0                      0               0
# Youssouf Fofana                 1                      0               0
# Yussuf Poulsen                  0                      0               0
# Ángel Correa                    0                      0               0
# Éder Militão                    0                      0               0
#
#                    AgeGroups
# Aaron Ramsey               2
# Aaron Wan-Bissaka          2
# Abdou Diallo               2
# Adama Traoré               2
# Adil Aouchiche             1
# ...                      ...
# Youssef En-Nesyri          2
# Youssouf Fofana            2
# Yussuf Poulsen             2
# Ángel Correa               2
# Éder Militão               2
#
# [274 rows x 52 columns]

# %%
df_mid = df[ (df['MatchPlayed']>20 ) & (df['PlayerType_Midfielder']==1) ]

x_features = [  'Goals',   'Asists',
        'GoalAstPer90',  'SCA',   'ShootPass',
       'ShootDrib', 'GCA',   'AssistPass', 'AssistDrib',
       'Crosses', 'PenaltyWon', 'AerialWonRate', 'ShootOnTarget', 'ShootPer90',
       'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
       'SuccDrib', 'DribLegs',   
       'Winner',  'League_Bundesliga', 'League_La Liga',
       'League_Ligue 1', 'League_Premier League', 'League_Serie A',
       'AgeGroups'  ] 


X = df_mid.reindex(columns=x_features)

y = df_mid.loc[:,"log_t_value"]

df_mid['tahmin'] = lm.predict(X)
df_mid['Prediction'] = np.exp(df_mid['tahmin'])
df_mid['difference'] = df_mid['Prediction']-df_mid['t_value']
df_mid =  df_mid[df_mid['League_Premier League']==1].sort_values('t_value',ascending=False).loc[:,['Name', 't_value', 'Prediction', 'difference']].head(50)
df_mid.columns = ['PlayerName', 'Transfermarkt Value', 'Prediction', 'Difference']
df_mid
# Out:
# <ipython-input-651-1f150b7c5c66>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mid['tahmin'] = lm.predict(X)
# <ipython-input-651-1f150b7c5c66>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mid['Prediction'] = np.exp(df_mid['tahmin'])
# <ipython-input-651-1f150b7c5c66>:20: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_mid['difference'] = df_mid['Prediction']-df_mid['t_value']
#                               PlayerName  Transfermarkt Value  Prediction  \
# Kevin De Bruyne          Kevin De Bruyne                120.0   49.630489
# Rodri                              Rodri                 64.0   66.788099
# Fabinho                          Fabinho                 60.0   75.443645
# N'Golo Kanté                N'Golo Kanté                 60.0   51.852055
# Declan Rice                  Declan Rice                 55.0   22.845527
# James Maddison            James Maddison                 55.0   50.336955
# Jorginho                        Jorginho                 50.0   46.892247
# Wilfried Zaha              Wilfried Zaha                 50.0   36.930936
# Rúben Neves                  Rúben Neves                 50.0   27.961520
# Youri Tielemans          Youri Tielemans                 50.0   34.595612
# Mason Mount                  Mason Mount                 45.0   33.611007
# Wilfred Ndidi              Wilfred Ndidi                 45.0   38.437977
# Georginio Wijnaldum  Georginio Wijnaldum                 40.0   74.003889
# Dele Alli                      Dele Alli                 38.0   41.817391
# Giovani Lo Celso        Giovani Lo Celso                 35.0   30.450355
# Dani Ceballos              Dani Ceballos                 32.0   38.222486
# Leander Dendoncker    Leander Dendoncker                 32.0   43.155116
# Allan Saint-Maximin  Allan Saint-Maximin                 32.0   38.697585
# Jordan Henderson        Jordan Henderson                 28.0   45.145897
# Lucas Torreira            Lucas Torreira                 28.0   39.840082
# Harvey Barnes              Harvey Barnes                 28.0   33.298543
#
#                      Difference
# Kevin De Bruyne      -70.369511
# Rodri                  2.788099
# Fabinho               15.443645
# N'Golo Kanté          -8.147945
# Declan Rice          -32.154473
# James Maddison        -4.663045
# Jorginho              -3.107753
# Wilfried Zaha        -13.069064
# Rúben Neves          -22.038480
# Youri Tielemans      -15.404388
# Mason Mount          -11.388993
# Wilfred Ndidi         -6.562023
# Georginio Wijnaldum   34.003889
# Dele Alli              3.817391
# Giovani Lo Celso      -4.549645
# Dani Ceballos          6.222486
# Leander Dendoncker    11.155116
# Allan Saint-Maximin    6.697585
# Jordan Henderson      17.145897
# Lucas Torreira        11.840082
# Harvey Barnes          5.298543

# %%
def reg_plot(x, y):
    ''' Takes in all of the X values and Y predictor '''

    plt.figure(figsize=(15, 5))

    lr = LinearRegression()
    lr.fit(x,y)
    pred = lr.predict(x)

    # Residual plot
    plt.subplot(1, 2, 1)
    res = y - pred
    plt.scatter(pred, res)
    plt.title("Residual plot")
    plt.xlabel("prediction")
    plt.ylabel("residuals")

    # QQ plot
    plt.subplot(1, 2, 2)
    stats.probplot(res, dist="norm", plot=plt)
    plt.title("Normal Q-Q plot")

# %%
import scipy.stats as stats

X_train, X_hold_out, y_train, y_hold_out = train_test_split(X, y, test_size=.2, random_state=27) # 80% Train 20% Test
kf = KFold(n_splits=5, shuffle=True, random_state = 27)
reg_plot(X_train, y_train)

# %%
feat_list_for  = ['Name', 'Position', 'Age', 'Min', 'Goals', 'Goals.1', 'Asists',
       'Asists.1', 'GoalAstPer90', '90s', 'SCA', 'SCA90', 'ShootPass',
       'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
       'CompletedPasses', 'PassCompRatio', 'TotDistPass', 'ProgDistPass',
       'Crosses', 'PenaltyWon', 'AerialWonRate', 'ShootOnTarget', 'ShootPer90',
       'GoalPerShoot', 'TacklesWon', 'TklDribbling', 'Blocks',
       'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
       'SuccDrib', 'DribLegs', 'Age2', 'Winner',  'League_Bundesliga', 'League_La Liga',
       'League_Ligue 1', 'League_Premier League', 'League_Serie A',
       'AgeGroups']

X = df.reindex(columns=x_features)

y = df.loc[:,"log_t_value"]
X_train, X_hold_out, y_train, y_hold_out = train_test_split(X, y, test_size=.2, random_state=27) # 80% Train 20% Test

# %%
lasso_reg(X_train, y_train, feat_list)
# Out:
# Best Alpha: 0.01
#
# Train r2: 0.7078531075436034
# Val r2: 0.25476074789813097
#
# [('Name', 0.0951410932183348), ('Position', 0.019013792730561786), ('Age', 0.020557993526172172), ('Min', 0.05350428304124251), ('Goals', 0.03578140696805512), ('Goals.1', -0.0), ('Asists', 0.0), ('Asists.1', 0.0), ('GoalAstPer90', -0.0), ('90s', -0.006547620686424141), ('SCA', 0.026338134381518327), ('SCA90', 0.06362473379835117), ('ShootPass', 0.0), ('ShootDrib', -0.028573496138125078), ('GCA', 0.015770592272611794), ('GCA90', 0.029482818449977053), ('AssistPass', 0.1385976733601692), ('AssistDrib', 0.022087261306620223), ('CompletedPasses', 0.01949324071893934), ('PassCompRatio', -0.0), ('TotDistPass', 0.0), ('ProgDistPass', -0.02111155541934424), ('Crosses', 0.0002478621434488179), ('PenaltyWon', -0.1580479235520416), ('AerialWonRate', 0.2646630523938841), ('ShootOnTarget', -0.0), ('ShootPer90', -0.0684698162999596)]

# %%
ridge_reg(X_train, y_train, feat_list)
# Out:
# Best Alpha: 100
# Train r2: 0.6579700518843559
# Val r2: 0.3081678103580193
#
# [('Name', 0.040180339478908124), ('Position', 0.02259216561288424), ('Age', 0.030450637770469864), ('Min', 0.02643257625203223), ('Goals', 0.03485872164050713), ('Goals.1', -0.003257030697294283), ('Asists', 0.020649973913568914), ('Asists.1', 0.01289730335097202), ('GoalAstPer90', -0.008304233545623459), ('90s', -0.015285813893332455), ('SCA', 0.024300713164381264), ('SCA90', 0.026054167216082377), ('ShootPass', 0.016784605553478403), ('ShootDrib', -0.019644100337893072), ('GCA', 0.03954963520166084), ('GCA90', 0.01779758363969726), ('AssistPass', 0.08440638189210177), ('AssistDrib', 0.03493016212377293), ('CompletedPasses', 0.014134708805942016), ('PassCompRatio', -0.004505635496058926), ('TotDistPass', 0.03982726958043326), ('ProgDistPass', -0.04118552415723483), ('Crosses', -0.009167878071970396), ('PenaltyWon', -0.1262721044628519), ('AerialWonRate', 0.16649740609100736), ('ShootOnTarget', -0.018680227271285276), ('ShootPer90', -0.03767844300521988)]

# %%
feat_list_for  = ['Name', 'Position', 'Age', 'Min', 'Goals', 'Goals.1', 'Asists',
       'Asists.1', 'GoalAstPer90', '90s', 'SCA', 'SCA90', 'ShootPass',
       'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
       'CompletedPasses', 'PassCompRatio', 'TotDistPass', 'ProgDistPass',
       'Crosses', 'PenaltyWon', 'AerialWonRate', 'ShootOnTarget', 'ShootPer90',
       'GoalPerShoot', 'TacklesWon', 'TklDribbling', 'Blocks',
       'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
       'SuccDrib', 'DribLegs', 'Age2', 'Winner',  'League_Bundesliga', 'League_La Liga',
       'League_Ligue 1', 'League_Premier League', 'League_Serie A',
       'AgeGroups']

X = df[ (df['MatchPlayed']>0 ) & (df['PlayerType_Forward']==1) ].reindex(columns=x_features)

y = df[ (df['MatchPlayed']>0 ) & (df['PlayerType_Forward']==1) ].loc[:,"log_t_value"]

X_train, X_hold_out, y_train, y_hold_out = train_test_split(X, y, test_size=.2, random_state=27) # 80% Train 20% Test

# %%
lasso_reg(X_train, y_train, feat_list)
# Out:
# Best Alpha: 0.1
#
# Train r2: 0.7559933730391839
# Val r2: 0.5181166765730619
#
# [('Name', 0.0), ('Position', 0.0), ('Age', 0.012477398142736695), ('Min', 0.0), ('Goals', 0.00844246964058802), ('Goals.1', 0.0), ('Asists', 0.0), ('Asists.1', 0.0), ('GoalAstPer90', 0.0), ('90s', 0.0), ('SCA', 0.0), ('SCA90', -0.0), ('ShootPass', 0.0), ('ShootDrib', 0.0), ('GCA', 0.0), ('GCA90', 0.0), ('AssistPass', 0.048076869424183835), ('AssistDrib', 0.0901548518516215), ('CompletedPasses', 0.0), ('PassCompRatio', 0.0), ('TotDistPass', 0.07134179544873523), ('ProgDistPass', 0.0), ('Crosses', 0.0), ('PenaltyWon', -0.11834065505595616), ('AerialWonRate', 0.25121753831151133), ('ShootOnTarget', -0.0), ('ShootPer90', -0.0)]

# %%
ridge_reg(X_train, y_train, feat_list)
# Out:
# Best Alpha: 100
# Train r2: 0.6856585593206742
# Val r2: 0.38094988102791105
#
# [('Name', 0.0333671521414346), ('Position', 0.0052134634948251685), ('Age', 0.035567972266523265), ('Min', 0.020539578468010987), ('Goals', 0.029475295549287305), ('Goals.1', 0.010228428772354501), ('Asists', 0.014844219352172259), ('Asists.1', 0.023260939846122233), ('GoalAstPer90', 0.011273611551437775), ('90s', 0.015582832594105667), ('SCA', 0.01620406322618013), ('SCA90', -0.01853968545257906), ('ShootPass', 0.013045845983396025), ('ShootDrib', -0.003731069361222242), ('GCA', 0.014500861477568976), ('GCA90', -0.0017029358573172552), ('AssistPass', 0.05972115879915238), ('AssistDrib', 0.04306577966960145), ('CompletedPasses', 0.010968937379677671), ('PassCompRatio', 0.014517469045716653), ('TotDistPass', 0.05377337883149463), ('ProgDistPass', -0.013086535681369063), ('Crosses', -0.007481853758890309), ('PenaltyWon', -0.0796755599646329), ('AerialWonRate', 0.10590771964157623), ('ShootOnTarget', -0.024824132433219674), ('ShootPer90', -0.025111736734316475)]

# %%
feat_list_for  = ['Name', 'Position', 'Age',   'Goals',   'Asists',
       'Asists.1', 'GoalAstPer90', '90s', 'SCA', 'SCA90', 'ShootPass',
       'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
       'CompletedPasses', 'PassCompRatio', 'TotDistPass', 'ProgDistPass',
       'Crosses', 'PenaltyWon', 'AerialWonRate', 'ShootOnTarget', 'ShootPer90',
       'GoalPerShoot', 'TacklesWon', 'TklDribbling', 'Blocks',
       'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',  'Age2',   'League_Bundesliga', 'League_La Liga',
       'League_Ligue 1', 'League_Premier League', 'League_Serie A',
       'AgeGroups']

X = df.reindex(columns=x_features)

y = df.loc[:,"log_t_value"]


X_train, X_test, y_train, y_test = train_test_split(X,y,    test_size=0.3,    random_state=0)
X_train.shape, X_test.shape ,y_train.shape ,y_test.shape
# Out:
# ((191, 27), (83, 27), (191,), (83,))

# %%
from sklearn.linear_model import LinearRegression
# importing linear regression
lreg = LinearRegression()

# for cross validation

from sklearn.model_selection import train_test_split

#X = train.drop('Item_Outlet_Sales',1)

x_train, x_cv, y_train, y_cv = train_test_split(X,y, test_size =0.2 )

# %%
lreg.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
# Linear modelimizi eğitelim

#lreg.fit(x_train,y_train)

# calculating mse

pred = lreg.predict(x_cv)

#Hataların karesel ortalamasına bakıyoruz
mse = np.mean((pred - y_cv)**2)

#modelin score r2

# evaluation using r-square

lreg.score(x_cv, y_cv)
#mse
# Out:
# 0.5843462754738604

# %%
from pandas import DataFrame

# %%
predictors = x_train.columns

coef = Series(lreg.coef_,predictors).sort_values()

coef.plot(kind='bar', title='Modal Coefficients')
# Out:
# <AxesSubplot:title={'center':'Modal Coefficients'}>

# %%
coeff = DataFrame(x_train.columns)

coeff['Coefficient Estimate'] = Series(lreg.coef_)

coeff
# Out:
#                         0  Coefficient Estimate
# 0                   Goals              0.035082
# 1                  Asists              0.007507
# 2            GoalAstPer90              0.160517
# 3                     SCA             -0.000032
# 4               ShootPass              0.006374
# 5               ShootDrib              0.007808
# 6                     GCA              0.021337
# 7              AssistPass             -0.033099
# 8              AssistDrib             -0.044690
# 9                 Crosses             -0.002470
# 10             PenaltyWon             -0.003330
# 11          AerialWonRate              0.003092
# 12          ShootOnTarget             -0.003034
# 13             ShootPer90             -0.109943
# 14         SuccPressRatio              0.008775
# 15            MatchPlayed             -0.004368
# 16          PointPerMatch              0.216248
# 17           TouchPenArea              0.000526
# 18               SuccDrib              0.001062
# 19               DribLegs             -0.003639
# 20                 Winner              0.000042
# 21      League_Bundesliga             -0.097285
# 22         League_La Liga              0.051869
# 23         League_Ligue 1             -0.391292
# 24  League_Premier League              0.476491
# 25         League_Serie A             -0.039783
# 26              AgeGroups             -0.233707

# %%
from sklearn.linear_model import Ridge

##training the model

ridgeReg = Ridge(alpha=0.05, normalize=True)

ridgeReg.fit(x_train,y_train)

pred = ridgeReg.predict(x_cv)

##calculating mse

mse = np.mean((pred - y_cv)**2)
ridgeReg.score(x_cv, y_cv)
# Out:
# 0.595053474197168

# %%
mse
# Out:
# 0.10040450410756212

# %%
from sklearn.linear_model import Ridge

##training the model

ridgeReg = Ridge(alpha=0.5, normalize=True)

ridgeReg.fit(x_train,y_train)

pred = ridgeReg.predict(x_cv)

##calculating mse

mse = np.mean((pred - y_cv)**2)

ridgeReg.score(x_cv, y_cv)
# Out:
# 0.5176923251514991

# %%
from sklearn.linear_model import Ridge

##training the model

ridgeReg = Ridge(alpha=5, normalize=True)

ridgeReg.fit(x_train,y_train)

pred = ridgeReg.predict(x_cv)

##calculating mse

mse = np.mean((pred - y_cv)**2)
ridgeReg.score(x_cv, y_cv)
# Out:
# 0.28855007025349955

# %%
mse
# Out:
# 0.17640051918444613

# %%
predictors = x_train.columns

coef = Series(ridgeReg.coef_,predictors).sort_values()

coef.plot(kind='bar', title='Modal Coefficients')
# Out:
# <AxesSubplot:title={'center':'Modal Coefficients'}>

# %%
from sklearn.linear_model import Lasso

lassoReg = Lasso(alpha=0.05, normalize=True)

lassoReg.fit(x_train,y_train)

pred = lassoReg.predict(x_cv)

#calculating mse

mse = np.mean((pred - y_cv)**2)


lassoReg.score(x_cv,y_cv)
# Out:
# -0.05011016894600706

# %%
from sklearn.linear_model import Lasso

lassoReg = Lasso(alpha=0.5, normalize=True)

lassoReg.fit(x_train,y_train)

pred = lassoReg.predict(x_cv)

#calculating mse

mse = np.mean((pred - y_cv)**2)



lassoReg.score(x_cv,y_cv)
# Out:
# -0.05011016894600706

# %%
from sklearn.linear_model import Lasso

lassoReg = Lasso(alpha=0.0005, normalize=True)

lassoReg.fit(x_train,y_train)

pred = lassoReg.predict(x_cv)

#calculating mse

mse = np.mean((pred - y_cv)**2)



lassoReg.score(x_cv,y_cv)
# Out:
# 0.5854107403383042

# %%
from sklearn.linear_model import ElasticNet

ENreg = ElasticNet(alpha=500, l1_ratio=0.5, normalize=False)

ENreg.fit(x_train,y_train)

pred_cv = ENreg.predict(x_cv)

#calculating mse

mse = np.mean((pred_cv - y_cv)**2)


ENreg.score(x_cv,y_cv) #R-Squar
# Out:
# -0.015035117823936295

# %%
df.columns
# Out:
# Index(['Name', 'Position', 'Age', 'Min', 'Goals', 'Goals.1', 'Asists',
#        'Asists.1', 'GoalAstPer90', '90s', 'SCA', 'SCA90', 'ShootPass',
#        'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
#        'CompletedPasses', 'PassCompRatio', 'TotDistPass', 'ProgDistPass',
#        'Crosses', 'PenaltyWon', 'AerialWonRate', 'ShootOnTarget', 'ShootPer90',
#        'GoalPerShoot', 'TacklesWon', 'TklDribbling', 'Blocks',
#        'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
#        'SuccDrib', 'DribLegs', 'Value', 'NetValue', 't_value', 'log_t_value',
#        'Age2', 'Winner', 'PlayerType_Defender', 'PlayerType_Forward',
#        'PlayerType_Midfielder', 'League_Bundesliga', 'League_La Liga',
#        'League_Ligue 1', 'League_Premier League', 'League_Serie A',
#        'AgeGroups'],
#       dtype='object')

# %%
x_features = [  'Goals',   'Asists',
        'GoalAstPer90',  'SCA',   'ShootPass',
       'ShootDrib', 'GCA',   'AssistPass', 'AssistDrib',
       'Crosses', 'PenaltyWon', 'AerialWonRate', 'ShootOnTarget', 'ShootPer90',
       'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
       'SuccDrib', 'DribLegs',   
       'Winner',  'League_Bundesliga', 'League_La Liga',
       'League_Ligue 1', 'League_Premier League', 'League_Serie A',
       'AgeGroups'  ] 


X = df_forvet[df_forvet['PlayerType_Forward']==1].reindex(columns=x_features)

y = df_forvet[df_forvet['PlayerType_Forward']==1].loc[:,"log_t_value"]


x_train, x_cv, y_train, y_cv = train_test_split(X,y, test_size =0.2 )

# %%
from sklearn.linear_model import Ridge

##training the model

ridgeReg = Ridge(alpha=0.05, normalize=True)

ridgeReg.fit(x_train,y_train)

pred = ridgeReg.predict(x_cv)

##calculating mse

mse = np.mean((pred - y_cv)**2)
ridgeReg.score(x_cv, y_cv)
# Out:
# 0.5918963809327213

# %%
df_forvet.columns
# Out:
# Index(['Name', 'Position', 'Age', 'Min', 'Goals', 'Goals.1', 'Asists',
#        'Asists.1', 'GoalAstPer90', '90s', 'SCA', 'SCA90', 'ShootPass',
#        'ShootDrib', 'GCA', 'GCA90', 'AssistPass', 'AssistDrib',
#        'CompletedPasses', 'PassCompRatio', 'TotDistPass', 'ProgDistPass',
#        'Crosses', 'PenaltyWon', 'AerialWonRate', 'ShootOnTarget', 'ShootPer90',
#        'GoalPerShoot', 'TacklesWon', 'TklDribbling', 'Blocks',
#        'SuccPressRatio', 'MatchPlayed', 'PointPerMatch', 'TouchPenArea',
#        'SuccDrib', 'DribLegs', 't_value', 'NetValue', 'log_t_value', 'Age2',
#        'Winner', 'PlayerType_Defender', 'PlayerType_Forward',
#        'PlayerType_Midfielder', 'League_Bundesliga', 'League_La Liga',
#        'League_Ligue 1', 'League_Premier League', 'League_Serie A',
#        'AgeGroups', 'tahmin', 'Prediction', 'difference'],
#       dtype='object')

# %%
plt.figure(figsize=(15,15))

predicted_bar = sns.jointplot(df['Asists'], df['AssistPass'] ,kind='hist' )
plt.xlabel ('Asists')
plt.ylabel ('AssistPass')
plt.figure(figsize=(15,15))
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variables as keyword args: x, y. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
